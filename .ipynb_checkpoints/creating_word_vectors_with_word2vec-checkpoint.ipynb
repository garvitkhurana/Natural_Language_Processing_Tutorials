# %% [markdown]
# # Creating Word Vectors with word2vec

# %% [markdown]
# In this notebook, we create word vectors from a corpus of public-domain books, a selection from [Project Gutenberg](https://www.gutenberg.org/).

# %% [markdown]
# #### Load dependencies

# %%
import nltk
from nltk import word_tokenize, sent_tokenize
import gensim
from gensim.models.word2vec import Word2Vec
from sklearn.manifold import TSNE
import pandas as pd
from bokeh.io import output_notebook
from bokeh.plotting import show, figure
# %matplotlib inline

# %%
nltk.download('punkt') # English-language sentence tokenizer (not all periods end sentences; not all sentences start with a capital letter)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/garvitkhurana/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# #### Load data

# %%
nltk.download('gutenberg')
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     /Users/garvitkhurana/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# True

# %%
from nltk.corpus import gutenberg

# %%
len(gutenberg.fileids())
# Out:
# 18

# %%
gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %% [markdown]
# #### Tokenize text

# %%
gberg_sent_tokens = sent_tokenize(gutenberg.raw())

# %%
gberg_sent_tokens[10:20]
# Out:
# ['It was on the wedding-day\nof this beloved friend that Emma first sat in mournful thought\nof any continuance.',
#  'The wedding over, and the bride-people gone,\nher father and herself were left to dine together, with no prospect\nof a third to cheer a long evening.',
#  'Her father composed himself\nto sleep after dinner, as usual, and she had then only to sit\nand think of what she had lost.',
#  'The event had every promise of happiness for her friend.',
#  "Mr. Weston\nwas a man of unexceptionable character, easy fortune, suitable age,\nand pleasant manners; and there was some satisfaction in considering\nwith what self-denying, generous friendship she had always wished\nand promoted the match; but it was a black morning's work for her.",
#  'The want of Miss Taylor would be felt every hour of every day.',
#  'She recalled her past kindness--the kindness, the affection of sixteen\nyears--how she had taught and how she had played with her from five\nyears old--how she had devoted all her powers to attach and amuse\nher in health--and how nursed her through the various illnesses\nof childhood.',
#  "A large debt of gratitude was owing here; but the\nintercourse of the last seven years, the equal footing and perfect\nunreserve which had soon followed Isabella's marriage, on their\nbeing left to each other, was yet a dearer, tenderer recollection.",
#  'She had been a friend and companion such as few possessed: intelligent,\nwell-informed, useful, gentle, knowing all the ways of the family,\ninterested in all its concerns, and peculiarly interested in herself,\nin every pleasure, every scheme of hers--one to whom she could speak\nevery thought as it arose, and who had such an affection for her\nas could never find fault.',
#  'How was she to bear the change?--It was true that her friend was\ngoing only half a mile from them; but Emma was aware that great must\nbe the difference between a Mrs. Weston, only half a mile from them,\nand a Miss Taylor in the house; and with all her advantages,\nnatural and domestic, she was now in great danger of suffering\nfrom intellectual solitude.']

# %%
gberg_sent_tokens[1]
# Out:
# "She was the youngest of the two daughters of a most affectionate,\nindulgent father; and had, in consequence of her sister's marriage,\nbeen mistress of his house from a very early period."

# %%
word_tokenize(gberg_sent_tokens[1])
# Out:
# ['She',
#  'was',
#  'the',
#  'youngest',
#  'of',
#  'the',
#  'two',
#  'daughters',
#  'of',
#  'a',
#  'most',
#  'affectionate',
#  ',',
#  'indulgent',
#  'father',
#  ';',
#  'and',
#  'had',
#  ',',
#  'in',
#  'consequence',
#  'of',
#  'her',
#  'sister',
#  "'s",
#  'marriage',
#  ',',
#  'been',
#  'mistress',
#  'of',
#  'his',
#  'house',
#  'from',
#  'a',
#  'very',
#  'early',
#  'period',
#  '.']

# %%
word_tokenize(gberg_sent_tokens[1])[14]
# Out:
# 'father'

# %%
# a convenient method that handles newlines, as well as tokenizing sentences and words in one shot
gberg_sents = gutenberg.sents()

# %%
gberg_sents[3]
# Out:
# ['Emma',
#  'Woodhouse',
#  ',',
#  'handsome',
#  ',',
#  'clever',
#  ',',
#  'and',
#  'rich',
#  ',',
#  'with',
#  'a',
#  'comfortable',
#  'home',
#  'and',
#  'happy',
#  'disposition',
#  ',',
#  'seemed',
#  'to',
#  'unite',
#  'some',
#  'of',
#  'the',
#  'best',
#  'blessings',
#  'of',
#  'existence',
#  ';',
#  'and',
#  'had',
#  'lived',
#  'nearly',
#  'twenty',
#  '-',
#  'one',
#  'years',
#  'in',
#  'the',
#  'world',
#  'with',
#  'very',
#  'little',
#  'to',
#  'distress',
#  'or',
#  'vex',
#  'her',
#  '.']

# %%
gberg_sents[4]
# Out:
# ['She',
#  'was',
#  'the',
#  'youngest',
#  'of',
#  'the',
#  'two',
#  'daughters',
#  'of',
#  'a',
#  'most',
#  'affectionate',
#  ',',
#  'indulgent',
#  'father',
#  ';',
#  'and',
#  'had',
#  ',',
#  'in',
#  'consequence',
#  'of',
#  'her',
#  'sister',
#  "'",
#  's',
#  'marriage',
#  ',',
#  'been',
#  'mistress',
#  'of',
#  'his',
#  'house',
#  'from',
#  'a',
#  'very',
#  'early',
#  'period',
#  '.']

# %%
gberg_sents[4][14]
# Out:
# 'father'

# %%
# another convenient method that we don't immediately need: 
gutenberg.words()
# Out:
# ['[', 'Emma', 'by', 'Jane', 'Austen', '1816', ']', ...]

# %%
# gutenberg.words() is analogous to the following line, which need not be run: 
# word_tokenize(gutenberg.raw())

# %%
# our Gutenberg corpus is 2.6m words in length: 
len(gutenberg.words())
# Out:
# 2621613

# %% [markdown]
# #### Run word2vec

# %%
model = Word2Vec(sentences=gberg_sents, size=64, sg=1, window=10, min_count=5, seed=42, workers=8)

# %%
model.save('raw_gutenberg_model.w2v')

# %% [markdown]
# #### Explore model

# %%
# skip re-training the model with the next line:  
model = gensim.models.Word2Vec.load('raw_gutenberg_model.w2v')

# %%
model['dog']
# Out:
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# array([ 0.3053435 , -0.07252906, -0.29097092,  0.20746301,  0.107388  ,
#        -0.2844218 ,  0.59477305,  0.16292502, -0.49249607, -0.05691642,
#        -0.01925854,  0.26365885, -0.24174498,  0.07385814, -0.29609555,
#         0.85797703,  0.1487434 ,  0.07500249, -0.53042066, -0.19438119,
#        -0.2104455 ,  0.3757535 ,  0.20545578, -0.5120407 , -0.07545244,
#         0.20047879,  0.24465728, -0.28080732, -0.08647654,  0.05952702,
#        -0.0525215 ,  0.1272417 , -0.27532125,  0.04881461,  0.05023466,
#        -0.46337155, -0.03182503, -0.23401763,  0.05128494, -0.21973419,
#         0.34896898, -0.46952653,  0.10378018, -0.0963526 ,  0.00607536,
#        -0.02676994,  0.09038287, -0.05780681,  0.4179085 ,  0.8066078 ,
#        -0.11653104,  0.13916121,  0.23981547, -0.41562194,  0.14159057,
#        -0.00506096,  0.15783706,  0.08092081, -0.17989714, -0.3279827 ,
#         0.2910313 , -0.55803394, -0.2759927 ,  0.0281207 ], dtype=float32)

# %%
len(model['dog'])
# Out:
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# 64

# %%
model.most_similar('dog') # distance
# Out:
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('puppy', 0.830764651298523),
#  ('cage', 0.7922641038894653),
#  ('sweeper', 0.7721359133720398),
#  ('pet', 0.7546625733375549),
#  ('kettle', 0.7520705461502075),
#  ('thief', 0.7506059408187866),
#  ('shell', 0.746807336807251),
#  ('lazy', 0.7462347745895386),
#  ('pig', 0.7453721761703491),
#  ('chimney', 0.7429569959640503)]

# %%
model.most_similar('think')
# Out:
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('suppose', 0.8742314577102661),
#  ('manage', 0.8460203409194946),
#  ('contradict', 0.8366432785987854),
#  ('know', 0.8203177452087402),
#  ('downright', 0.8200138807296753),
#  ('argue', 0.8158806562423706),
#  ('believe', 0.8146969676017761),
#  ('Mamma', 0.8082491755485535),
#  ('awfully', 0.8076088428497314),
#  ('NOW', 0.8065305948257446)]

# %%
model.most_similar('day')
# Out:
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('morning', 0.7882235050201416),
#  ('night', 0.7580522894859314),
#  ('time', 0.7478247880935669),
#  ('evening', 0.7137569785118103),
#  ('month', 0.7110298871994019),
#  ('week', 0.6961895227432251),
#  ('morrow', 0.690854549407959),
#  ('sabbath', 0.6839328408241272),
#  ('Saturday', 0.6693803071975708),
#  ('fourteenth', 0.6682628989219666)]

# %%
model.most_similar('father')
# Out:
# [('mother', 0.8728880882263184),
#  ('brother', 0.8333652019500732),
#  ('sister', 0.7919358015060425),
#  ('wife', 0.7858221530914307),
#  ('daughter', 0.7800713181495667),
#  ('Amnon', 0.7543610334396362),
#  ('Tamar', 0.7502950429916382),
#  ('servant', 0.7387294769287109),
#  ('uncle', 0.7327381372451782),
#  ('curseth', 0.7289719581604004)]

# %%
model.most_similar('help')
# Out:
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('save', 0.7308444976806641),
#  ('stay', 0.7022508382797241),
#  ('exclaim', 0.6962946057319641),
#  ('--`', 0.6959395408630371),
#  ('cheerfully', 0.6921311020851135),
#  ('detain', 0.6833940148353577),
#  ('displease', 0.6814334392547607),
#  ('fret', 0.6795176267623901),
#  ('plead', 0.6768871545791626),
#  ('frighten', 0.6768587827682495)]

# %%
model.doesnt_match("mother father daughter dog".split())
# Out:
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `doesnt_match` (Method will be removed in 4.0.0, use self.wv.doesnt_match() instead).
#   """Entry point for launching an IPython kernel.
# 'dog'

# %%
model.similarity('father', 'dog')
# Out:
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   """Entry point for launching an IPython kernel.
# 0.4779410542903947

# %%
# close, but not quite; distinctly in female direction: 
model.most_similar(positive=['father', 'woman'], negative=['man'])
# Out:
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
# [('sister', 0.7819421291351318),
#  ('mother', 0.7774558663368225),
#  ('husband', 0.7644433975219727),
#  ('wife', 0.7548173666000366),
#  ('daughter', 0.750711977481842),
#  ('Sarah', 0.7175673246383667),
#  ('Sarai', 0.7047159671783447),
#  ('brother', 0.7015928030014038),
#  ('daughters', 0.6883976459503174),
#  ('elder', 0.675480842590332)]

# %%
# more confident about this one: 
model.most_similar(positive=['son', 'woman'], negative=['man'])
# Out:
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
# [('Sarah', 0.7308780550956726),
#  ('Sarai', 0.7305750250816345),
#  ('Hagar', 0.7288485169410706),
#  ('wife', 0.7285659909248352),
#  ('Leah', 0.7258926630020142),
#  ('daughter', 0.7169227004051208),
#  ('Bethuel', 0.7089294195175171),
#  ('Jesse', 0.7054682970046997),
#  ('Hittite', 0.7037913799285889),
#  ('conceived', 0.7014265060424805)]

# %%
model.most_similar(positive=['husband', 'woman'], negative=['man'])
# Out:
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('wife', 0.7323013544082642),
#  ('sister', 0.694678544998169),
#  ('conceived', 0.669508695602417),
#  ('mother', 0.6669032573699951),
#  ('child', 0.6628454923629761),
#  ('maid', 0.6540146470069885),
#  ('daughter', 0.6525365114212036),
#  ('widow', 0.6451483368873596),
#  ('nurse', 0.6337612271308899),
#  ('adultery', 0.6228774785995483)]

# %%
model.most_similar(positive=['king', 'woman'], negative=['man'], topn=30)
# Out:
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('Sarah', 0.7301355600357056),
#  ('Solomon', 0.6973534822463989),
#  ('Rachel', 0.6907618045806885),
#  ('Judah', 0.6843635439872742),
#  ('Sarai', 0.6781248450279236),
#  ('Leah', 0.6770263910293579),
#  ('Abram', 0.6762545108795166),
#  ('Hagar', 0.6682261824607849),
#  ('Pharaoh', 0.6611028909683228),
#  ('Laban', 0.6594597101211548),
#  ('Rebekah', 0.659412145614624),
#  ('queen', 0.6486087441444397),
#  ('Bethuel', 0.6453341245651245),
#  ('Ephron', 0.6399964094161987),
#  ('Padanaram', 0.6380250453948975),
#  ('Samaria', 0.6341228485107422),
#  ('damsel', 0.6341086626052856),
#  ('birthright', 0.633590817451477),
#  ('princes', 0.6271429061889648),
#  ('Hamor', 0.6266193985939026),
#  ('Bilhah', 0.6253798007965088),
#  ('David', 0.6253097057342529),
#  ('Zilpah', 0.6251536011695862),
#  ('Babylon', 0.6249426007270813),
#  ('ministered', 0.6197174191474915),
#  ('Canaan', 0.6172976493835449),
#  ('daughter', 0.6165421009063721),
#  ('Lot', 0.6160545945167542),
#  ('Joseph', 0.6148746609687805),
#  ('household', 0.6145324110984802)]

# %%
# impressive for such a small data set, without any cleaning, e.g., to lower case (covered next)

# %% [markdown]
# #### Reduce word vector dimensionality with t-SNE

# %%
model.wv.vocab
# Out:
# {'speak': <gensim.models.keyedvectors.Vocab at 0x1a24aae0f0>,
#  'significant': <gensim.models.keyedvectors.Vocab at 0x1a24aaeb70>,
#  'instruction': <gensim.models.keyedvectors.Vocab at 0x1a24aaeba8>,
#  'prints': <gensim.models.keyedvectors.Vocab at 0x1a24aae940>,
#  'bordered': <gensim.models.keyedvectors.Vocab at 0x1a24aae278>,
#  'purpose': <gensim.models.keyedvectors.Vocab at 0x10e9a49e8>,
#  'determin': <gensim.models.keyedvectors.Vocab at 0x1a24aae5c0>,
#  'subsequent': <gensim.models.keyedvectors.Vocab at 0x1a24aae2e8>,
#  '`': <gensim.models.keyedvectors.Vocab at 0x1a24aaefd0>,
#  'soaked': <gensim.models.keyedvectors.Vocab at 0x1a27dd9400>,
#  'frozen': <gensim.models.keyedvectors.Vocab at 0x1a27dd9f28>,
#  'polished': <gensim.models.keyedvectors.Vocab at 0x1a27dd98d0>,
#  'Chittim': <gensim.models.keyedvectors.Vocab at 0x1a27dd9390>,
#  'ability': <gensim.models.keyedvectors.Vocab at 0x1a27dd9080>,
#  'quire': <gensim.models.keyedvectors.Vocab at 0x1a27dd97b8>,
#  'November': <gensim.models.keyedvectors.Vocab at 0x10e9b2588>,
#  'Izhar': <gensim.models.keyedvectors.Vocab at 0x1a27dd9dd8>,
#  'fired': <gensim.models.keyedvectors.Vocab at 0x1a27dd9668>,
#  'quite': <gensim.models.keyedvectors.Vocab at 0x1a27dd96d8>,
#  'Russell': <gensim.models.keyedvectors.Vocab at 0x1a27dd9fd0>,
#  'Aloud': <gensim.models.keyedvectors.Vocab at 0x1a27dd9be0>,
#  'T': <gensim.models.keyedvectors.Vocab at 0x1a277e1668>,
#  'scoundrel': <gensim.models.keyedvectors.Vocab at 0x1a27dd9cc0>,
#  'exulting': <gensim.models.keyedvectors.Vocab at 0x1a27dd94e0>,
#  'truths': <gensim.models.keyedvectors.Vocab at 0x1a27dd9780>,
#  'sparrow': <gensim.models.keyedvectors.Vocab at 0x1a27dd9e10>,
#  'reel': <gensim.models.keyedvectors.Vocab at 0x1a27dd96a0>,
#  'eleventh': <gensim.models.keyedvectors.Vocab at 0x1a27dd9e48>,
#  'dukes': <gensim.models.keyedvectors.Vocab at 0x1a27dd9c88>,
#  'Rory': <gensim.models.keyedvectors.Vocab at 0x10e9b6e10>,
#  'Rechab': <gensim.models.keyedvectors.Vocab at 0x1a27af03c8>,
#  'keels': <gensim.models.keyedvectors.Vocab at 0x1a27dd9828>,
#  'turkey': <gensim.models.keyedvectors.Vocab at 0x1a27dd9d68>,
#  'adulteries': <gensim.models.keyedvectors.Vocab at 0x1a27dd9ef0>,
#  'cover': <gensim.models.keyedvectors.Vocab at 0x1a27dd9b70>,
#  'sofa': <gensim.models.keyedvectors.Vocab at 0x1a27dd9518>,
#  'Amasai': <gensim.models.keyedvectors.Vocab at 0x1a27dd9c50>,
#  'Piccola': <gensim.models.keyedvectors.Vocab at 0x1a27dd9278>,
#  'Pedaiah': <gensim.models.keyedvectors.Vocab at 0x1a27dd9240>,
#  'glaring': <gensim.models.keyedvectors.Vocab at 0x1a27dd90f0>,
#  'wooded': <gensim.models.keyedvectors.Vocab at 0x1a27dd9da0>,
#  'hasn': <gensim.models.keyedvectors.Vocab at 0x1a27dd9ba8>,
#  'brook': <gensim.models.keyedvectors.Vocab at 0x1a28d06a20>,
#  'Manoah': <gensim.models.keyedvectors.Vocab at 0x1a27dd9a20>,
#  'imperfection': <gensim.models.keyedvectors.Vocab at 0x1a27dd9710>,
#  'mankind': <gensim.models.keyedvectors.Vocab at 0x1a27dd91d0>,
#  'hauing': <gensim.models.keyedvectors.Vocab at 0x1a28d35630>,
#  'lighten': <gensim.models.keyedvectors.Vocab at 0x1a27dd9940>,
#  'relish': <gensim.models.keyedvectors.Vocab at 0x1a27dd9908>,
#  'flavor': <gensim.models.keyedvectors.Vocab at 0x1a28cb6ac8>,
#  'Immense': <gensim.models.keyedvectors.Vocab at 0x1a27dd92b0>,
#  'blade': <gensim.models.keyedvectors.Vocab at 0x1a27dd9470>,
#  'mule': <gensim.models.keyedvectors.Vocab at 0x1a27dd9748>,
#  'purport': <gensim.models.keyedvectors.Vocab at 0x1a27dd99e8>,
#  'Sinai': <gensim.models.keyedvectors.Vocab at 0x1a27dd9978>,
#  'harbour': <gensim.models.keyedvectors.Vocab at 0x1a28d356d8>,
#  'Hebron': <gensim.models.keyedvectors.Vocab at 0x1a27dd9d30>,
#  'latent': <gensim.models.keyedvectors.Vocab at 0x1a27dd9208>,
#  'Magna': <gensim.models.keyedvectors.Vocab at 0x1a27dd9a58>,
#  'guarding': <gensim.models.keyedvectors.Vocab at 0x1a27e85320>,
#  'ballad': <gensim.models.keyedvectors.Vocab at 0x1a27dd95f8>,
#  'roads': <gensim.models.keyedvectors.Vocab at 0x1a27dd9a90>,
#  'dexterous': <gensim.models.keyedvectors.Vocab at 0x1a27dd9550>,
#  'parched': <gensim.models.keyedvectors.Vocab at 0x1a27dd9eb8>,
#  'editor': <gensim.models.keyedvectors.Vocab at 0x1a27dd9b00>,
#  'Notwithstanding': <gensim.models.keyedvectors.Vocab at 0x1a24997390>,
#  'warmed': <gensim.models.keyedvectors.Vocab at 0x1a279624e0>,
#  'battles': <gensim.models.keyedvectors.Vocab at 0x1a279626a0>,
#  'doubted': <gensim.models.keyedvectors.Vocab at 0x10e9c8860>,
#  'Eshtaol': <gensim.models.keyedvectors.Vocab at 0x1a27962eb8>,
#  'likes': <gensim.models.keyedvectors.Vocab at 0x1a279622e8>,
#  '!': <gensim.models.keyedvectors.Vocab at 0x1a27962080>,
#  'tempered': <gensim.models.keyedvectors.Vocab at 0x1a27962be0>,
#  'rated': <gensim.models.keyedvectors.Vocab at 0x1a27962780>,
#  'meadow': <gensim.models.keyedvectors.Vocab at 0x1a279628d0>,
#  'pondering': <gensim.models.keyedvectors.Vocab at 0x1a27962a58>,
#  'brought': <gensim.models.keyedvectors.Vocab at 0x1a279623c8>,
#  'shortest': <gensim.models.keyedvectors.Vocab at 0x1a27962358>,
#  'prolonged': <gensim.models.keyedvectors.Vocab at 0x1a27962da0>,
#  'feelings': <gensim.models.keyedvectors.Vocab at 0x1a27e90f98>,
#  'Agagite': <gensim.models.keyedvectors.Vocab at 0x1a27e90278>,
#  'thread': <gensim.models.keyedvectors.Vocab at 0x1a27e90d30>,
#  'Menahem': <gensim.models.keyedvectors.Vocab at 0x1a27e90550>,
#  'Eat': <gensim.models.keyedvectors.Vocab at 0x1a27e90fd0>,
#  'balanced': <gensim.models.keyedvectors.Vocab at 0x1a27e90588>,
#  'ending': <gensim.models.keyedvectors.Vocab at 0x1a27e90978>,
#  'moss': <gensim.models.keyedvectors.Vocab at 0x1a27ed12e8>,
#  'whose': <gensim.models.keyedvectors.Vocab at 0x1a27e90908>,
#  'fanciful': <gensim.models.keyedvectors.Vocab at 0x1a279fbe10>,
#  'base': <gensim.models.keyedvectors.Vocab at 0x1a27e90630>,
#  'fortified': <gensim.models.keyedvectors.Vocab at 0x1a27e90ba8>,
#  'messenger': <gensim.models.keyedvectors.Vocab at 0x1a28d06be0>,
#  'accepting': <gensim.models.keyedvectors.Vocab at 0x1a27e90160>,
#  'faulty': <gensim.models.keyedvectors.Vocab at 0x1a27ed19e8>,
#  'dying': <gensim.models.keyedvectors.Vocab at 0x1a27e90080>,
#  'impaired': <gensim.models.keyedvectors.Vocab at 0x1a27e90828>,
#  'sunk': <gensim.models.keyedvectors.Vocab at 0x1a27e906a0>,
#  'despair': <gensim.models.keyedvectors.Vocab at 0x1a27e90b00>,
#  'future': <gensim.models.keyedvectors.Vocab at 0x1a27e90518>,
#  'reasoning': <gensim.models.keyedvectors.Vocab at 0x1a27d2a5f8>,
#  'hireling': <gensim.models.keyedvectors.Vocab at 0x1a27e90a58>,
#  'comely': <gensim.models.keyedvectors.Vocab at 0x1a27e90240>,
#  'pitty': <gensim.models.keyedvectors.Vocab at 0x1a28d06c88>,
#  'Phinehas': <gensim.models.keyedvectors.Vocab at 0x1a28d35828>,
#  'motor': <gensim.models.keyedvectors.Vocab at 0x1a27e907b8>,
#  'equivalent': <gensim.models.keyedvectors.Vocab at 0x1a27e90940>,
#  'reputation': <gensim.models.keyedvectors.Vocab at 0x1a28d06cc0>,
#  'gaze': <gensim.models.keyedvectors.Vocab at 0x1a27e90400>,
#  'uttering': <gensim.models.keyedvectors.Vocab at 0x1a27e853c8>,
#  'imprisoned': <gensim.models.keyedvectors.Vocab at 0x1a28e08c18>,
#  'Hartfield': <gensim.models.keyedvectors.Vocab at 0x1a28c8c828>,
#  'attack': <gensim.models.keyedvectors.Vocab at 0x1a27e90c50>,
#  'lobsters': <gensim.models.keyedvectors.Vocab at 0x1a27e90748>,
#  'males': <gensim.models.keyedvectors.Vocab at 0x1a27e909b0>,
#  'aching': <gensim.models.keyedvectors.Vocab at 0x1a27e902b0>,
#  'depth': <gensim.models.keyedvectors.Vocab at 0x1a27e90a90>,
#  'vacancy': <gensim.models.keyedvectors.Vocab at 0x1a28e042e8>,
#  'Mankind': <gensim.models.keyedvectors.Vocab at 0x1a27e90cc0>,
#  'drivers': <gensim.models.keyedvectors.Vocab at 0x1a27af09b0>,
#  'shady': <gensim.models.keyedvectors.Vocab at 0x1a27e90eb8>,
#  'couched': <gensim.models.keyedvectors.Vocab at 0x1a27e90470>,
#  'traditions': <gensim.models.keyedvectors.Vocab at 0x1a27e90128>,
#  'betook': <gensim.models.keyedvectors.Vocab at 0x1a27e90e80>,
#  'negligence': <gensim.models.keyedvectors.Vocab at 0x1a27e90f28>,
#  'variety': <gensim.models.keyedvectors.Vocab at 0x1a27e902e8>,
#  'attire': <gensim.models.keyedvectors.Vocab at 0x1a28c72320>,
#  'endued': <gensim.models.keyedvectors.Vocab at 0x1a27e909e8>,
#  'dynamite': <gensim.models.keyedvectors.Vocab at 0x1a27e90198>,
#  'trading': <gensim.models.keyedvectors.Vocab at 0x1a27e90438>,
#  'anarchy': <gensim.models.keyedvectors.Vocab at 0x1a27e90dd8>,
#  '://': <gensim.models.keyedvectors.Vocab at 0x1a27e906d8>,
#  'BURSAL': <gensim.models.keyedvectors.Vocab at 0x1a27e905f8>,
#  'breach': <gensim.models.keyedvectors.Vocab at 0x1a27e90710>,
#  'troop': <gensim.models.keyedvectors.Vocab at 0x1a28e166d8>,
#  'untempered': <gensim.models.keyedvectors.Vocab at 0x1a27e90b38>,
#  'likeliest': <gensim.models.keyedvectors.Vocab at 0x1a27e903c8>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x1a27e90ef0>,
#  'Shepherd': <gensim.models.keyedvectors.Vocab at 0x1a27e90320>,
#  'speakes': <gensim.models.keyedvectors.Vocab at 0x1a27e90898>,
#  'sturdily': <gensim.models.keyedvectors.Vocab at 0x1a27e28550>,
#  'trifling': <gensim.models.keyedvectors.Vocab at 0x1a27e90a20>,
#  'cross': <gensim.models.keyedvectors.Vocab at 0x1a27e900f0>,
#  'wonder': <gensim.models.keyedvectors.Vocab at 0x1a27e904a8>,
#  '27': <gensim.models.keyedvectors.Vocab at 0x1a27e90da0>,
#  'softening': <gensim.models.keyedvectors.Vocab at 0x1a27e90048>,
#  'weigh': <gensim.models.keyedvectors.Vocab at 0x1a27e90358>,
#  'use': <gensim.models.keyedvectors.Vocab at 0x1a277e1ba8>,
#  'whirlpool': <gensim.models.keyedvectors.Vocab at 0x1a277e1470>,
#  'fault': <gensim.models.keyedvectors.Vocab at 0x1a277e19e8>,
#  'Bar': <gensim.models.keyedvectors.Vocab at 0x1a277e1a20>,
#  'atheist': <gensim.models.keyedvectors.Vocab at 0x1a277e1d68>,
#  'confine': <gensim.models.keyedvectors.Vocab at 0x1a277e1080>,
#  'costume': <gensim.models.keyedvectors.Vocab at 0x1a277e1358>,
#  'foreign': <gensim.models.keyedvectors.Vocab at 0x1a28d06e10>,
#  'infants': <gensim.models.keyedvectors.Vocab at 0x1a28c2ab00>,
#  'shifting': <gensim.models.keyedvectors.Vocab at 0x1a277e1630>,
#  'working': <gensim.models.keyedvectors.Vocab at 0x1a28baa668>,
#  'shrunk': <gensim.models.keyedvectors.Vocab at 0x1a277e1d30>,
#  'chat': <gensim.models.keyedvectors.Vocab at 0x1a277e12b0>,
#  'spilled': <gensim.models.keyedvectors.Vocab at 0x1a277e1898>,
#  'Excuse': <gensim.models.keyedvectors.Vocab at 0x1a277e11d0>,
#  'begge': <gensim.models.keyedvectors.Vocab at 0x1a277e1f98>,
#  'forebodings': <gensim.models.keyedvectors.Vocab at 0x1a27dd9ac8>,
#  'patiently': <gensim.models.keyedvectors.Vocab at 0x1a277e1c88>,
#  'property': <gensim.models.keyedvectors.Vocab at 0x1a277e1c18>,
#  'Panado': <gensim.models.keyedvectors.Vocab at 0x1a277e1b38>,
#  'vagabond': <gensim.models.keyedvectors.Vocab at 0x1a27af0898>,
#  'preferring': <gensim.models.keyedvectors.Vocab at 0x1a28d35a90>,
#  'greeted': <gensim.models.keyedvectors.Vocab at 0x1a27af0668>,
#  'trophy': <gensim.models.keyedvectors.Vocab at 0x1a28d06ef0>,
#  'Danish': <gensim.models.keyedvectors.Vocab at 0x1a27af0b00>,
#  'lessen': <gensim.models.keyedvectors.Vocab at 0x1a278897b8>,
#  'supple': <gensim.models.keyedvectors.Vocab at 0x1a27af0400>,
#  'Now': <gensim.models.keyedvectors.Vocab at 0x1a2782ca58>,
#  'mixed': <gensim.models.keyedvectors.Vocab at 0x1a27af0470>,
#  'anyrate': <gensim.models.keyedvectors.Vocab at 0x1a27af0be0>,
#  'steed': <gensim.models.keyedvectors.Vocab at 0x1a27af0da0>,
#  'sustained': <gensim.models.keyedvectors.Vocab at 0x1a27af0630>,
#  'riding': <gensim.models.keyedvectors.Vocab at 0x1a27af0e80>,
#  'developed': <gensim.models.keyedvectors.Vocab at 0x1a27af05c0>,
#  'understand': <gensim.models.keyedvectors.Vocab at 0x1a24aa03c8>,
#  'landscape': <gensim.models.keyedvectors.Vocab at 0x1a27af0f60>,
#  'while': <gensim.models.keyedvectors.Vocab at 0x1a27af0dd8>,
#  'don': <gensim.models.keyedvectors.Vocab at 0x1a27af0d30>,
#  'gardening': <gensim.models.keyedvectors.Vocab at 0x1a28b91cf8>,
#  'cistern': <gensim.models.keyedvectors.Vocab at 0x1a27af0eb8>,
#  'toll': <gensim.models.keyedvectors.Vocab at 0x1a27af0c18>,
#  'pyramid': <gensim.models.keyedvectors.Vocab at 0x1a27af0128>,
#  'discover': <gensim.models.keyedvectors.Vocab at 0x1a27af0080>,
#  'opaque': <gensim.models.keyedvectors.Vocab at 0x1a27af02b0>,
#  'peerless': <gensim.models.keyedvectors.Vocab at 0x10e9972e8>,
#  'husbandmen': <gensim.models.keyedvectors.Vocab at 0x1a27af00f0>,
#  'thickness': <gensim.models.keyedvectors.Vocab at 0x1a27af0438>,
#  'chasing': <gensim.models.keyedvectors.Vocab at 0x1a27af06a0>,
#  'She': <gensim.models.keyedvectors.Vocab at 0x1a27af0710>,
#  'charger': <gensim.models.keyedvectors.Vocab at 0x1a27b6f860>,
#  'Lightfoot': <gensim.models.keyedvectors.Vocab at 0x1a27af05f8>,
#  'thick': <gensim.models.keyedvectors.Vocab at 0x1a27af0a58>,
#  'confirm': <gensim.models.keyedvectors.Vocab at 0x1a27af0e48>,
#  'Weymouth': <gensim.models.keyedvectors.Vocab at 0x1a27af0908>,
#  'gateway': <gensim.models.keyedvectors.Vocab at 0x1a27af0f98>,
#  'Dreyfus': <gensim.models.keyedvectors.Vocab at 0x1a27af06d8>,
#  'signs': <gensim.models.keyedvectors.Vocab at 0x1a27af0ef0>,
#  'triple': <gensim.models.keyedvectors.Vocab at 0x1a27af0940>,
#  'near': <gensim.models.keyedvectors.Vocab at 0x1a27af02e8>,
#  'vague': <gensim.models.keyedvectors.Vocab at 0x1a27af07b8>,
#  'preceded': <gensim.models.keyedvectors.Vocab at 0x1a27af0358>,
#  'subscribe': <gensim.models.keyedvectors.Vocab at 0x1a27af0e10>,
#  'saue': <gensim.models.keyedvectors.Vocab at 0x1a27af0748>,
#  'liues': <gensim.models.keyedvectors.Vocab at 0x1a27af0240>,
#  'proud': <gensim.models.keyedvectors.Vocab at 0x10e9d12b0>,
#  'Mexico': <gensim.models.keyedvectors.Vocab at 0x1a27827048>,
#  'diligence': <gensim.models.keyedvectors.Vocab at 0x1a28d0a160>,
#  'constrain': <gensim.models.keyedvectors.Vocab at 0x1a27827b70>,
#  'model': <gensim.models.keyedvectors.Vocab at 0x1a27827f28>,
#  'shapes': <gensim.models.keyedvectors.Vocab at 0x1a27827390>,
#  'Enemie': <gensim.models.keyedvectors.Vocab at 0x1a27827940>,
#  'marble': <gensim.models.keyedvectors.Vocab at 0x1a28d35cf8>,
#  'droop': <gensim.models.keyedvectors.Vocab at 0x1a27827a58>,
#  'Forms': <gensim.models.keyedvectors.Vocab at 0x1a27827550>,
#  'timed': <gensim.models.keyedvectors.Vocab at 0x1a278275f8>,
#  'ascended': <gensim.models.keyedvectors.Vocab at 0x1a278274e0>,
#  'lanterns': <gensim.models.keyedvectors.Vocab at 0x1a278278d0>,
#  'WELL': <gensim.models.keyedvectors.Vocab at 0x1a27827f60>,
#  'potency': <gensim.models.keyedvectors.Vocab at 0x1a27827358>,
#  'potatoes': <gensim.models.keyedvectors.Vocab at 0x1a27827208>,
#  'expert': <gensim.models.keyedvectors.Vocab at 0x1a278276d8>,
#  'thicket': <gensim.models.keyedvectors.Vocab at 0x1a27827438>,
#  'markets': <gensim.models.keyedvectors.Vocab at 0x1a278279e8>,
#  'services': <gensim.models.keyedvectors.Vocab at 0x1a28d0a278>,
#  'render': <gensim.models.keyedvectors.Vocab at 0x1a27e03128>,
#  'beach': <gensim.models.keyedvectors.Vocab at 0x1a27827d30>,
#  'daubed': <gensim.models.keyedvectors.Vocab at 0x1a278279b0>,
#  'benevolent': <gensim.models.keyedvectors.Vocab at 0x1a28baa9b0>,
#  'journeyed': <gensim.models.keyedvectors.Vocab at 0x1a27d29e80>,
#  'additional': <gensim.models.keyedvectors.Vocab at 0x1a27827400>,
#  '8': <gensim.models.keyedvectors.Vocab at 0x1a27827630>,
#  'fiend': <gensim.models.keyedvectors.Vocab at 0x1a27d67a58>,
#  'chanced': <gensim.models.keyedvectors.Vocab at 0x1a27af2978>,
#  'incidentally': <gensim.models.keyedvectors.Vocab at 0x1a28d0a2e8>,
#  'backed': <gensim.models.keyedvectors.Vocab at 0x1a27af2e10>,
#  'shreds': <gensim.models.keyedvectors.Vocab at 0x1a27af2b70>,
#  'weaker': <gensim.models.keyedvectors.Vocab at 0x1a27af29e8>,
#  'melons': <gensim.models.keyedvectors.Vocab at 0x1a27af2240>,
#  'ceasing': <gensim.models.keyedvectors.Vocab at 0x1a27af2278>,
#  'Sey': <gensim.models.keyedvectors.Vocab at 0x1a27af26a0>,
#  'chop': <gensim.models.keyedvectors.Vocab at 0x1a27af2a58>,
#  'compacted': <gensim.models.keyedvectors.Vocab at 0x1a27af2908>,
#  'Had': <gensim.models.keyedvectors.Vocab at 0x1a27af2a90>,
#  'Nights': <gensim.models.keyedvectors.Vocab at 0x1a27af2c50>,
#  'Ebedmelech': <gensim.models.keyedvectors.Vocab at 0x1a27af28d0>,
#  'Rachel': <gensim.models.keyedvectors.Vocab at 0x1a28d35eb8>,
#  'accomplices': <gensim.models.keyedvectors.Vocab at 0x1a27af26d8>,
#  'glanced': <gensim.models.keyedvectors.Vocab at 0x1a27af2320>,
#  'scarf': <gensim.models.keyedvectors.Vocab at 0x1a28bed978>,
#  'whichever': <gensim.models.keyedvectors.Vocab at 0x1a27af2fd0>,
#  'gull': <gensim.models.keyedvectors.Vocab at 0x1a28d0a390>,
#  'driver': <gensim.models.keyedvectors.Vocab at 0x1a27af2b00>,
#  'retreated': <gensim.models.keyedvectors.Vocab at 0x1a27af25f8>,
#  'Dewdrop': <gensim.models.keyedvectors.Vocab at 0x1a27af2048>,
#  'dwellers': <gensim.models.keyedvectors.Vocab at 0x1a28d35358>,
#  'repulsed': <gensim.models.keyedvectors.Vocab at 0x1a27af2898>,
#  'Everybody': <gensim.models.keyedvectors.Vocab at 0x1a27af2390>,
#  'Torches': <gensim.models.keyedvectors.Vocab at 0x1a27af2940>,
#  'threescore': <gensim.models.keyedvectors.Vocab at 0x1a27af2cc0>,
#  'pry': <gensim.models.keyedvectors.Vocab at 0x1a27af2e48>,
#  'hilarious': <gensim.models.keyedvectors.Vocab at 0x1a27af22b0>,
#  'primitive': <gensim.models.keyedvectors.Vocab at 0x1a27af21d0>,
#  'week': <gensim.models.keyedvectors.Vocab at 0x1a28e04828>,
#  'triumphed': <gensim.models.keyedvectors.Vocab at 0x1a27af20b8>,
#  'Cherubick': <gensim.models.keyedvectors.Vocab at 0x1a27af24e0>,
#  'footprint': <gensim.models.keyedvectors.Vocab at 0x1a27af2438>,
#  'from': <gensim.models.keyedvectors.Vocab at 0x1a27af2780>,
#  'balls': <gensim.models.keyedvectors.Vocab at 0x1a27af20f0>,
#  'speech': <gensim.models.keyedvectors.Vocab at 0x1a27af2208>,
#  'weave': <gensim.models.keyedvectors.Vocab at 0x1a27af2d68>,
#  'shrieking': <gensim.models.keyedvectors.Vocab at 0x1a27af2160>,
#  'lowering': <gensim.models.keyedvectors.Vocab at 0x1a27af2c18>,
#  'gunpowder': <gensim.models.keyedvectors.Vocab at 0x1a27af2ba8>,
#  'sacred': <gensim.models.keyedvectors.Vocab at 0x1a27af25c0>,
#  'doomed': <gensim.models.keyedvectors.Vocab at 0x1a27af2710>,
#  'mortals': <gensim.models.keyedvectors.Vocab at 0x1a27af2da0>,
#  'whist': <gensim.models.keyedvectors.Vocab at 0x1a27af2630>,
#  'prodigious': <gensim.models.keyedvectors.Vocab at 0x1a27e03ba8>,
#  'branching': <gensim.models.keyedvectors.Vocab at 0x10e9b2860>,
#  'haughty': <gensim.models.keyedvectors.Vocab at 0x1a27e03d68>,
#  'Paradise': <gensim.models.keyedvectors.Vocab at 0x1a27e030f0>,
#  'Blown': <gensim.models.keyedvectors.Vocab at 0x1a27e037f0>,
#  'guided': <gensim.models.keyedvectors.Vocab at 0x1a27e03c88>,
#  'Bethuel': <gensim.models.keyedvectors.Vocab at 0x1a28d470f0>,
#  'extending': <gensim.models.keyedvectors.Vocab at 0x1a28d35be0>,
#  'Arm': <gensim.models.keyedvectors.Vocab at 0x1a27f22940>,
#  'tending': <gensim.models.keyedvectors.Vocab at 0x1a27e03f60>,
#  'chalk': <gensim.models.keyedvectors.Vocab at 0x1a27e03080>,
#  'arsenal': <gensim.models.keyedvectors.Vocab at 0x10e9aedd8>,
#  'Country': <gensim.models.keyedvectors.Vocab at 0x1a27e03470>,
#  'relating': <gensim.models.keyedvectors.Vocab at 0x1a27e03b70>,
#  'privileges': <gensim.models.keyedvectors.Vocab at 0x1a27e03390>,
#  'THEY': <gensim.models.keyedvectors.Vocab at 0x1a27e03f28>,
#  'Dormouse': <gensim.models.keyedvectors.Vocab at 0x1a27e03048>,
#  'guess': <gensim.models.keyedvectors.Vocab at 0x1a27e039b0>,
#  'repress': <gensim.models.keyedvectors.Vocab at 0x1a27e034a8>,
#  'caul': <gensim.models.keyedvectors.Vocab at 0x1a27e03400>,
#  'Tobiah': <gensim.models.keyedvectors.Vocab at 0x1a27eb66d8>,
#  'literal': <gensim.models.keyedvectors.Vocab at 0x1a27e03cc0>,
#  'design': <gensim.models.keyedvectors.Vocab at 0x1a27e03e10>,
#  'Dead': <gensim.models.keyedvectors.Vocab at 0x1a27e03828>,
#  'motto': <gensim.models.keyedvectors.Vocab at 0x10e9bf630>,
#  'partial': <gensim.models.keyedvectors.Vocab at 0x1a27e036a0>,
#  'join': <gensim.models.keyedvectors.Vocab at 0x1a27e03b00>,
#  'dealer': <gensim.models.keyedvectors.Vocab at 0x1a27e03dd8>,
#  'distributed': <gensim.models.keyedvectors.Vocab at 0x1a27e03710>,
#  'tenderly': <gensim.models.keyedvectors.Vocab at 0x1a27e03208>,
#  'loom': <gensim.models.keyedvectors.Vocab at 0x1a27e03978>,
#  'wagons': <gensim.models.keyedvectors.Vocab at 0x1a28d0a668>,
#  'Thel': <gensim.models.keyedvectors.Vocab at 0x1a27e036d8>,
#  'lads': <gensim.models.keyedvectors.Vocab at 0x1a27e03320>,
#  'woolly': <gensim.models.keyedvectors.Vocab at 0x1a27e032b0>,
#  'Maidens': <gensim.models.keyedvectors.Vocab at 0x1a27e032e8>,
#  'Christmas': <gensim.models.keyedvectors.Vocab at 0x1a27e03d30>,
#  'Nantucketer': <gensim.models.keyedvectors.Vocab at 0x1a27d73748>,
#  'pitchpoling': <gensim.models.keyedvectors.Vocab at 0x1a27e03eb8>,
#  'warred': <gensim.models.keyedvectors.Vocab at 0x1a27e03c50>,
#  'Action': <gensim.models.keyedvectors.Vocab at 0x1a27e03e80>,
#  'Hin': <gensim.models.keyedvectors.Vocab at 0x1a27e03780>,
#  'purge': <gensim.models.keyedvectors.Vocab at 0x1a27e03748>,
#  'biscuits': <gensim.models.keyedvectors.Vocab at 0x1a27e03240>,
#  'fried': <gensim.models.keyedvectors.Vocab at 0x1a27e03198>,
#  'reluctance': <gensim.models.keyedvectors.Vocab at 0x1a27e81e80>,
#  'signifies': <gensim.models.keyedvectors.Vocab at 0x1a27e03a90>,
#  'committeth': <gensim.models.keyedvectors.Vocab at 0x1a27e03160>,
#  'imitated': <gensim.models.keyedvectors.Vocab at 0x1a27e03898>,
#  'euen': <gensim.models.keyedvectors.Vocab at 0x1a27e03588>,
#  'insomuch': <gensim.models.keyedvectors.Vocab at 0x1a27e035c0>,
#  'crab': <gensim.models.keyedvectors.Vocab at 0x1a27e03860>,
#  'acquire': <gensim.models.keyedvectors.Vocab at 0x1a27e038d0>,
#  'whether': <gensim.models.keyedvectors.Vocab at 0x1a27e03358>,
#  'Rose': <gensim.models.keyedvectors.Vocab at 0x1a27e03e48>,
#  'Offence': <gensim.models.keyedvectors.Vocab at 0x1a28c9d2b0>,
#  'harsh': <gensim.models.keyedvectors.Vocab at 0x1a27e031d0>,
#  'Rehum': <gensim.models.keyedvectors.Vocab at 0x1a27e03a20>,
#  'eggs': <gensim.models.keyedvectors.Vocab at 0x1a27e03438>,
#  'inexplicable': <gensim.models.keyedvectors.Vocab at 0x1a2782b208>,
#  'bay': <gensim.models.keyedvectors.Vocab at 0x1a2782b470>,
#  'strongest': <gensim.models.keyedvectors.Vocab at 0x1a28d47438>,
#  'cowardly': <gensim.models.keyedvectors.Vocab at 0x1a2782b2e8>,
#  'harshly': <gensim.models.keyedvectors.Vocab at 0x1a2782bc88>,
#  'fragrance': <gensim.models.keyedvectors.Vocab at 0x1a2782bc50>,
#  'Wimpey': <gensim.models.keyedvectors.Vocab at 0x1a2782b198>,
#  'Hivites': <gensim.models.keyedvectors.Vocab at 0x1a2782b710>,
#  'own': <gensim.models.keyedvectors.Vocab at 0x1a2782b940>,
#  'regrets': <gensim.models.keyedvectors.Vocab at 0x1a27dc3e10>,
#  'argued': <gensim.models.keyedvectors.Vocab at 0x1a28d0a860>,
#  'Sun': <gensim.models.keyedvectors.Vocab at 0x1a27dc39e8>,
#  'affront': <gensim.models.keyedvectors.Vocab at 0x1a2782b128>,
#  'affectation': <gensim.models.keyedvectors.Vocab at 0x1a28ba4550>,
#  'exploded': <gensim.models.keyedvectors.Vocab at 0x1a2782bba8>,
#  'embraced': <gensim.models.keyedvectors.Vocab at 0x1a2782bb00>,
#  'collector': <gensim.models.keyedvectors.Vocab at 0x1a2782b9b0>,
#  'Daughter': <gensim.models.keyedvectors.Vocab at 0x1a2782b588>,
#  'trimmed': <gensim.models.keyedvectors.Vocab at 0x1a2782b6d8>,
#  'imaginative': <gensim.models.keyedvectors.Vocab at 0x1a28c49c18>,
#  'bias': <gensim.models.keyedvectors.Vocab at 0x1a2782b978>,
#  'Follow': <gensim.models.keyedvectors.Vocab at 0x1a28baafd0>,
#  'impelled': <gensim.models.keyedvectors.Vocab at 0x1a2782b518>,
#  'Goliath': <gensim.models.keyedvectors.Vocab at 0x1a2782b780>,
#  'commissioned': <gensim.models.keyedvectors.Vocab at 0x1a2782bbe0>,
#  'necklace': <gensim.models.keyedvectors.Vocab at 0x1a24a6c470>,
#  'badgers': <gensim.models.keyedvectors.Vocab at 0x1a27d52320>,
#  'cruet': <gensim.models.keyedvectors.Vocab at 0x1a24a6c438>,
#  'improvements': <gensim.models.keyedvectors.Vocab at 0x1a27f48828>,
#  'emerods': <gensim.models.keyedvectors.Vocab at 0x1a27f48908>,
#  'Mean': <gensim.models.keyedvectors.Vocab at 0x1a27f48550>,
#  'scraps': <gensim.models.keyedvectors.Vocab at 0x1a27f48748>,
#  'crowning': <gensim.models.keyedvectors.Vocab at 0x1a27d52710>,
#  'happily': <gensim.models.keyedvectors.Vocab at 0x1a27a61978>,
#  'unheeded': <gensim.models.keyedvectors.Vocab at 0x1a27a61e80>,
#  'forbearance': <gensim.models.keyedvectors.Vocab at 0x1a27a61588>,
#  'adequately': <gensim.models.keyedvectors.Vocab at 0x1a27a61c50>,
#  'apron': <gensim.models.keyedvectors.Vocab at 0x1a27a61b38>,
#  'perils': <gensim.models.keyedvectors.Vocab at 0x1a28ba7048>,
#  'Oft': <gensim.models.keyedvectors.Vocab at 0x1a27a61860>,
#  'eels': <gensim.models.keyedvectors.Vocab at 0x10e9d5ba8>,
#  'thickest': <gensim.models.keyedvectors.Vocab at 0x1a27a61940>,
#  'prythee': <gensim.models.keyedvectors.Vocab at 0x1a27a61320>,
#  'lawsuit': <gensim.models.keyedvectors.Vocab at 0x1a27a61d30>,
#  'Delilah': <gensim.models.keyedvectors.Vocab at 0x1a27a61d68>,
#  'guidance': <gensim.models.keyedvectors.Vocab at 0x10e9d9198>,
#  'stick': <gensim.models.keyedvectors.Vocab at 0x1a27a61e10>,
#  'suffereth': <gensim.models.keyedvectors.Vocab at 0x1a27a61b00>,
#  'scarcely': <gensim.models.keyedvectors.Vocab at 0x1a27a61240>,
#  'overjoyed': <gensim.models.keyedvectors.Vocab at 0x1a27a61b70>,
#  'Feare': <gensim.models.keyedvectors.Vocab at 0x1a27d73ef0>,
#  'plotting': <gensim.models.keyedvectors.Vocab at 0x1a27a61cf8>,
#  'brimming': <gensim.models.keyedvectors.Vocab at 0x1a27a61278>,
#  ',)': <gensim.models.keyedvectors.Vocab at 0x1a27a61908>,
#  'blooded': <gensim.models.keyedvectors.Vocab at 0x1a27a614a8>,
#  'HOW': <gensim.models.keyedvectors.Vocab at 0x1a27a61208>,
#  'trades': <gensim.models.keyedvectors.Vocab at 0x1a27a61550>,
#  'Loose': <gensim.models.keyedvectors.Vocab at 0x1a27a61080>,
#  'devoting': <gensim.models.keyedvectors.Vocab at 0x1a27a616a0>,
#  'calves': <gensim.models.keyedvectors.Vocab at 0x1a27a61ba8>,
#  'amaze': <gensim.models.keyedvectors.Vocab at 0x1a28c08b38>,
#  'perverted': <gensim.models.keyedvectors.Vocab at 0x1a27a61c88>,
#  'stead': <gensim.models.keyedvectors.Vocab at 0x1a27a618d0>,
#  'racing': <gensim.models.keyedvectors.Vocab at 0x1a27a61da0>,
#  'Rebekah': <gensim.models.keyedvectors.Vocab at 0x1a27a612b0>,
#  'watches': <gensim.models.keyedvectors.Vocab at 0x1a28ba7198>,
#  'Jeush': <gensim.models.keyedvectors.Vocab at 0x1a27a61f98>,
#  'perseverance': <gensim.models.keyedvectors.Vocab at 0x1a27a61c18>,
#  'fearfully': <gensim.models.keyedvectors.Vocab at 0x1a28d47630>,
#  'shipwrecked': <gensim.models.keyedvectors.Vocab at 0x1a27a61128>,
#  'Jazer': <gensim.models.keyedvectors.Vocab at 0x1a27a61438>,
#  'wandereth': <gensim.models.keyedvectors.Vocab at 0x1a27a61be0>,
#  'unaccountably': <gensim.models.keyedvectors.Vocab at 0x1a27eb6f60>,
#  'puff': <gensim.models.keyedvectors.Vocab at 0x1a27eb6128>,
#  'hawk': <gensim.models.keyedvectors.Vocab at 0x1a28b61470>,
#  'Terrors': <gensim.models.keyedvectors.Vocab at 0x1a27eb6e10>,
#  'detain': <gensim.models.keyedvectors.Vocab at 0x1a27eb6278>,
#  'thus': <gensim.models.keyedvectors.Vocab at 0x1a28ba7208>,
#  'succeed': <gensim.models.keyedvectors.Vocab at 0x1a27eb6cc0>,
#  'Jehohanan': <gensim.models.keyedvectors.Vocab at 0x1a27eb66a0>,
#  'Abijam': <gensim.models.keyedvectors.Vocab at 0x1a27eb6358>,
#  'discovering': <gensim.models.keyedvectors.Vocab at 0x1a27eb6860>,
#  'supposition': <gensim.models.keyedvectors.Vocab at 0x1a27eb6cf8>,
#  'deere': <gensim.models.keyedvectors.Vocab at 0x1a27eb6c50>,
#  'merited': <gensim.models.keyedvectors.Vocab at 0x1a27eb6a58>,
#  'Send': <gensim.models.keyedvectors.Vocab at 0x1a27eb6550>,
#  'banks': <gensim.models.keyedvectors.Vocab at 0x10e9d5908>,
#  'tremble': <gensim.models.keyedvectors.Vocab at 0x1a27eb6be0>,
#  'subtle': <gensim.models.keyedvectors.Vocab at 0x1a27eb6e48>,
#  'cruell': <gensim.models.keyedvectors.Vocab at 0x1a27eb6ba8>,
#  'Wine': <gensim.models.keyedvectors.Vocab at 0x1a27eb6630>,
#  'knewest': <gensim.models.keyedvectors.Vocab at 0x1a27eb6828>,
#  'scriptures': <gensim.models.keyedvectors.Vocab at 0x1a27eb6ef0>,
#  'fraught': <gensim.models.keyedvectors.Vocab at 0x1a27eb6fd0>,
#  'diseas': <gensim.models.keyedvectors.Vocab at 0x1a28d47780>,
#  'quarrelled': <gensim.models.keyedvectors.Vocab at 0x1a27eb6048>,
#  'blend': <gensim.models.keyedvectors.Vocab at 0x1a27eb6240>,
#  'repaid': <gensim.models.keyedvectors.Vocab at 0x1a27d73780>,
#  'wind': <gensim.models.keyedvectors.Vocab at 0x1a27eb6940>,
#  'fleecy': <gensim.models.keyedvectors.Vocab at 0x1a27eb6d30>,
#  'cant': <gensim.models.keyedvectors.Vocab at 0x1a27eb69e8>,
#  'beares': <gensim.models.keyedvectors.Vocab at 0x1a28d477f0>,
#  'applause': <gensim.models.keyedvectors.Vocab at 0x1a27eb6438>,
#  'whisper': <gensim.models.keyedvectors.Vocab at 0x1a27eb6470>,
#  'arriving': <gensim.models.keyedvectors.Vocab at 0x1a28c5f748>,
#  'stoned': <gensim.models.keyedvectors.Vocab at 0x1a27eb6dd8>,
#  'Lye': <gensim.models.keyedvectors.Vocab at 0x1a27eb6e80>,
#  '".': <gensim.models.keyedvectors.Vocab at 0x1a27eb6320>,
#  'planning': <gensim.models.keyedvectors.Vocab at 0x1a27eb6a20>,
#  'Governor': <gensim.models.keyedvectors.Vocab at 0x1a27eb6b38>,
#  'foreigners': <gensim.models.keyedvectors.Vocab at 0x1a27eb6c18>,
#  'preluding': <gensim.models.keyedvectors.Vocab at 0x1a27eb6588>,
#  'saddle': <gensim.models.keyedvectors.Vocab at 0x1a27eb6c88>,
#  'Canst': <gensim.models.keyedvectors.Vocab at 0x1a27eb6518>,
#  'commandeth': <gensim.models.keyedvectors.Vocab at 0x1a28c00278>,
#  'efficient': <gensim.models.keyedvectors.Vocab at 0x1a27eb6898>,
#  'venturing': <gensim.models.keyedvectors.Vocab at 0x1a28e00470>,
#  'Marcus': <gensim.models.keyedvectors.Vocab at 0x1a27eb65c0>,
#  'cheerless': <gensim.models.keyedvectors.Vocab at 0x1a27eb6da0>,
#  'amuse': <gensim.models.keyedvectors.Vocab at 0x1a27eb69b0>,
#  '105': <gensim.models.keyedvectors.Vocab at 0x1a28c7a1d0>,
#  'almighty': <gensim.models.keyedvectors.Vocab at 0x1a27eb6160>,
#  'Cowper': <gensim.models.keyedvectors.Vocab at 0x1a27eb6780>,
#  'angrily': <gensim.models.keyedvectors.Vocab at 0x1a27eb6710>,
#  'threshing': <gensim.models.keyedvectors.Vocab at 0x1a27eb67f0>,
#  'bewildering': <gensim.models.keyedvectors.Vocab at 0x1a27eb6748>,
#  'Deuteronomy': <gensim.models.keyedvectors.Vocab at 0x10e997710>,
#  'hovel': <gensim.models.keyedvectors.Vocab at 0x1a27eb65f8>,
#  'Supper': <gensim.models.keyedvectors.Vocab at 0x1a28ba7390>,
#  'faire': <gensim.models.keyedvectors.Vocab at 0x1a27eb64e0>,
#  'prompt': <gensim.models.keyedvectors.Vocab at 0x1a27eb6a90>,
#  'predictions': <gensim.models.keyedvectors.Vocab at 0x1a27d73b00>,
#  'Chip': <gensim.models.keyedvectors.Vocab at 0x1a279cf080>,
#  'promotion': <gensim.models.keyedvectors.Vocab at 0x1a279cf1d0>,
#  'Mabel': <gensim.models.keyedvectors.Vocab at 0x1a279cf780>,
#  'candid': <gensim.models.keyedvectors.Vocab at 0x1a279cf630>,
#  'recall': <gensim.models.keyedvectors.Vocab at 0x1a279cf2e8>,
#  'defeat': <gensim.models.keyedvectors.Vocab at 0x1a279cf198>,
#  'bedroom': <gensim.models.keyedvectors.Vocab at 0x1a279cf278>,
#  'capture': <gensim.models.keyedvectors.Vocab at 0x1a279cfa58>,
#  'period': <gensim.models.keyedvectors.Vocab at 0x1a279cf6a0>,
#  'selling': <gensim.models.keyedvectors.Vocab at 0x1a279cf208>,
#  'Abinadab': <gensim.models.keyedvectors.Vocab at 0x1a279cf9b0>,
#  'drinking': <gensim.models.keyedvectors.Vocab at 0x1a279cf160>,
#  'reports': <gensim.models.keyedvectors.Vocab at 0x1a279cf9e8>,
#  'promenade': <gensim.models.keyedvectors.Vocab at 0x1a279cf550>,
#  'wonted': <gensim.models.keyedvectors.Vocab at 0x1a279cf390>,
#  'fatality': <gensim.models.keyedvectors.Vocab at 0x1a28c7e2b0>,
#  'superfluous': <gensim.models.keyedvectors.Vocab at 0x1a279cf4a8>,
#  'tuft': <gensim.models.keyedvectors.Vocab at 0x1a279cfa20>,
#  'St': <gensim.models.keyedvectors.Vocab at 0x1a279cfc88>,
#  'professional': <gensim.models.keyedvectors.Vocab at 0x1a279cfbe0>,
#  'Dash': <gensim.models.keyedvectors.Vocab at 0x1a28de5eb8>,
#  'mutiny': <gensim.models.keyedvectors.Vocab at 0x1a27f2bf28>,
#  'hook': <gensim.models.keyedvectors.Vocab at 0x1a279cf128>,
#  'partially': <gensim.models.keyedvectors.Vocab at 0x1a279cf7f0>,
#  ";'": <gensim.models.keyedvectors.Vocab at 0x1a28c68e48>,
#  'beings': <gensim.models.keyedvectors.Vocab at 0x1a279cf3c8>,
#  'Bartholomew': <gensim.models.keyedvectors.Vocab at 0x1a279cf5c0>,
#  'caves': <gensim.models.keyedvectors.Vocab at 0x1a279cfc50>,
#  'apparently': <gensim.models.keyedvectors.Vocab at 0x1a279cf588>,
#  'removing': <gensim.models.keyedvectors.Vocab at 0x1a28e08cc0>,
#  'themselues': <gensim.models.keyedvectors.Vocab at 0x1a27ed1be0>,
#  'climbed': <gensim.models.keyedvectors.Vocab at 0x1a27e90d68>,
#  'comer': <gensim.models.keyedvectors.Vocab at 0x1a27ed1b38>,
#  'doleful': <gensim.models.keyedvectors.Vocab at 0x1a27ed1278>,
#  'Fiend': <gensim.models.keyedvectors.Vocab at 0x1a27ed16a0>,
#  'pretensions': <gensim.models.keyedvectors.Vocab at 0x1a27ed1978>,
#  'slid': <gensim.models.keyedvectors.Vocab at 0x1a27ed1128>,
#  'fishy': <gensim.models.keyedvectors.Vocab at 0x10e9b24e0>,
#  'crowding': <gensim.models.keyedvectors.Vocab at 0x1a27ed18d0>,
#  'meane': <gensim.models.keyedvectors.Vocab at 0x1a27ed14e0>,
#  'tongues': <gensim.models.keyedvectors.Vocab at 0x1a27ed1588>,
#  'poor': <gensim.models.keyedvectors.Vocab at 0x1a28d0ada0>,
#  'wasted': <gensim.models.keyedvectors.Vocab at 0x1a27ed1208>,
#  'Tirzah': <gensim.models.keyedvectors.Vocab at 0x1a27ed1b70>,
#  'peeping': <gensim.models.keyedvectors.Vocab at 0x1a27ed12b0>,
#  'ascending': <gensim.models.keyedvectors.Vocab at 0x1a27ed1710>,
#  'Write': <gensim.models.keyedvectors.Vocab at 0x1a27ed1ef0>,
#  'dumplings': <gensim.models.keyedvectors.Vocab at 0x10e997eb8>,
#  'save': <gensim.models.keyedvectors.Vocab at 0x1a28cfcc50>,
#  'pennants': <gensim.models.keyedvectors.Vocab at 0x1a27ed1b00>,
#  'growled': <gensim.models.keyedvectors.Vocab at 0x1a27ed16d8>,
#  'questioned': <gensim.models.keyedvectors.Vocab at 0x1a27ed1860>,
#  'rains': <gensim.models.keyedvectors.Vocab at 0x1a27ead1d0>,
#  'boughs': <gensim.models.keyedvectors.Vocab at 0x1a27ed1400>,
#  'needless': <gensim.models.keyedvectors.Vocab at 0x1a27ed17b8>,
#  'rising': <gensim.models.keyedvectors.Vocab at 0x1a27ed11d0>,
#  'wherefore': <gensim.models.keyedvectors.Vocab at 0x1a27ed1eb8>,
#  'wander': <gensim.models.keyedvectors.Vocab at 0x1a27ed1a20>,
#  'separated': <gensim.models.keyedvectors.Vocab at 0x1a27ed1390>,
#  'smelling': <gensim.models.keyedvectors.Vocab at 0x1a27ed1320>,
#  'inference': <gensim.models.keyedvectors.Vocab at 0x1a27ed1cc0>,
#  'tube': <gensim.models.keyedvectors.Vocab at 0x1a27ed1358>,
#  'travelling': <gensim.models.keyedvectors.Vocab at 0x1a28d0af98>,
#  'slaying': <gensim.models.keyedvectors.Vocab at 0x1a27ed1630>,
#  'halfpenny': <gensim.models.keyedvectors.Vocab at 0x1a27ed1550>,
#  'Pharez': <gensim.models.keyedvectors.Vocab at 0x1a27ed1048>,
#  'barred': <gensim.models.keyedvectors.Vocab at 0x1a27ed10f0>,
#  'job': <gensim.models.keyedvectors.Vocab at 0x1a27ed1a58>,
#  'consider': <gensim.models.keyedvectors.Vocab at 0x1a27af3a20>,
#  'naughty': <gensim.models.keyedvectors.Vocab at 0x1a27ed1f28>,
#  'glassy': <gensim.models.keyedvectors.Vocab at 0x1a27ed1240>,
#  'Herodias': <gensim.models.keyedvectors.Vocab at 0x1a27ed14a8>,
#  'chaises': <gensim.models.keyedvectors.Vocab at 0x1a27e90ac8>,
#  'imitation': <gensim.models.keyedvectors.Vocab at 0x1a27ed1748>,
#  'fruitful': <gensim.models.keyedvectors.Vocab at 0x1a27ed1908>,
#  'distracted': <gensim.models.keyedvectors.Vocab at 0x1a28d47a90>,
#  'fasted': <gensim.models.keyedvectors.Vocab at 0x1a27ed1e10>,
#  'hurricane': <gensim.models.keyedvectors.Vocab at 0x1a27ed1198>,
#  'this': <gensim.models.keyedvectors.Vocab at 0x1a27ed1e48>,
#  'merge': <gensim.models.keyedvectors.Vocab at 0x1a27ed1438>,
#  'noticed': <gensim.models.keyedvectors.Vocab at 0x1a27ed1cf8>,
#  'rank': <gensim.models.keyedvectors.Vocab at 0x1a27ed1ba8>,
#  'deathless': <gensim.models.keyedvectors.Vocab at 0x1a27ed1668>,
#  'earth': <gensim.models.keyedvectors.Vocab at 0x1a27ed1828>,
#  'landed': <gensim.models.keyedvectors.Vocab at 0x1a27ed1898>,
#  'sevenfold': <gensim.models.keyedvectors.Vocab at 0x1a27e037b8>,
#  'divinely': <gensim.models.keyedvectors.Vocab at 0x1a27ed10b8>,
#  'Pilate': <gensim.models.keyedvectors.Vocab at 0x1a28c72588>,
#  'dire': <gensim.models.keyedvectors.Vocab at 0x1a27ed1940>,
#  'priest': <gensim.models.keyedvectors.Vocab at 0x1a27d2a898>,
#  'lookest': <gensim.models.keyedvectors.Vocab at 0x1a27d2a278>,
#  'Learn': <gensim.models.keyedvectors.Vocab at 0x1a27d2a1d0>,
#  'Ahira': <gensim.models.keyedvectors.Vocab at 0x1a27d2a3c8>,
#  'Patagonian': <gensim.models.keyedvectors.Vocab at 0x1a27d2a710>,
#  'shrouds': <gensim.models.keyedvectors.Vocab at 0x1a27d2a240>,
#  'immigrants': <gensim.models.keyedvectors.Vocab at 0x1a27d2a8d0>,
#  'Bildad': <gensim.models.keyedvectors.Vocab at 0x1a27d2a0f0>,
#  'stuck': <gensim.models.keyedvectors.Vocab at 0x1a27d2a7f0>,
#  'Dick': <gensim.models.keyedvectors.Vocab at 0x1a27d2acf8>,
#  'disgusting': <gensim.models.keyedvectors.Vocab at 0x1a27d2abe0>,
#  'Speaking': <gensim.models.keyedvectors.Vocab at 0x1a27d2a320>,
#  'reverberations': <gensim.models.keyedvectors.Vocab at 0x1a27d2a6a0>,
#  'door': <gensim.models.keyedvectors.Vocab at 0x1a27d2a978>,
#  'Forget': <gensim.models.keyedvectors.Vocab at 0x1a27d2a518>,
#  'supplied': <gensim.models.keyedvectors.Vocab at 0x1a27d2add8>,
#  'plausible': <gensim.models.keyedvectors.Vocab at 0x1a27d2af28>,
#  'But': <gensim.models.keyedvectors.Vocab at 0x1a27e710b8>,
#  'plain': <gensim.models.keyedvectors.Vocab at 0x1a27d2a588>,
#  'Chamberlain': <gensim.models.keyedvectors.Vocab at 0x10e9aec88>,
#  'inflamed': <gensim.models.keyedvectors.Vocab at 0x1a27d2a748>,
#  'practised': <gensim.models.keyedvectors.Vocab at 0x1a27d2aba8>,
#  'materially': <gensim.models.keyedvectors.Vocab at 0x1a27d2a198>,
#  'decrees': <gensim.models.keyedvectors.Vocab at 0x1a27d2ae48>,
#  'basket': <gensim.models.keyedvectors.Vocab at 0x1a28d0f198>,
#  'raging': <gensim.models.keyedvectors.Vocab at 0x1a27d2ab70>,
#  'selues': <gensim.models.keyedvectors.Vocab at 0x1a27d2a828>,
#  'style': <gensim.models.keyedvectors.Vocab at 0x1a27d2af60>,
#  'fears': <gensim.models.keyedvectors.Vocab at 0x1a27d2a160>,
#  'WITH': <gensim.models.keyedvectors.Vocab at 0x1a27d2a2b0>,
#  'staggering': <gensim.models.keyedvectors.Vocab at 0x1a27d2a0b8>,
#  'Noah': <gensim.models.keyedvectors.Vocab at 0x1a27d2a208>,
#  'Joy': <gensim.models.keyedvectors.Vocab at 0x1a27d2aa58>,
#  'majesty': <gensim.models.keyedvectors.Vocab at 0x1a27d2a470>,
#  'ore': <gensim.models.keyedvectors.Vocab at 0x1a27d2ab00>,
#  'Bela': <gensim.models.keyedvectors.Vocab at 0x1a27d2a4e0>,
#  'loss': <gensim.models.keyedvectors.Vocab at 0x1a28d0f240>,
#  'Brook': <gensim.models.keyedvectors.Vocab at 0x1a27d2a6d8>,
#  'rooted': <gensim.models.keyedvectors.Vocab at 0x10e98ed68>,
#  'physiology': <gensim.models.keyedvectors.Vocab at 0x1a27d2aef0>,
#  'nobility': <gensim.models.keyedvectors.Vocab at 0x1a27d2ad68>,
#  'Looks': <gensim.models.keyedvectors.Vocab at 0x1a27b599b0>,
#  'scaly': <gensim.models.keyedvectors.Vocab at 0x1a27d2a7b8>,
#  'disobedience': <gensim.models.keyedvectors.Vocab at 0x1a27d2a438>,
#  'ephah': <gensim.models.keyedvectors.Vocab at 0x1a27d2afd0>,
#  'murmur': <gensim.models.keyedvectors.Vocab at 0x1a27d2ae10>,
#  'nation': <gensim.models.keyedvectors.Vocab at 0x1a27d2a908>,
#  'stripes': <gensim.models.keyedvectors.Vocab at 0x1a27d2aeb8>,
#  'Cumberland': <gensim.models.keyedvectors.Vocab at 0x1a27d67d30>,
#  'bestial': <gensim.models.keyedvectors.Vocab at 0x1a27d67160>,
#  'risking': <gensim.models.keyedvectors.Vocab at 0x1a27d672e8>,
#  'tide': <gensim.models.keyedvectors.Vocab at 0x1a27d678d0>,
#  'surprized': <gensim.models.keyedvectors.Vocab at 0x1a27d67240>,
#  'projecting': <gensim.models.keyedvectors.Vocab at 0x1a27d67d68>,
#  'leader': <gensim.models.keyedvectors.Vocab at 0x1a27d67358>,
#  'republican': <gensim.models.keyedvectors.Vocab at 0x1a27d67ef0>,
#  'edifice': <gensim.models.keyedvectors.Vocab at 0x1a27d679b0>,
#  'snuff': <gensim.models.keyedvectors.Vocab at 0x1a27d67e10>,
#  'marking': <gensim.models.keyedvectors.Vocab at 0x1a27d670b8>,
#  'cooper': <gensim.models.keyedvectors.Vocab at 0x1a28b62a58>,
#  'ex': <gensim.models.keyedvectors.Vocab at 0x1a27d67f60>,
#  'shuffling': <gensim.models.keyedvectors.Vocab at 0x1a27d67b70>,
#  'choked': <gensim.models.keyedvectors.Vocab at 0x1a27d67cf8>,
#  'deprived': <gensim.models.keyedvectors.Vocab at 0x1a27d67780>,
#  'loosen': <gensim.models.keyedvectors.Vocab at 0x1a27e96550>,
#  'VERY': <gensim.models.keyedvectors.Vocab at 0x1a27eb8048>,
#  'turf': <gensim.models.keyedvectors.Vocab at 0x1a27d67320>,
#  'Food': <gensim.models.keyedvectors.Vocab at 0x1a27d67e48>,
#  'hatchet': <gensim.models.keyedvectors.Vocab at 0x1a27d67dd8>,
#  'heath': <gensim.models.keyedvectors.Vocab at 0x1a27d67128>,
#  'riveted': <gensim.models.keyedvectors.Vocab at 0x1a27d672b0>,
#  'delighteth': <gensim.models.keyedvectors.Vocab at 0x1a27d67208>,
#  'soul': <gensim.models.keyedvectors.Vocab at 0x1a27d679e8>,
#  'burst': <gensim.models.keyedvectors.Vocab at 0x1a27d67e80>,
#  'approve': <gensim.models.keyedvectors.Vocab at 0x1a27d67940>,
#  'shiny': <gensim.models.keyedvectors.Vocab at 0x1a27d67710>,
#  'Patty': <gensim.models.keyedvectors.Vocab at 0x1a27d67630>,
#  'uniforms': <gensim.models.keyedvectors.Vocab at 0x1a27d675f8>,
#  'results': <gensim.models.keyedvectors.Vocab at 0x1a27d67390>,
#  'joking': <gensim.models.keyedvectors.Vocab at 0x1a27d67a90>,
#  'OTTER': <gensim.models.keyedvectors.Vocab at 0x10e9d5ef0>,
#  'custom': <gensim.models.keyedvectors.Vocab at 0x1a27d67da0>,
#  'crude': <gensim.models.keyedvectors.Vocab at 0x1a27d676a0>,
#  'Gryphon': <gensim.models.keyedvectors.Vocab at 0x1a27d677f0>,
#  'blasting': <gensim.models.keyedvectors.Vocab at 0x1a27d67908>,
#  'Poets': <gensim.models.keyedvectors.Vocab at 0x1a27d67eb8>,
#  'Olives': <gensim.models.keyedvectors.Vocab at 0x1a27d67080>,
#  'remarkably': <gensim.models.keyedvectors.Vocab at 0x1a24a63278>,
#  'omit': <gensim.models.keyedvectors.Vocab at 0x1a24a635f8>,
#  'Shuhite': <gensim.models.keyedvectors.Vocab at 0x1a27ee3f60>,
#  'none': <gensim.models.keyedvectors.Vocab at 0x1a27ee3c88>,
#  'queen': <gensim.models.keyedvectors.Vocab at 0x1a27ee3cc0>,
#  'compel': <gensim.models.keyedvectors.Vocab at 0x1a27ee3ef0>,
#  'hundredfold': <gensim.models.keyedvectors.Vocab at 0x1a27ee3da0>,
#  'gloomily': <gensim.models.keyedvectors.Vocab at 0x1a27ee3470>,
#  'Amid': <gensim.models.keyedvectors.Vocab at 0x1a27ee3b00>,
#  'swerve': <gensim.models.keyedvectors.Vocab at 0x1a27ee30b8>,
#  'manhood': <gensim.models.keyedvectors.Vocab at 0x1a27ee37f0>,
#  'packed': <gensim.models.keyedvectors.Vocab at 0x1a27ee3a58>,
#  'Greenland': <gensim.models.keyedvectors.Vocab at 0x1a27ee3b38>,
#  'Mur': <gensim.models.keyedvectors.Vocab at 0x1a27ee3588>,
#  'each': <gensim.models.keyedvectors.Vocab at 0x1a27ee3ac8>,
#  'Rising': <gensim.models.keyedvectors.Vocab at 0x1a27ee37b8>,
#  'delayed': <gensim.models.keyedvectors.Vocab at 0x1a27db1358>,
#  'waistcoat': <gensim.models.keyedvectors.Vocab at 0x1a27ee3630>,
#  'brake': <gensim.models.keyedvectors.Vocab at 0x1a27ee3cf8>,
#  ':': <gensim.models.keyedvectors.Vocab at 0x1a27ee39b0>,
#  'canvas': <gensim.models.keyedvectors.Vocab at 0x1a27ee3e10>,
#  'judge': <gensim.models.keyedvectors.Vocab at 0x1a27b59fd0>,
#  'Jupiter': <gensim.models.keyedvectors.Vocab at 0x1a27ee35c0>,
#  'foul': <gensim.models.keyedvectors.Vocab at 0x1a28d0f5c0>,
#  'canoe': <gensim.models.keyedvectors.Vocab at 0x1a27ee3ba8>,
#  'goeth': <gensim.models.keyedvectors.Vocab at 0x1a27ee3320>,
#  'hasten': <gensim.models.keyedvectors.Vocab at 0x1a28ba7c18>,
#  'gesture': <gensim.models.keyedvectors.Vocab at 0x1a27ee3160>,
#  'goods': <gensim.models.keyedvectors.Vocab at 0x1a27ee33c8>,
#  'Mahalaleel': <gensim.models.keyedvectors.Vocab at 0x1a27b59f28>,
#  'Matthew': <gensim.models.keyedvectors.Vocab at 0x1a27ee3390>,
#  'Cai': <gensim.models.keyedvectors.Vocab at 0x1a27ee3c50>,
#  'physician': <gensim.models.keyedvectors.Vocab at 0x1a27ee35f8>,
#  'troubles': <gensim.models.keyedvectors.Vocab at 0x1a27ee3dd8>,
#  'Common': <gensim.models.keyedvectors.Vocab at 0x1a27ee3748>,
#  'Georgia': <gensim.models.keyedvectors.Vocab at 0x1a27ee3278>,
#  'Otway': <gensim.models.keyedvectors.Vocab at 0x1a27ee39e8>,
#  'confectioner': <gensim.models.keyedvectors.Vocab at 0x1a27ee3828>,
#  'singed': <gensim.models.keyedvectors.Vocab at 0x1a27ee3240>,
#  'tidy': <gensim.models.keyedvectors.Vocab at 0x1a27b69b70>,
#  'Accordingly': <gensim.models.keyedvectors.Vocab at 0x1a27ee3550>,
#  '?--': <gensim.models.keyedvectors.Vocab at 0x1a27ee3a20>,
#  'gripe': <gensim.models.keyedvectors.Vocab at 0x1a27ee3f28>,
#  'removal': <gensim.models.keyedvectors.Vocab at 0x1a27ee3d68>,
#  'swimming': <gensim.models.keyedvectors.Vocab at 0x1a27ee3e48>,
#  'systems': <gensim.models.keyedvectors.Vocab at 0x1a27ee34a8>,
#  'without': <gensim.models.keyedvectors.Vocab at 0x1a27ee32b0>,
#  'exclamation': <gensim.models.keyedvectors.Vocab at 0x1a27ee3438>,
#  'sober': <gensim.models.keyedvectors.Vocab at 0x1a27ee3400>,
#  'Ile': <gensim.models.keyedvectors.Vocab at 0x1a27a615c0>,
#  'mess': <gensim.models.keyedvectors.Vocab at 0x1a27ee3518>,
#  'Already': <gensim.models.keyedvectors.Vocab at 0x1a28be62b0>,
#  'strove': <gensim.models.keyedvectors.Vocab at 0x1a28be4898>,
#  'commend': <gensim.models.keyedvectors.Vocab at 0x1a28c112b0>,
#  'framed': <gensim.models.keyedvectors.Vocab at 0x1a27ee3a90>,
#  'Dominations': <gensim.models.keyedvectors.Vocab at 0x1a27ee3780>,
#  'denied': <gensim.models.keyedvectors.Vocab at 0x1a27f2b2b0>,
#  'maxim': <gensim.models.keyedvectors.Vocab at 0x1a27ee38d0>,
#  'dispersed': <gensim.models.keyedvectors.Vocab at 0x10e9d5470>,
#  'wrenched': <gensim.models.keyedvectors.Vocab at 0x10e9bfa58>,
#  'account': <gensim.models.keyedvectors.Vocab at 0x1a27ee3898>,
#  'fringes': <gensim.models.keyedvectors.Vocab at 0x1a27ee32e8>,
#  'verse': <gensim.models.keyedvectors.Vocab at 0x1a27ee3710>,
#  'shuttlecock': <gensim.models.keyedvectors.Vocab at 0x1a27f2bef0>,
#  'volition': <gensim.models.keyedvectors.Vocab at 0x1a27ee36a0>,
#  'wert': <gensim.models.keyedvectors.Vocab at 0x1a27ee3eb8>,
#  'hatred': <gensim.models.keyedvectors.Vocab at 0x1a27ee30f0>,
#  'Point': <gensim.models.keyedvectors.Vocab at 0x1a27ee3668>,
#  'bachelor': <gensim.models.keyedvectors.Vocab at 0x1a27b60860>,
#  'flags': <gensim.models.keyedvectors.Vocab at 0x1a27ee3128>,
#  'profess': <gensim.models.keyedvectors.Vocab at 0x1a27ee3c18>,
#  'wreathen': <gensim.models.keyedvectors.Vocab at 0x1a27e3fe80>,
#  'Thursday': <gensim.models.keyedvectors.Vocab at 0x1a27e3f320>,
#  'risen': <gensim.models.keyedvectors.Vocab at 0x1a27e3ff60>,
#  'dispense': <gensim.models.keyedvectors.Vocab at 0x1a28e0d940>,
#  '_his_': <gensim.models.keyedvectors.Vocab at 0x1a27e3fef0>,
#  'prisons': <gensim.models.keyedvectors.Vocab at 0x1a27e3f358>,
#  'Ryan': <gensim.models.keyedvectors.Vocab at 0x1a27e3fe10>,
#  'wigwam': <gensim.models.keyedvectors.Vocab at 0x1a27e3f630>,
#  'Tahiti': <gensim.models.keyedvectors.Vocab at 0x1a27e3f438>,
#  'tallied': <gensim.models.keyedvectors.Vocab at 0x1a27e3f198>,
#  'above': <gensim.models.keyedvectors.Vocab at 0x1a27e3f6d8>,
#  'Benjamin': <gensim.models.keyedvectors.Vocab at 0x1a27e3fbe0>,
#  'occurs': <gensim.models.keyedvectors.Vocab at 0x1a27e3f7f0>,
#  'ask': <gensim.models.keyedvectors.Vocab at 0x1a27e3f860>,
#  'amiably': <gensim.models.keyedvectors.Vocab at 0x1a27e3f748>,
#  'nursed': <gensim.models.keyedvectors.Vocab at 0x1a27819d68>,
#  'newes': <gensim.models.keyedvectors.Vocab at 0x1a27e3f0f0>,
#  'foreheads': <gensim.models.keyedvectors.Vocab at 0x1a27e3f208>,
#  'thirds': <gensim.models.keyedvectors.Vocab at 0x1a27e3fa90>,
#  'balances': <gensim.models.keyedvectors.Vocab at 0x1a27ee9b38>,
#  'Clifton': <gensim.models.keyedvectors.Vocab at 0x1a27e3f0b8>,
#  'Dare': <gensim.models.keyedvectors.Vocab at 0x1a27e3f6a0>,
#  'stain': <gensim.models.keyedvectors.Vocab at 0x1a27e3f3c8>,
#  'link': <gensim.models.keyedvectors.Vocab at 0x1a27e3f470>,
#  'BOY': <gensim.models.keyedvectors.Vocab at 0x1a27e3f898>,
#  'senseless': <gensim.models.keyedvectors.Vocab at 0x1a27e3f4a8>,
#  'legged': <gensim.models.keyedvectors.Vocab at 0x1a27ee9278>,
#  'stump': <gensim.models.keyedvectors.Vocab at 0x1a27e3f940>,
#  'Again': <gensim.models.keyedvectors.Vocab at 0x1a27b59390>,
#  'Innumerable': <gensim.models.keyedvectors.Vocab at 0x1a27e3f1d0>,
#  'Hand': <gensim.models.keyedvectors.Vocab at 0x1a27e27c18>,
#  'During': <gensim.models.keyedvectors.Vocab at 0x1a277d67f0>,
#  'stiffly': <gensim.models.keyedvectors.Vocab at 0x1a28ce2518>,
#  'Fell': <gensim.models.keyedvectors.Vocab at 0x1a27b59b38>,
#  'LORD': <gensim.models.keyedvectors.Vocab at 0x1a27e3f128>,
#  'AM': <gensim.models.keyedvectors.Vocab at 0x1a27e3fa58>,
#  'sucked': <gensim.models.keyedvectors.Vocab at 0x1a28d35748>,
#  'Zerahiah': <gensim.models.keyedvectors.Vocab at 0x1a27e3f160>,
#  'swell': <gensim.models.keyedvectors.Vocab at 0x1a27e3ffd0>,
#  'enclose': <gensim.models.keyedvectors.Vocab at 0x1a27e3f2b0>,
#  'forgiveness': <gensim.models.keyedvectors.Vocab at 0x1a27e3fac8>,
#  'five': <gensim.models.keyedvectors.Vocab at 0x1a27e3f400>,
#  'Haply': <gensim.models.keyedvectors.Vocab at 0x1a27e3f9b0>,
#  'bathe': <gensim.models.keyedvectors.Vocab at 0x1a27e3ff28>,
#  'argument': <gensim.models.keyedvectors.Vocab at 0x1a27e3f518>,
#  'unholy': <gensim.models.keyedvectors.Vocab at 0x1a27e3fb70>,
#  'holdeth': <gensim.models.keyedvectors.Vocab at 0x1a27e3f668>,
#  '121': <gensim.models.keyedvectors.Vocab at 0x1a28d1cba8>,
#  'weeds': <gensim.models.keyedvectors.Vocab at 0x1a27e3fcc0>,
#  'glint': <gensim.models.keyedvectors.Vocab at 0x1a27b81e48>,
#  'member': <gensim.models.keyedvectors.Vocab at 0x1a27e96668>,
#  'virgins': <gensim.models.keyedvectors.Vocab at 0x1a27e96278>,
#  'vineyards': <gensim.models.keyedvectors.Vocab at 0x1a27e965f8>,
#  'Hermon': <gensim.models.keyedvectors.Vocab at 0x10e9ae0b8>,
#  'belongeth': <gensim.models.keyedvectors.Vocab at 0x1a27b590b8>,
#  'easy': <gensim.models.keyedvectors.Vocab at 0x1a27e96a90>,
#  'Statue': <gensim.models.keyedvectors.Vocab at 0x1a27e96630>,
#  'pipe': <gensim.models.keyedvectors.Vocab at 0x1a28d0f048>,
#  'Teman': <gensim.models.keyedvectors.Vocab at 0x1a27e96b38>,
#  'massacre': <gensim.models.keyedvectors.Vocab at 0x1a27e966d8>,
#  'garden': <gensim.models.keyedvectors.Vocab at 0x1a27e964e0>,
#  'entreaty': <gensim.models.keyedvectors.Vocab at 0x1a27e96cc0>,
#  'honest': <gensim.models.keyedvectors.Vocab at 0x1a27e96400>,
#  'rib': <gensim.models.keyedvectors.Vocab at 0x1a27e96be0>,
#  'gracious': <gensim.models.keyedvectors.Vocab at 0x1a27e96518>,
#  'addressing': <gensim.models.keyedvectors.Vocab at 0x1a27e96710>,
#  'decay': <gensim.models.keyedvectors.Vocab at 0x1a27e966a0>,
#  'grazed': <gensim.models.keyedvectors.Vocab at 0x1a27e96588>,
#  'satisfaction': <gensim.models.keyedvectors.Vocab at 0x1a27e96470>,
#  'farm': <gensim.models.keyedvectors.Vocab at 0x1a27e960f0>,
#  'yesterday': <gensim.models.keyedvectors.Vocab at 0x1a27e967b8>,
#  'forgets': <gensim.models.keyedvectors.Vocab at 0x1a27e68ac8>,
#  'owned': <gensim.models.keyedvectors.Vocab at 0x1a27dd9cf8>,
#  'Macduff': <gensim.models.keyedvectors.Vocab at 0x1a28be65f8>,
#  'baldness': <gensim.models.keyedvectors.Vocab at 0x1a27e96390>,
#  'particulars': <gensim.models.keyedvectors.Vocab at 0x1a27e96080>,
#  'horses': <gensim.models.keyedvectors.Vocab at 0x1a28c91630>,
#  'sunrising': <gensim.models.keyedvectors.Vocab at 0x1a27e96f28>,
#  'thing': <gensim.models.keyedvectors.Vocab at 0x1a27e96898>,
#  'clinking': <gensim.models.keyedvectors.Vocab at 0x1a27e96cf8>,
#  'outward': <gensim.models.keyedvectors.Vocab at 0x1a27e96eb8>,
#  'verbal': <gensim.models.keyedvectors.Vocab at 0x1a27e96e80>,
#  'eyesight': <gensim.models.keyedvectors.Vocab at 0x1a27e96048>,
#  'disgrace': <gensim.models.keyedvectors.Vocab at 0x1a27e965c0>,
#  'note': <gensim.models.keyedvectors.Vocab at 0x1a27e960b8>,
#  'doubloons': <gensim.models.keyedvectors.Vocab at 0x1a27e968d0>,
#  'charts': <gensim.models.keyedvectors.Vocab at 0x1a27e96828>,
#  'Square': <gensim.models.keyedvectors.Vocab at 0x1a28be66a0>,
#  'inexpressibly': <gensim.models.keyedvectors.Vocab at 0x1a28bce128>,
#  'legends': <gensim.models.keyedvectors.Vocab at 0x1a27e964a8>,
#  'berth': <gensim.models.keyedvectors.Vocab at 0x1a27e96b70>,
#  'VIII': <gensim.models.keyedvectors.Vocab at 0x1a27e96978>,
#  'defraud': <gensim.models.keyedvectors.Vocab at 0x1a27e962b0>,
#  'rockets': <gensim.models.keyedvectors.Vocab at 0x1a27f040b8>,
#  'unable': <gensim.models.keyedvectors.Vocab at 0x1a27e967f0>,
#  'red': <gensim.models.keyedvectors.Vocab at 0x1a27e96dd8>,
#  'clergyman': <gensim.models.keyedvectors.Vocab at 0x1a27e96438>,
#  'spoke': <gensim.models.keyedvectors.Vocab at 0x1a27e96860>,
#  'usual': <gensim.models.keyedvectors.Vocab at 0x1a27e96ba8>,
#  'toes': <gensim.models.keyedvectors.Vocab at 0x1a28d0fa90>,
#  'fringe': <gensim.models.keyedvectors.Vocab at 0x1a27e96c50>,
#  'guile': <gensim.models.keyedvectors.Vocab at 0x1a27e96b00>,
#  'Barzillai': <gensim.models.keyedvectors.Vocab at 0x1a27e96d30>,
#  'sundry': <gensim.models.keyedvectors.Vocab at 0x1a27e96ef0>,
#  'correct': <gensim.models.keyedvectors.Vocab at 0x1a27e96940>,
#  'tete': <gensim.models.keyedvectors.Vocab at 0x1a27e96128>,
#  'representations': <gensim.models.keyedvectors.Vocab at 0x1a27e96e10>,
#  'Sidonians': <gensim.models.keyedvectors.Vocab at 0x1a279532b0>,
#  'axe': <gensim.models.keyedvectors.Vocab at 0x1a27b59358>,
#  'admires': <gensim.models.keyedvectors.Vocab at 0x1a28bce208>,
#  'continued': <gensim.models.keyedvectors.Vocab at 0x1a279537b8>,
#  'interpreted': <gensim.models.keyedvectors.Vocab at 0x1a27953a90>,
#  'Kidron': <gensim.models.keyedvectors.Vocab at 0x1a28d0aa20>,
#  'ample': <gensim.models.keyedvectors.Vocab at 0x1a279535c0>,
#  'travelled': <gensim.models.keyedvectors.Vocab at 0x1a27b59f60>,
#  'Fierce': <gensim.models.keyedvectors.Vocab at 0x1a27953ac8>,
#  'holden': <gensim.models.keyedvectors.Vocab at 0x1a27953f28>,
#  'clearing': <gensim.models.keyedvectors.Vocab at 0x1a27953780>,
#  'leaky': <gensim.models.keyedvectors.Vocab at 0x1a27b591d0>,
#  'Professor': <gensim.models.keyedvectors.Vocab at 0x1a27953fd0>,
#  'furrows': <gensim.models.keyedvectors.Vocab at 0x1a27953470>,
#  'items': <gensim.models.keyedvectors.Vocab at 0x1a27953c88>,
#  'purified': <gensim.models.keyedvectors.Vocab at 0x1a27953748>,
#  'visit': <gensim.models.keyedvectors.Vocab at 0x1a279799e8>,
#  'Seruants': <gensim.models.keyedvectors.Vocab at 0x1a28be6748>,
#  'unemployed': <gensim.models.keyedvectors.Vocab at 0x1a27953048>,
#  'Dante': <gensim.models.keyedvectors.Vocab at 0x1a279530f0>,
#  'whereat': <gensim.models.keyedvectors.Vocab at 0x1a27953668>,
#  'collections': <gensim.models.keyedvectors.Vocab at 0x1a27953588>,
#  'pestilence': <gensim.models.keyedvectors.Vocab at 0x1a27953dd8>,
#  'ladder': <gensim.models.keyedvectors.Vocab at 0x1a279534a8>,
#  'bride': <gensim.models.keyedvectors.Vocab at 0x1a28bce278>,
#  'courses': <gensim.models.keyedvectors.Vocab at 0x1a27b35748>,
#  'keepsake': <gensim.models.keyedvectors.Vocab at 0x1a27953240>,
#  'firstlings': <gensim.models.keyedvectors.Vocab at 0x1a27953828>,
#  'Tyranny': <gensim.models.keyedvectors.Vocab at 0x1a27953b38>,
#  'eternal': <gensim.models.keyedvectors.Vocab at 0x1a279a5470>,
#  'drench': <gensim.models.keyedvectors.Vocab at 0x1a27953940>,
#  'Har': <gensim.models.keyedvectors.Vocab at 0x1a278217b8>,
#  'People': <gensim.models.keyedvectors.Vocab at 0x1a27821390>,
#  'desirable': <gensim.models.keyedvectors.Vocab at 0x1a28d0fbe0>,
#  'endlessly': <gensim.models.keyedvectors.Vocab at 0x1a27821080>,
#  'uncertainty': <gensim.models.keyedvectors.Vocab at 0x1a27821a20>,
#  'marries': <gensim.models.keyedvectors.Vocab at 0x1a27821e10>,
#  'sighed': <gensim.models.keyedvectors.Vocab at 0x1a279a5438>,
#  'death': <gensim.models.keyedvectors.Vocab at 0x1a27821470>,
#  'ruling': <gensim.models.keyedvectors.Vocab at 0x1a28be6940>,
#  'pleading': <gensim.models.keyedvectors.Vocab at 0x1a27821940>,
#  'Jabin': <gensim.models.keyedvectors.Vocab at 0x1a27821128>,
#  'erected': <gensim.models.keyedvectors.Vocab at 0x1a28d0fc50>,
#  'expensive': <gensim.models.keyedvectors.Vocab at 0x1a27821be0>,
#  'myriad': <gensim.models.keyedvectors.Vocab at 0x1a27821d30>,
#  '_very_': <gensim.models.keyedvectors.Vocab at 0x1a28d35dd8>,
#  'frown': <gensim.models.keyedvectors.Vocab at 0x1a28d0fc88>,
#  'foam': <gensim.models.keyedvectors.Vocab at 0x1a27821860>,
#  '?)': <gensim.models.keyedvectors.Vocab at 0x1a278210f0>,
#  'socket': <gensim.models.keyedvectors.Vocab at 0x1a27821198>,
#  'girdles': <gensim.models.keyedvectors.Vocab at 0x1a27876208>,
#  'oceans': <gensim.models.keyedvectors.Vocab at 0x1a278761d0>,
#  'dayes': <gensim.models.keyedvectors.Vocab at 0x1a27876320>,
#  'Hear': <gensim.models.keyedvectors.Vocab at 0x1a27876e48>,
#  'actor': <gensim.models.keyedvectors.Vocab at 0x1a28bfd358>,
#  'mistress': <gensim.models.keyedvectors.Vocab at 0x1a27807c88>,
#  'whereby': <gensim.models.keyedvectors.Vocab at 0x10e9970b8>,
#  'pursuit': <gensim.models.keyedvectors.Vocab at 0x1a27876f28>,
#  'sufficiently': <gensim.models.keyedvectors.Vocab at 0x1a27876b00>,
#  'series': <gensim.models.keyedvectors.Vocab at 0x1a27876358>,
#  'frame': <gensim.models.keyedvectors.Vocab at 0x1a27876668>,
#  'tire': <gensim.models.keyedvectors.Vocab at 0x1a278762e8>,
#  'blind': <gensim.models.keyedvectors.Vocab at 0x1a278766d8>,
#  'renounce': <gensim.models.keyedvectors.Vocab at 0x10e9976a0>,
#  'unnamed': <gensim.models.keyedvectors.Vocab at 0x1a24a75710>,
#  'care': <gensim.models.keyedvectors.Vocab at 0x1a24a75a58>,
#  'Round': <gensim.models.keyedvectors.Vocab at 0x1a28be68d0>,
#  '96': <gensim.models.keyedvectors.Vocab at 0x1a27e8c518>,
#  'flax': <gensim.models.keyedvectors.Vocab at 0x1a27e8c550>,
#  'ribs': <gensim.models.keyedvectors.Vocab at 0x1a28be0e10>,
#  'views': <gensim.models.keyedvectors.Vocab at 0x1a27e8c4a8>,
#  'Ahimaaz': <gensim.models.keyedvectors.Vocab at 0x1a27e8ce10>,
#  'Sixteen': <gensim.models.keyedvectors.Vocab at 0x1a28bce3c8>,
#  'blissful': <gensim.models.keyedvectors.Vocab at 0x1a27e8c6d8>,
#  'dreaded': <gensim.models.keyedvectors.Vocab at 0x1a27e8c1d0>,
#  'says': <gensim.models.keyedvectors.Vocab at 0x10e9c3630>,
#  'Derick': <gensim.models.keyedvectors.Vocab at 0x1a27e8c160>,
#  'pollute': <gensim.models.keyedvectors.Vocab at 0x1a27e8c6a0>,
#  'poorer': <gensim.models.keyedvectors.Vocab at 0x1a27e8cb70>,
#  'indignantly': <gensim.models.keyedvectors.Vocab at 0x1a27e8c780>,
#  'festive': <gensim.models.keyedvectors.Vocab at 0x1a27e8c208>,
#  'troubleth': <gensim.models.keyedvectors.Vocab at 0x1a27e8ce80>,
#  'prosperous': <gensim.models.keyedvectors.Vocab at 0x1a27e8c0b8>,
#  'byword': <gensim.models.keyedvectors.Vocab at 0x1a27e8c3c8>,
#  'Gay': <gensim.models.keyedvectors.Vocab at 0x1a27e8c5f8>,
#  'Asia': <gensim.models.keyedvectors.Vocab at 0x1a27e8c828>,
#  'Sodom': <gensim.models.keyedvectors.Vocab at 0x1a27e8c438>,
#  'deliver': <gensim.models.keyedvectors.Vocab at 0x1a27d29160>,
#  'stern': <gensim.models.keyedvectors.Vocab at 0x1a27e8ccf8>,
#  'dollars': <gensim.models.keyedvectors.Vocab at 0x1a27e8cfd0>,
#  'prophetic': <gensim.models.keyedvectors.Vocab at 0x1a27e8c048>,
#  'wrist': <gensim.models.keyedvectors.Vocab at 0x1a28c68e10>,
#  'throats': <gensim.models.keyedvectors.Vocab at 0x1a27e8ce48>,
#  'Ghost': <gensim.models.keyedvectors.Vocab at 0x1a28bce518>,
#  'sleeping': <gensim.models.keyedvectors.Vocab at 0x1a27e8c240>,
#  'Inspector': <gensim.models.keyedvectors.Vocab at 0x1a27e8c860>,
#  'unwholesome': <gensim.models.keyedvectors.Vocab at 0x10e9a8780>,
#  'Beleeue': <gensim.models.keyedvectors.Vocab at 0x1a27e8c908>,
#  'tally': <gensim.models.keyedvectors.Vocab at 0x1a27e8c588>,
#  'desired': <gensim.models.keyedvectors.Vocab at 0x1a27e8cd68>,
#  'Brian': <gensim.models.keyedvectors.Vocab at 0x1a27e8c198>,
#  'worshipped': <gensim.models.keyedvectors.Vocab at 0x1a27e8c5c0>,
#  'dragged': <gensim.models.keyedvectors.Vocab at 0x1a27e8c9e8>,
#  'sporting': <gensim.models.keyedvectors.Vocab at 0x1a27e8c320>,
#  'Java': <gensim.models.keyedvectors.Vocab at 0x1a27e8cba8>,
#  'Binnui': <gensim.models.keyedvectors.Vocab at 0x1a27e8c0f0>,
#  'unlikely': <gensim.models.keyedvectors.Vocab at 0x1a27e8cf28>,
#  'heroick': <gensim.models.keyedvectors.Vocab at 0x1a27e8cdd8>,
#  'personality': <gensim.models.keyedvectors.Vocab at 0x1a27e8ca58>,
#  'issued': <gensim.models.keyedvectors.Vocab at 0x1a28be6a20>,
#  'Octauius': <gensim.models.keyedvectors.Vocab at 0x1a27e8c358>,
#  'affair': <gensim.models.keyedvectors.Vocab at 0x1a28dfbac8>,
#  'helping': <gensim.models.keyedvectors.Vocab at 0x1a27e8c978>,
#  'lunch': <gensim.models.keyedvectors.Vocab at 0x1a27e8c128>,
#  'And': <gensim.models.keyedvectors.Vocab at 0x1a27e8c630>,
#  'poz': <gensim.models.keyedvectors.Vocab at 0x1a27e8cb38>,
#  'guide': <gensim.models.keyedvectors.Vocab at 0x1a27e8cac8>,
#  'reigned': <gensim.models.keyedvectors.Vocab at 0x1a27e8c9b0>,
#  'Thames': <gensim.models.keyedvectors.Vocab at 0x1a27e8ceb8>,
#  'communicate': <gensim.models.keyedvectors.Vocab at 0x1a27807cf8>,
#  'muscular': <gensim.models.keyedvectors.Vocab at 0x1a27e8c898>,
#  'Ophrah': <gensim.models.keyedvectors.Vocab at 0x1a27e8cc18>,
#  'start': <gensim.models.keyedvectors.Vocab at 0x1a27e8c4e0>,
#  'town': <gensim.models.keyedvectors.Vocab at 0x1a27e8cf98>,
#  'hoarse': <gensim.models.keyedvectors.Vocab at 0x1a27e8c940>,
#  'uttereth': <gensim.models.keyedvectors.Vocab at 0x1a28c95b38>,
#  'Wild': <gensim.models.keyedvectors.Vocab at 0x1a27e8c7f0>,
#  'cushions': <gensim.models.keyedvectors.Vocab at 0x1a27e8c400>,
#  'seated': <gensim.models.keyedvectors.Vocab at 0x1a27e8cd30>,
#  'pink': <gensim.models.keyedvectors.Vocab at 0x1a27e8c710>,
#  'Sooth': <gensim.models.keyedvectors.Vocab at 0x1a27e8ca20>,
#  'message': <gensim.models.keyedvectors.Vocab at 0x1a27e8c080>,
#  'sanctified': <gensim.models.keyedvectors.Vocab at 0x1a27e8c668>,
#  'twain': <gensim.models.keyedvectors.Vocab at 0x1a27e8c748>,
#  'Onely': <gensim.models.keyedvectors.Vocab at 0x1a2794f048>,
#  'suspension': <gensim.models.keyedvectors.Vocab at 0x1a28d8eeb8>,
#  'leadeth': <gensim.models.keyedvectors.Vocab at 0x1a28d8e668>,
#  'angry': <gensim.models.keyedvectors.Vocab at 0x1a2794f908>,
#  'Samaritans': <gensim.models.keyedvectors.Vocab at 0x1a2794fc50>,
#  'desist': <gensim.models.keyedvectors.Vocab at 0x1a2794f588>,
#  'splinters': <gensim.models.keyedvectors.Vocab at 0x1a2794f240>,
#  'animals': <gensim.models.keyedvectors.Vocab at 0x1a2794f828>,
#  'Kibrothhattaavah': <gensim.models.keyedvectors.Vocab at 0x1a2794f0b8>,
#  'fidelity': <gensim.models.keyedvectors.Vocab at 0x1a2794feb8>,
#  'gamesome': <gensim.models.keyedvectors.Vocab at 0x1a2794f630>,
#  'nuts': <gensim.models.keyedvectors.Vocab at 0x1a28c83710>,
#  'opportunities': <gensim.models.keyedvectors.Vocab at 0x1a2794fac8>,
#  'luxuriant': <gensim.models.keyedvectors.Vocab at 0x1a2794fe10>,
#  'anvil': <gensim.models.keyedvectors.Vocab at 0x1a28be6a90>,
#  'declare': <gensim.models.keyedvectors.Vocab at 0x1a2794f2e8>,
#  'diminished': <gensim.models.keyedvectors.Vocab at 0x1a2794f550>,
#  'Returning': <gensim.models.keyedvectors.Vocab at 0x1a28e04e10>,
#  'family': <gensim.models.keyedvectors.Vocab at 0x1a28d013c8>,
#  'straits': <gensim.models.keyedvectors.Vocab at 0x1a2794f400>,
#  'heir': <gensim.models.keyedvectors.Vocab at 0x1a2794fb00>,
#  'Virginia': <gensim.models.keyedvectors.Vocab at 0x1a28cf42e8>,
#  'Brooklyn': <gensim.models.keyedvectors.Vocab at 0x1a2794f5f8>,
#  'some': <gensim.models.keyedvectors.Vocab at 0x1a2794f0f0>,
#  'preached': <gensim.models.keyedvectors.Vocab at 0x1a2794f4a8>,
#  'contemned': <gensim.models.keyedvectors.Vocab at 0x1a2794f438>,
#  'strolled': <gensim.models.keyedvectors.Vocab at 0x1a2794fd68>,
#  'Barlow': <gensim.models.keyedvectors.Vocab at 0x1a2794f8d0>,
#  'aquiline': <gensim.models.keyedvectors.Vocab at 0x1a28e08b38>,
#  'tropics': <gensim.models.keyedvectors.Vocab at 0x1a2794fe48>,
#  'sword': <gensim.models.keyedvectors.Vocab at 0x1a2794f198>,
#  'threads': <gensim.models.keyedvectors.Vocab at 0x1a28d0aba8>,
#  'gallon': <gensim.models.keyedvectors.Vocab at 0x1a2794f978>,
#  'could': <gensim.models.keyedvectors.Vocab at 0x1a27d47b38>,
#  'reflection': <gensim.models.keyedvectors.Vocab at 0x1a2794ff28>,
#  'Mayor': <gensim.models.keyedvectors.Vocab at 0x1a27863a58>,
#  'Cawdor': <gensim.models.keyedvectors.Vocab at 0x1a27863a90>,
#  'psalteries': <gensim.models.keyedvectors.Vocab at 0x1a27863588>,
#  ...}

# %%
len(model.wv.vocab)
# Out:
# 17011

# %%
X = model[model.wv.vocab]
# Out:
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.

# %%
X.shape
# Out:
# (17011, 64)

# %%
tsne = TSNE(n_components=2, n_iter=1000) # 200 is minimum iter; default is 1000

# %%
X_2d = tsne.fit_transform(X)

# %%
X_2d[0:5]
# Out:
# array([[-38.690945 ,  24.691082 ],
#        [ 20.374537 ,  -4.9723454],
#        [-24.305895 ,  22.25776  ],
#        [  7.774654 , -28.915133 ],
#        [  8.727895 , -11.9155035]], dtype=float32)

# %%
# create DataFrame for storing results and plotting
coords_df = pd.DataFrame(X_2d, columns=['x','y'])
coords_df['token'] = model.wv.vocab.keys()

# %%
coords_df.head()
# Out:
#            x          y        token
# 0 -38.690945  24.691082        speak
# 1  20.374537  -4.972345  significant
# 2 -24.305895  22.257759  instruction
# 3   7.774654 -28.915133       prints
# 4   8.727895 -11.915504     bordered

# %%
# coords_df.to_csv('raw_gutenberg_tsne.csv', index=False)

# %% [markdown]
# #### Visualize 2D representation of word vectors

# %%
coords_df = pd.read_csv('raw_gutenberg_tsne.csv')

# %%
coords_df.plot.scatter('x', 'y', figsize=(12,12), marker='.', s=10, alpha=0.2,c="blue")

# %%
output_notebook() # output bokeh plots inline in notebook
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b3f9b131-1c93-4980-9685-b1e3ac57a01a">Loading BokehJS ...</span>
#     </div>

# %%
subset_df = coords_df.sample(n=5000)

# %%
p = figure(plot_width=800, plot_height=800)
_ = p.text(x=subset_df.x, y=subset_df.y, text=subset_df.token)

# %%
show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="0a72cbac-259e-4266-98a8-aa4bc5098d54"></div>
# </div>
