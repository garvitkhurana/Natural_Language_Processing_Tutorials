# %% [markdown]
# # Creating Word Vectors with word2vec

# %% [markdown]
# In this notebook, we create word vectors from a corpus of public-domain books, a selection from [Project Gutenberg](https://www.gutenberg.org/).

# %% [markdown]
# #### Load dependencies

# %%
import nltk
from nltk import word_tokenize, sent_tokenize
import gensim
from gensim.models.word2vec import Word2Vec
from sklearn.manifold import TSNE
import pandas as pd
from bokeh.io import output_notebook
from bokeh.plotting import show, figure
# %matplotlib inline

# %%
nltk.download('punkt') # English-language sentence tokenizer (not all periods end sentences; not all sentences start with a capital letter)

# %% [markdown]
# #### Load data

# %%
nltk.download('gutenberg')
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     /Users/garvitkhurana/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# True

# %%
from nltk.corpus import gutenberg

# %%
len(gutenberg.fileids())
# Out:
# 18

# %%
gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %% [markdown]
# #### Tokenize text

# %%
gberg_sent_tokens = sent_tokenize(gutenberg.raw())

# %%
gberg_sent_tokens[10:20]
# Out:
# ['It was on the wedding-day\nof this beloved friend that Emma first sat in mournful thought\nof any continuance.',
#  'The wedding over, and the bride-people gone,\nher father and herself were left to dine together, with no prospect\nof a third to cheer a long evening.',
#  'Her father composed himself\nto sleep after dinner, as usual, and she had then only to sit\nand think of what she had lost.',
#  'The event had every promise of happiness for her friend.',
#  "Mr. Weston\nwas a man of unexceptionable character, easy fortune, suitable age,\nand pleasant manners; and there was some satisfaction in considering\nwith what self-denying, generous friendship she had always wished\nand promoted the match; but it was a black morning's work for her.",
#  'The want of Miss Taylor would be felt every hour of every day.',
#  'She recalled her past kindness--the kindness, the affection of sixteen\nyears--how she had taught and how she had played with her from five\nyears old--how she had devoted all her powers to attach and amuse\nher in health--and how nursed her through the various illnesses\nof childhood.',
#  "A large debt of gratitude was owing here; but the\nintercourse of the last seven years, the equal footing and perfect\nunreserve which had soon followed Isabella's marriage, on their\nbeing left to each other, was yet a dearer, tenderer recollection.",
#  'She had been a friend and companion such as few possessed: intelligent,\nwell-informed, useful, gentle, knowing all the ways of the family,\ninterested in all its concerns, and peculiarly interested in herself,\nin every pleasure, every scheme of hers--one to whom she could speak\nevery thought as it arose, and who had such an affection for her\nas could never find fault.',
#  'How was she to bear the change?--It was true that her friend was\ngoing only half a mile from them; but Emma was aware that great must\nbe the difference between a Mrs. Weston, only half a mile from them,\nand a Miss Taylor in the house; and with all her advantages,\nnatural and domestic, she was now in great danger of suffering\nfrom intellectual solitude.']

# %%
gberg_sent_tokens[1]
# Out:
# "She was the youngest of the two daughters of a most affectionate,\nindulgent father; and had, in consequence of her sister's marriage,\nbeen mistress of his house from a very early period."

# %%
word_tokenize(gberg_sent_tokens[1])
# Out:
# ['She',
#  'was',
#  'the',
#  'youngest',
#  'of',
#  'the',
#  'two',
#  'daughters',
#  'of',
#  'a',
#  'most',
#  'affectionate',
#  ',',
#  'indulgent',
#  'father',
#  ';',
#  'and',
#  'had',
#  ',',
#  'in',
#  'consequence',
#  'of',
#  'her',
#  'sister',
#  "'s",
#  'marriage',
#  ',',
#  'been',
#  'mistress',
#  'of',
#  'his',
#  'house',
#  'from',
#  'a',
#  'very',
#  'early',
#  'period',
#  '.']

# %%
word_tokenize(gberg_sent_tokens[1])[14]
# Out:
# 'father'

# %%
# a convenient method that handles newlines, as well as tokenizing sentences and words in one shot
gberg_sents = gutenberg.sents()

# %%
gberg_sents[3]
# Out:
# ['Emma',
#  'Woodhouse',
#  ',',
#  'handsome',
#  ',',
#  'clever',
#  ',',
#  'and',
#  'rich',
#  ',',
#  'with',
#  'a',
#  'comfortable',
#  'home',
#  'and',
#  'happy',
#  'disposition',
#  ',',
#  'seemed',
#  'to',
#  'unite',
#  'some',
#  'of',
#  'the',
#  'best',
#  'blessings',
#  'of',
#  'existence',
#  ';',
#  'and',
#  'had',
#  'lived',
#  'nearly',
#  'twenty',
#  '-',
#  'one',
#  'years',
#  'in',
#  'the',
#  'world',
#  'with',
#  'very',
#  'little',
#  'to',
#  'distress',
#  'or',
#  'vex',
#  'her',
#  '.']

# %%
gberg_sents[4]
# Out:
# ['She',
#  'was',
#  'the',
#  'youngest',
#  'of',
#  'the',
#  'two',
#  'daughters',
#  'of',
#  'a',
#  'most',
#  'affectionate',
#  ',',
#  'indulgent',
#  'father',
#  ';',
#  'and',
#  'had',
#  ',',
#  'in',
#  'consequence',
#  'of',
#  'her',
#  'sister',
#  "'",
#  's',
#  'marriage',
#  ',',
#  'been',
#  'mistress',
#  'of',
#  'his',
#  'house',
#  'from',
#  'a',
#  'very',
#  'early',
#  'period',
#  '.']

# %%
gberg_sents[4][14]
# Out:
# 'father'

# %%
# another convenient method that we don't immediately need: 
gutenberg.words()
# Out:
# ['[', 'Emma', 'by', 'Jane', 'Austen', '1816', ']', ...]

# %%
# gutenberg.words() is analogous to the following line, which need not be run: 
# word_tokenize(gutenberg.raw())

# %%
# our Gutenberg corpus is 2.6m words in length: 
len(gutenberg.words())
# Out:
# 2621613

# %% [markdown]
# #### Run word2vec

# %%
model = Word2Vec(sentences=gberg_sents, size=64, sg=1, window=10, min_count=5, seed=42, workers=8)

# %%
model.save('raw_gutenberg_model.w2v')

# %% [markdown]
# #### Explore model

# %%
# skip re-training the model with the next line:  
model = gensim.models.Word2Vec.load('raw_gutenberg_model.w2v')

# %%
model['dog']
# Out:
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# array([ 0.12967627,  0.22366616, -0.04895347,  0.48068658, -0.0512192 ,
#        -0.25564432,  0.25745457,  0.47401932,  0.03461463, -0.38529944,
#         0.02485201, -0.3951841 ,  0.36035952,  0.08620894,  0.06203103,
#         0.31410983,  0.08759797, -0.56160265, -0.35978436,  0.23913696,
#        -0.25926745,  0.17992972, -0.0731106 , -0.5374668 ,  0.14859948,
#         0.04056375, -0.21412905, -0.11110596,  0.6341513 , -0.32069707,
#        -0.04279768,  0.23346044,  0.3045399 , -0.16445144, -0.7109213 ,
#        -0.32158977, -0.01410222, -0.06449791, -0.013713  ,  0.27734074,
#        -0.06495606, -0.20155273, -0.2110344 , -0.17293343, -0.5826398 ,
#        -0.31618336, -0.06059416,  0.32044694,  0.22991934, -0.11659871,
#        -0.20760028,  0.35589454, -0.08935375, -0.138671  ,  0.02305991,
#        -0.37190315,  0.0962362 ,  0.08387335,  0.8197927 ,  0.17160797,
#        -0.04777133,  0.3841263 ,  0.0235185 , -0.24437277], dtype=float32)

# %%
len(model['dog'])
# Out:
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# 64

# %%
model.most_similar('dog') # distance
# Out:
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('puppy', 0.8221297264099121),
#  ('sweeper', 0.8155755996704102),
#  ('cage', 0.7757616639137268),
#  ('kick', 0.7723021507263184),
#  ('chimney', 0.7696447372436523),
#  ('thief', 0.7598559856414795),
#  ('Tom', 0.7569286823272705),
#  ('pig', 0.7463473081588745),
#  ('lazy', 0.7433638572692871),
#  ('cannibal', 0.7425912022590637)]

# %%
model.most_similar('think')
# Out:
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('suppose', 0.861723780632019),
#  ('NOW', 0.8199707865715027),
#  ('manage', 0.8103471398353577),
#  ('awfully', 0.8060990571975708),
#  ('_you_', 0.80097496509552),
#  ('believe', 0.800645112991333),
#  ('know', 0.7978417277336121),
#  ('shouldn', 0.7934278249740601),
#  ('Selina', 0.7933170795440674),
#  ('mean', 0.7927958369255066)]

# %%
model.most_similar('day')
# Out:
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('morning', 0.7942497730255127),
#  ('night', 0.7935203313827515),
#  ('time', 0.7603916525840759),
#  ('evening', 0.7171837687492371),
#  ('month', 0.714638352394104),
#  ('week', 0.7027317881584167),
#  ('Saturday', 0.6730067729949951),
#  ('sabbath', 0.6709843277931213),
#  ('afternoon', 0.6573425531387329),
#  ('Early', 0.6549190282821655)]

# %%
model.most_similar('father')
# Out:
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('mother', 0.8461813926696777),
#  ('brother', 0.8353849053382874),
#  ('sister', 0.7708993554115295),
#  ('daughter', 0.7689160108566284),
#  ('wife', 0.7480056881904602),
#  ('Amnon', 0.7444391250610352),
#  ('concubine', 0.7402116060256958),
#  ('bondwoman', 0.7298697829246521),
#  ('younger', 0.7288893461227417),
#  ('uncle', 0.7269917726516724)]

# %%
model.most_similar('help')
# Out:
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('save', 0.754135012626648),
#  ('persuade', 0.7310070991516113),
#  ('betray', 0.7248772382736206),
#  ('quarrelled', 0.7216915488243103),
#  ('--`', 0.7194758653640747),
#  ('civilly', 0.7183911800384521),
#  ('hesitate', 0.7156596183776855),
#  ('deceive', 0.709246039390564),
#  ('sup', 0.7089089155197144),
#  ('stay', 0.7035971879959106)]

# %%
model.doesnt_match("mother father daughter dog".split())
# Out:
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `doesnt_match` (Method will be removed in 4.0.0, use self.wv.doesnt_match() instead).
#   """Entry point for launching an IPython kernel.
# 'dog'

# %%
model.similarity('father', 'dog')
# Out:
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   """Entry point for launching an IPython kernel.
# 0.4526254345943888

# %%
# close, but not quite; distinctly in female direction: 
model.most_similar(positive=['father', 'woman'], negative=['man'])
# Out:
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
# [('daughter', 0.7768922448158264),
#  ('mother', 0.7738335728645325),
#  ('sister', 0.7666959762573242),
#  ('wife', 0.7590457201004028),
#  ('husband', 0.7389540076255798),
#  ('brother', 0.7356401085853577),
#  ('child', 0.709202229976654),
#  ('Sarah', 0.7076252698898315),
#  ('Amnon', 0.6981574296951294),
#  ('daughters', 0.695275068283081)]

# %%
# more confident about this one: 
model.most_similar(positive=['son', 'woman'], negative=['man'])
# Out:
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
# [('daughter', 0.7216010689735413),
#  ('Leah', 0.7189501523971558),
#  ('wife', 0.7091480493545532),
#  ('Hagar', 0.6890485286712646),
#  ('Sarah', 0.6861205101013184),
#  ('brother', 0.674677312374115),
#  ('Rachel', 0.6736871004104614),
#  ('Bilhah', 0.6729787588119507),
#  ('Esau', 0.6713649034500122),
#  ('Hittite', 0.668331503868103)]

# %%
model.most_similar(positive=['husband', 'woman'], negative=['man'])
# Out:
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('wife', 0.7162677049636841),
#  ('sister', 0.7013059854507446),
#  ('child', 0.6835906505584717),
#  ('mother', 0.6808884143829346),
#  ('conceived', 0.6723538637161255),
#  ('daughter', 0.6689561009407043),
#  ('nurse', 0.6348733901977539),
#  ('widow', 0.6326421499252319),
#  ('Amnon', 0.6293679475784302),
#  ('daughters', 0.609796404838562)]

# %%
model.most_similar(positive=['king', 'woman'], negative=['man'], topn=30)
# Out:
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('Sarah', 0.7322282791137695),
#  ('Leah', 0.7138115167617798),
#  ('Judah', 0.6922429800033569),
#  ('Rachel', 0.6911393404006958),
#  ('Abram', 0.6850821375846863),
#  ('Hagar', 0.6809401512145996),
#  ('Laban', 0.6786673069000244),
#  ('Bilhah', 0.6726975440979004),
#  ('daughter', 0.6707599759101868),
#  ('Esau', 0.666330873966217),
#  ('Sarai', 0.6649512052536011),
#  ('Padanaram', 0.6633750200271606),
#  ('Hanun', 0.6633498668670654),
#  ('David', 0.6629506349563599),
#  ('queen', 0.6598349809646606),
#  ('birthright', 0.6588975191116333),
#  ('Zilpah', 0.6586890816688538),
#  ('Joseph', 0.6506704688072205),
#  ('Pharaoh', 0.6505971550941467),
#  ('Rebekah', 0.6503122448921204),
#  ('Babylon', 0.6495007276535034),
#  ('Bethuel', 0.6480889320373535),
#  ('Abimelech', 0.6441887021064758),
#  ('Onan', 0.6436560750007629),
#  ('Amnon', 0.6396293640136719),
#  ('conceived', 0.6387895941734314),
#  ('Solomon', 0.6385107636451721),
#  ('Samaria', 0.6383638381958008),
#  ('Balaam', 0.6368927955627441),
#  ('Jerubbaal', 0.6331923007965088)]

# %%
# impressive for such a small data set, without any cleaning, e.g., to lower case (covered next)

# %% [markdown]
# #### Reduce word vector dimensionality with t-SNE

# %%
model.wv.vocab
# Out:
# {'hurricane': <gensim.models.keyedvectors.Vocab at 0x1a21c514e0>,
#  'beef': <gensim.models.keyedvectors.Vocab at 0x1a21c51e80>,
#  'Caesars': <gensim.models.keyedvectors.Vocab at 0x1a21c51f60>,
#  'raised': <gensim.models.keyedvectors.Vocab at 0x1a21c51438>,
#  'hits': <gensim.models.keyedvectors.Vocab at 0x1a21c51cc0>,
#  'unfound': <gensim.models.keyedvectors.Vocab at 0x1a21c51588>,
#  'contrast': <gensim.models.keyedvectors.Vocab at 0x1a21c51d68>,
#  'instantaneous': <gensim.models.keyedvectors.Vocab at 0x1a21c51da0>,
#  'affectation': <gensim.models.keyedvectors.Vocab at 0x1a21c51198>,
#  'Lystra': <gensim.models.keyedvectors.Vocab at 0x1a21c516d8>,
#  'stifling': <gensim.models.keyedvectors.Vocab at 0x1a21c512b0>,
#  '38': <gensim.models.keyedvectors.Vocab at 0x1a21c51710>,
#  'ample': <gensim.models.keyedvectors.Vocab at 0x1a22173be0>,
#  'Archers': <gensim.models.keyedvectors.Vocab at 0x1a21c51160>,
#  'clouds': <gensim.models.keyedvectors.Vocab at 0x1a21c515f8>,
#  'merge': <gensim.models.keyedvectors.Vocab at 0x1a21c51518>,
#  'broke': <gensim.models.keyedvectors.Vocab at 0x1a1ee2aa20>,
#  'vibration': <gensim.models.keyedvectors.Vocab at 0x108d81e48>,
#  'pole': <gensim.models.keyedvectors.Vocab at 0x1a1ee2a160>,
#  'Jonas': <gensim.models.keyedvectors.Vocab at 0x1a1ee2ad30>,
#  'brown': <gensim.models.keyedvectors.Vocab at 0x1a1ee2af60>,
#  'robes': <gensim.models.keyedvectors.Vocab at 0x1a1ee2a940>,
#  'wisdom': <gensim.models.keyedvectors.Vocab at 0x1a1ee2a4e0>,
#  'spokes': <gensim.models.keyedvectors.Vocab at 0x1a1ee2a390>,
#  'justification': <gensim.models.keyedvectors.Vocab at 0x1a1ee2ae48>,
#  'regretted': <gensim.models.keyedvectors.Vocab at 0x1a221b0240>,
#  'sovereign': <gensim.models.keyedvectors.Vocab at 0x1a1ee2a438>,
#  'Horrible': <gensim.models.keyedvectors.Vocab at 0x1a2329af60>,
#  'hearty': <gensim.models.keyedvectors.Vocab at 0x1a1ee2ae10>,
#  'dined': <gensim.models.keyedvectors.Vocab at 0x1a1ee2a198>,
#  'softened': <gensim.models.keyedvectors.Vocab at 0x1a220e7fd0>,
#  'Arabia': <gensim.models.keyedvectors.Vocab at 0x1a221b9cc0>,
#  'reaches': <gensim.models.keyedvectors.Vocab at 0x1a221b9748>,
#  'Legions': <gensim.models.keyedvectors.Vocab at 0x1a221b98d0>,
#  'gulf': <gensim.models.keyedvectors.Vocab at 0x1a221b9e80>,
#  'hotter': <gensim.models.keyedvectors.Vocab at 0x1a221b9358>,
#  'Merlin': <gensim.models.keyedvectors.Vocab at 0x1a221b9f60>,
#  'Tarry': <gensim.models.keyedvectors.Vocab at 0x1a2315cb38>,
#  'Jehu': <gensim.models.keyedvectors.Vocab at 0x1a221b9668>,
#  'happen': <gensim.models.keyedvectors.Vocab at 0x1a221b95f8>,
#  'copies': <gensim.models.keyedvectors.Vocab at 0x1a221b9a58>,
#  'Ar': <gensim.models.keyedvectors.Vocab at 0x1a221b9278>,
#  'disagreeable': <gensim.models.keyedvectors.Vocab at 0x1a221b9be0>,
#  'wilds': <gensim.models.keyedvectors.Vocab at 0x1a221b9240>,
#  'endeavors': <gensim.models.keyedvectors.Vocab at 0x1a221b9080>,
#  'curl': <gensim.models.keyedvectors.Vocab at 0x1a221b9588>,
#  'naivete': <gensim.models.keyedvectors.Vocab at 0x1a221b92e8>,
#  'transgressed': <gensim.models.keyedvectors.Vocab at 0x1a1fd3b9e8>,
#  'forbidding': <gensim.models.keyedvectors.Vocab at 0x1a221b9ef0>,
#  'OTHER': <gensim.models.keyedvectors.Vocab at 0x1a221b9518>,
#  'final': <gensim.models.keyedvectors.Vocab at 0x1a221b9630>,
#  'change': <gensim.models.keyedvectors.Vocab at 0x1a221b9b38>,
#  'telleth': <gensim.models.keyedvectors.Vocab at 0x1a221b9550>,
#  'strides': <gensim.models.keyedvectors.Vocab at 0x108caf7f0>,
#  'knew': <gensim.models.keyedvectors.Vocab at 0x1a221b9c50>,
#  'planning': <gensim.models.keyedvectors.Vocab at 0x1a1fd3ba90>,
#  'thankful': <gensim.models.keyedvectors.Vocab at 0x108d7a470>,
#  'employments': <gensim.models.keyedvectors.Vocab at 0x1a1fc8e198>,
#  'practicable': <gensim.models.keyedvectors.Vocab at 0x1a221b9048>,
#  'griefe': <gensim.models.keyedvectors.Vocab at 0x1a221b9e10>,
#  'Niagara': <gensim.models.keyedvectors.Vocab at 0x1a221b9908>,
#  'careering': <gensim.models.keyedvectors.Vocab at 0x1a221b9c88>,
#  'mantle': <gensim.models.keyedvectors.Vocab at 0x1a221b9b00>,
#  'consented': <gensim.models.keyedvectors.Vocab at 0x1a221b9828>,
#  'conformity': <gensim.models.keyedvectors.Vocab at 0x1a221b9898>,
#  'Assyria': <gensim.models.keyedvectors.Vocab at 0x1a221b93c8>,
#  'peep': <gensim.models.keyedvectors.Vocab at 0x1a221b92b0>,
#  'guilt': <gensim.models.keyedvectors.Vocab at 0x1a1ee21208>,
#  'Whatever': <gensim.models.keyedvectors.Vocab at 0x1a1ee21b00>,
#  'Newington': <gensim.models.keyedvectors.Vocab at 0x1a1fdc6e48>,
#  'Author': <gensim.models.keyedvectors.Vocab at 0x1a1ee21c18>,
#  'engaging': <gensim.models.keyedvectors.Vocab at 0x1a1ee21eb8>,
#  'river': <gensim.models.keyedvectors.Vocab at 0x1a1ee21fd0>,
#  'differ': <gensim.models.keyedvectors.Vocab at 0x1a1ee212e8>,
#  'partakers': <gensim.models.keyedvectors.Vocab at 0x1a1ee216a0>,
#  'pines': <gensim.models.keyedvectors.Vocab at 0x1a1ee215f8>,
#  'atmospheres': <gensim.models.keyedvectors.Vocab at 0x1a232b2c88>,
#  'strolled': <gensim.models.keyedvectors.Vocab at 0x1a1ee21128>,
#  'mortar': <gensim.models.keyedvectors.Vocab at 0x1a1ee211d0>,
#  'spermaceti': <gensim.models.keyedvectors.Vocab at 0x1a1ee215c0>,
#  'involving': <gensim.models.keyedvectors.Vocab at 0x1a1ee21278>,
#  'posts': <gensim.models.keyedvectors.Vocab at 0x1a20c5a390>,
#  'morality': <gensim.models.keyedvectors.Vocab at 0x1a20c5a978>,
#  'Ebal': <gensim.models.keyedvectors.Vocab at 0x1a1ee70198>,
#  'actual': <gensim.models.keyedvectors.Vocab at 0x1a1ee70b00>,
#  'entering': <gensim.models.keyedvectors.Vocab at 0x1a1ee70d30>,
#  'naval': <gensim.models.keyedvectors.Vocab at 0x1a1ee70ac8>,
#  'Bruno': <gensim.models.keyedvectors.Vocab at 0x1a1ee70c88>,
#  'baby': <gensim.models.keyedvectors.Vocab at 0x1a1ee70518>,
#  'marking': <gensim.models.keyedvectors.Vocab at 0x1a1ee700b8>,
#  'misty': <gensim.models.keyedvectors.Vocab at 0x1a1ee709e8>,
#  'swung': <gensim.models.keyedvectors.Vocab at 0x1a1ee709b0>,
#  'miscellaneous': <gensim.models.keyedvectors.Vocab at 0x1a221c5cf8>,
#  'basis': <gensim.models.keyedvectors.Vocab at 0x1a21e1a588>,
#  'opaque': <gensim.models.keyedvectors.Vocab at 0x1a221b0cc0>,
#  'sporting': <gensim.models.keyedvectors.Vocab at 0x1a221b05f8>,
#  'George': <gensim.models.keyedvectors.Vocab at 0x1a1fda30f0>,
#  'cubic': <gensim.models.keyedvectors.Vocab at 0x1a221b02e8>,
#  'publicity': <gensim.models.keyedvectors.Vocab at 0x1a221b0160>,
#  'marvelled': <gensim.models.keyedvectors.Vocab at 0x1a221b0860>,
#  'Smallridge': <gensim.models.keyedvectors.Vocab at 0x1a221b0208>,
#  'shuddered': <gensim.models.keyedvectors.Vocab at 0x1a221b0a58>,
#  'seven': <gensim.models.keyedvectors.Vocab at 0x1a221b0710>,
#  'watery': <gensim.models.keyedvectors.Vocab at 0x1a1fd3bda0>,
#  'situation': <gensim.models.keyedvectors.Vocab at 0x1a221b04e0>,
#  'temporarily': <gensim.models.keyedvectors.Vocab at 0x1a221b0f28>,
#  'Looke': <gensim.models.keyedvectors.Vocab at 0x1a1fd3be10>,
#  'Naboth': <gensim.models.keyedvectors.Vocab at 0x1a221b0588>,
#  'imperious': <gensim.models.keyedvectors.Vocab at 0x1a221b0630>,
#  'wringing': <gensim.models.keyedvectors.Vocab at 0x1a221b07f0>,
#  'suspect': <gensim.models.keyedvectors.Vocab at 0x1a221b0278>,
#  'departing': <gensim.models.keyedvectors.Vocab at 0x1a221b0ef0>,
#  'merry': <gensim.models.keyedvectors.Vocab at 0x1a221b0be0>,
#  'Waves': <gensim.models.keyedvectors.Vocab at 0x1a221b0828>,
#  'spirit': <gensim.models.keyedvectors.Vocab at 0x1a221b09b0>,
#  'waxen': <gensim.models.keyedvectors.Vocab at 0x1a221b0908>,
#  'desperately': <gensim.models.keyedvectors.Vocab at 0x1a221b0358>,
#  'XVIII': <gensim.models.keyedvectors.Vocab at 0x1a221b0d30>,
#  'advised': <gensim.models.keyedvectors.Vocab at 0x1a221b0390>,
#  'sang': <gensim.models.keyedvectors.Vocab at 0x1a1fda3358>,
#  'sealed': <gensim.models.keyedvectors.Vocab at 0x1a221b00b8>,
#  'tuned': <gensim.models.keyedvectors.Vocab at 0x1a221b0048>,
#  'feverishly': <gensim.models.keyedvectors.Vocab at 0x1a221b00f0>,
#  'dusky': <gensim.models.keyedvectors.Vocab at 0x1a21e1a6d8>,
#  'THIS': <gensim.models.keyedvectors.Vocab at 0x1a221b0780>,
#  'willingness': <gensim.models.keyedvectors.Vocab at 0x1a221b0b00>,
#  'Straits': <gensim.models.keyedvectors.Vocab at 0x1a221b0e10>,
#  'tough': <gensim.models.keyedvectors.Vocab at 0x1a221b0080>,
#  'idle': <gensim.models.keyedvectors.Vocab at 0x1a221b01d0>,
#  'leak': <gensim.models.keyedvectors.Vocab at 0x1a1ee2ae80>,
#  'fresher': <gensim.models.keyedvectors.Vocab at 0x1a221b0e80>,
#  'outlandish': <gensim.models.keyedvectors.Vocab at 0x1a221b0eb8>,
#  'sulk': <gensim.models.keyedvectors.Vocab at 0x1a221b0898>,
#  'piped': <gensim.models.keyedvectors.Vocab at 0x1a221b0470>,
#  'roses': <gensim.models.keyedvectors.Vocab at 0x1a221ba2b0>,
#  'bronze': <gensim.models.keyedvectors.Vocab at 0x1a221ba438>,
#  'Gall': <gensim.models.keyedvectors.Vocab at 0x1a221baa90>,
#  'vilde': <gensim.models.keyedvectors.Vocab at 0x1a1ee2abe0>,
#  'torrents': <gensim.models.keyedvectors.Vocab at 0x1a221ba198>,
#  'detestable': <gensim.models.keyedvectors.Vocab at 0x1a221ba3c8>,
#  'victory': <gensim.models.keyedvectors.Vocab at 0x1a221bada0>,
#  'eruption': <gensim.models.keyedvectors.Vocab at 0x1a221ba278>,
#  'Gird': <gensim.models.keyedvectors.Vocab at 0x1a221ba780>,
#  'Everyone': <gensim.models.keyedvectors.Vocab at 0x1a221baef0>,
#  'ties': <gensim.models.keyedvectors.Vocab at 0x1a221bab38>,
#  'loops': <gensim.models.keyedvectors.Vocab at 0x1a1fd41128>,
#  'horrors': <gensim.models.keyedvectors.Vocab at 0x1a221bad30>,
#  'Devil': <gensim.models.keyedvectors.Vocab at 0x1a221ba4a8>,
#  'virtuous': <gensim.models.keyedvectors.Vocab at 0x1a1fd41160>,
#  'malady': <gensim.models.keyedvectors.Vocab at 0x1a221ba080>,
#  'already': <gensim.models.keyedvectors.Vocab at 0x1a221bab70>,
#  'regarded': <gensim.models.keyedvectors.Vocab at 0x1a221ba940>,
#  'WAS': <gensim.models.keyedvectors.Vocab at 0x1a221ba7f0>,
#  'shunned': <gensim.models.keyedvectors.Vocab at 0x1a22167198>,
#  '_had_': <gensim.models.keyedvectors.Vocab at 0x1a221ba2e8>,
#  'kindly': <gensim.models.keyedvectors.Vocab at 0x1a221ba320>,
#  'skulls': <gensim.models.keyedvectors.Vocab at 0x1a221baf98>,
#  'sincere': <gensim.models.keyedvectors.Vocab at 0x1a221bab00>,
#  'Cherry': <gensim.models.keyedvectors.Vocab at 0x1a221badd8>,
#  'galleries': <gensim.models.keyedvectors.Vocab at 0x1a221baa58>,
#  'i': <gensim.models.keyedvectors.Vocab at 0x1a221ba7b8>,
#  'artifice': <gensim.models.keyedvectors.Vocab at 0x1a221ba860>,
#  'bandstand': <gensim.models.keyedvectors.Vocab at 0x1a221baa20>,
#  'Mast': <gensim.models.keyedvectors.Vocab at 0x1a221ba978>,
#  'heart': <gensim.models.keyedvectors.Vocab at 0x1a221bae48>,
#  'Admiral': <gensim.models.keyedvectors.Vocab at 0x1a221ba240>,
#  'chariots': <gensim.models.keyedvectors.Vocab at 0x1a22173710>,
#  'borderland': <gensim.models.keyedvectors.Vocab at 0x1a22167f28>,
#  'entertain': <gensim.models.keyedvectors.Vocab at 0x1a22185da0>,
#  'diminished': <gensim.models.keyedvectors.Vocab at 0x1a22172438>,
#  'Leah': <gensim.models.keyedvectors.Vocab at 0x1a221bae80>,
#  'grip': <gensim.models.keyedvectors.Vocab at 0x1a221ba160>,
#  'human': <gensim.models.keyedvectors.Vocab at 0x1a221ba0f0>,
#  'cheating': <gensim.models.keyedvectors.Vocab at 0x1a22187f28>,
#  'Oakly': <gensim.models.keyedvectors.Vocab at 0x1a22187198>,
#  'sown': <gensim.models.keyedvectors.Vocab at 0x1a22187978>,
#  'cropped': <gensim.models.keyedvectors.Vocab at 0x1a221875c0>,
#  'mentioning': <gensim.models.keyedvectors.Vocab at 0x1a221873c8>,
#  'twig': <gensim.models.keyedvectors.Vocab at 0x1a221870f0>,
#  'Ramothgilead': <gensim.models.keyedvectors.Vocab at 0x1a2216bef0>,
#  'deemed': <gensim.models.keyedvectors.Vocab at 0x1a221872e8>,
#  'hooks': <gensim.models.keyedvectors.Vocab at 0x1a2202ecc0>,
#  'Knowest': <gensim.models.keyedvectors.Vocab at 0x1a1fd413c8>,
#  'originally': <gensim.models.keyedvectors.Vocab at 0x1a221c7780>,
#  'villains': <gensim.models.keyedvectors.Vocab at 0x1a221c7b70>,
#  'morter': <gensim.models.keyedvectors.Vocab at 0x1a220e93c8>,
#  'ostensible': <gensim.models.keyedvectors.Vocab at 0x1a221c74e0>,
#  'darkened': <gensim.models.keyedvectors.Vocab at 0x1a221c7630>,
#  'remarked': <gensim.models.keyedvectors.Vocab at 0x1a221c7be0>,
#  'cloak': <gensim.models.keyedvectors.Vocab at 0x1a220e98d0>,
#  'Rising': <gensim.models.keyedvectors.Vocab at 0x1a221c7f28>,
#  'rams': <gensim.models.keyedvectors.Vocab at 0x1a221c7e80>,
#  'utter': <gensim.models.keyedvectors.Vocab at 0x1a221c7080>,
#  'overshadowed': <gensim.models.keyedvectors.Vocab at 0x108cc4198>,
#  'Westgate': <gensim.models.keyedvectors.Vocab at 0x1a221c70f0>,
#  'overlay': <gensim.models.keyedvectors.Vocab at 0x108d7d4e0>,
#  'Portia': <gensim.models.keyedvectors.Vocab at 0x1a22173e10>,
#  'presence': <gensim.models.keyedvectors.Vocab at 0x1a221c7240>,
#  'neglected': <gensim.models.keyedvectors.Vocab at 0x1a220dd278>,
#  'vase': <gensim.models.keyedvectors.Vocab at 0x1a221c73c8>,
#  'stole': <gensim.models.keyedvectors.Vocab at 0x1a221c75f8>,
#  'moored': <gensim.models.keyedvectors.Vocab at 0x1a221c7470>,
#  'slates': <gensim.models.keyedvectors.Vocab at 0x1a221c7748>,
#  'gate': <gensim.models.keyedvectors.Vocab at 0x1a21e1af60>,
#  'kite': <gensim.models.keyedvectors.Vocab at 0x1a221c7c18>,
#  'landscapes': <gensim.models.keyedvectors.Vocab at 0x1a221c7ef0>,
#  'crumbs': <gensim.models.keyedvectors.Vocab at 0x1a221c77b8>,
#  'Villars': <gensim.models.keyedvectors.Vocab at 0x1a21e1a198>,
#  'broom': <gensim.models.keyedvectors.Vocab at 0x1a2215b2e8>,
#  'towards': <gensim.models.keyedvectors.Vocab at 0x1a221c7438>,
#  'prayeth': <gensim.models.keyedvectors.Vocab at 0x1a22086f60>,
#  'fatigues': <gensim.models.keyedvectors.Vocab at 0x1a221c7cf8>,
#  'ground': <gensim.models.keyedvectors.Vocab at 0x1a221c7518>,
#  'bewildering': <gensim.models.keyedvectors.Vocab at 0x1a1fda4ef0>,
#  'steak': <gensim.models.keyedvectors.Vocab at 0x1a221c7e48>,
#  'raging': <gensim.models.keyedvectors.Vocab at 0x1a221c7390>,
#  'aspiring': <gensim.models.keyedvectors.Vocab at 0x1a221c75c0>,
#  'moderately': <gensim.models.keyedvectors.Vocab at 0x1a221c7fd0>,
#  'Race': <gensim.models.keyedvectors.Vocab at 0x1a221c7d30>,
#  'mason': <gensim.models.keyedvectors.Vocab at 0x1a221c7898>,
#  'vertical': <gensim.models.keyedvectors.Vocab at 0x1a221c7b00>,
#  'callous': <gensim.models.keyedvectors.Vocab at 0x1a221c7f60>,
#  'multiplied': <gensim.models.keyedvectors.Vocab at 0x1a221c77f0>,
#  'individuality': <gensim.models.keyedvectors.Vocab at 0x1a221c7908>,
#  'nation': <gensim.models.keyedvectors.Vocab at 0x1a22033240>,
#  'fitted': <gensim.models.keyedvectors.Vocab at 0x1a21fbb240>,
#  'enabled': <gensim.models.keyedvectors.Vocab at 0x1a21fbb438>,
#  'overcome': <gensim.models.keyedvectors.Vocab at 0x1a21fbbb70>,
#  'passive': <gensim.models.keyedvectors.Vocab at 0x1a21fbbd68>,
#  'rul': <gensim.models.keyedvectors.Vocab at 0x1a21fbb7f0>,
#  'absorbing': <gensim.models.keyedvectors.Vocab at 0x1a21fbbb00>,
#  'comest': <gensim.models.keyedvectors.Vocab at 0x1a21fbbac8>,
#  'lumps': <gensim.models.keyedvectors.Vocab at 0x1a21fbb4e0>,
#  'pressed': <gensim.models.keyedvectors.Vocab at 0x1a21fbb160>,
#  'begging': <gensim.models.keyedvectors.Vocab at 0x1a21fbb0b8>,
#  'dishonour': <gensim.models.keyedvectors.Vocab at 0x1a21fbb048>,
#  'owing': <gensim.models.keyedvectors.Vocab at 0x1a21fbb748>,
#  'fearing': <gensim.models.keyedvectors.Vocab at 0x1a21fbbf60>,
#  'envelope': <gensim.models.keyedvectors.Vocab at 0x1a21fbb6d8>,
#  'Watching': <gensim.models.keyedvectors.Vocab at 0x1a21fbb9e8>,
#  'Turning': <gensim.models.keyedvectors.Vocab at 0x1a21fbb1d0>,
#  'ascertained': <gensim.models.keyedvectors.Vocab at 0x1a21fbb128>,
#  'aft': <gensim.models.keyedvectors.Vocab at 0x1a21fbbe10>,
#  'colds': <gensim.models.keyedvectors.Vocab at 0x1a21fbbe80>,
#  'eighteenth': <gensim.models.keyedvectors.Vocab at 0x1a21fbbfd0>,
#  'exchanged': <gensim.models.keyedvectors.Vocab at 0x1a21fbbf98>,
#  'fell': <gensim.models.keyedvectors.Vocab at 0x1a21fbb978>,
#  'glaring': <gensim.models.keyedvectors.Vocab at 0x1a21fbb780>,
#  'Adventures': <gensim.models.keyedvectors.Vocab at 0x1a21fbba20>,
#  'St': <gensim.models.keyedvectors.Vocab at 0x1a21fbbef0>,
#  'wooden': <gensim.models.keyedvectors.Vocab at 0x1a1fd41710>,
#  'knowne': <gensim.models.keyedvectors.Vocab at 0x1a21fbb470>,
#  'straps': <gensim.models.keyedvectors.Vocab at 0x1a2306d208>,
#  '119': <gensim.models.keyedvectors.Vocab at 0x1a2306d128>,
#  'mysterious': <gensim.models.keyedvectors.Vocab at 0x1a2306d160>,
#  'c': <gensim.models.keyedvectors.Vocab at 0x1a2306d320>,
#  'intermediate': <gensim.models.keyedvectors.Vocab at 0x1a2306d080>,
#  'Sound': <gensim.models.keyedvectors.Vocab at 0x1a2306d240>,
#  'infected': <gensim.models.keyedvectors.Vocab at 0x1a2306d198>,
#  'Diamond': <gensim.models.keyedvectors.Vocab at 0x1a2306d400>,
#  'discretion': <gensim.models.keyedvectors.Vocab at 0x1a2306d4a8>,
#  'Dalroy': <gensim.models.keyedvectors.Vocab at 0x1a2306d2b0>,
#  'Marry': <gensim.models.keyedvectors.Vocab at 0x1a2306d358>,
#  'wanted': <gensim.models.keyedvectors.Vocab at 0x1a2306d0f0>,
#  'winepress': <gensim.models.keyedvectors.Vocab at 0x1a2306d470>,
#  'received': <gensim.models.keyedvectors.Vocab at 0x1a2306dc88>,
#  'pitchers': <gensim.models.keyedvectors.Vocab at 0x1a2306dda0>,
#  'brings': <gensim.models.keyedvectors.Vocab at 0x1a2306db38>,
#  'heirs': <gensim.models.keyedvectors.Vocab at 0x1a2306dd30>,
#  'unawares': <gensim.models.keyedvectors.Vocab at 0x1a2306dbe0>,
#  'Lucius': <gensim.models.keyedvectors.Vocab at 0x1a2306dd68>,
#  'calves': <gensim.models.keyedvectors.Vocab at 0x1a2306df60>,
#  'tangle': <gensim.models.keyedvectors.Vocab at 0x1a2306deb8>,
#  'tails': <gensim.models.keyedvectors.Vocab at 0x1a2306de10>,
#  'Destroy': <gensim.models.keyedvectors.Vocab at 0x1a2306dcf8>,
#  'Sihon': <gensim.models.keyedvectors.Vocab at 0x1a2306d6d8>,
#  'bursting': <gensim.models.keyedvectors.Vocab at 0x1a2306df28>,
#  'Against': <gensim.models.keyedvectors.Vocab at 0x1a2306df98>,
#  'roads': <gensim.models.keyedvectors.Vocab at 0x1a220e7940>,
#  'craft': <gensim.models.keyedvectors.Vocab at 0x1a220e7240>,
#  ')--': <gensim.models.keyedvectors.Vocab at 0x1a220e7f98>,
#  'Sure': <gensim.models.keyedvectors.Vocab at 0x1a220e7cf8>,
#  'brig': <gensim.models.keyedvectors.Vocab at 0x1a2315c1d0>,
#  'merciful': <gensim.models.keyedvectors.Vocab at 0x1a220e7d30>,
#  'pleas': <gensim.models.keyedvectors.Vocab at 0x1a220e7358>,
#  'refuge': <gensim.models.keyedvectors.Vocab at 0x1a21c95a58>,
#  'might': <gensim.models.keyedvectors.Vocab at 0x1a220e72b0>,
#  'gratify': <gensim.models.keyedvectors.Vocab at 0x1a220e7160>,
#  'Simeon': <gensim.models.keyedvectors.Vocab at 0x1a220e7ef0>,
#  'undertake': <gensim.models.keyedvectors.Vocab at 0x1a220e7128>,
#  'affrighted': <gensim.models.keyedvectors.Vocab at 0x1a220e7080>,
#  'females': <gensim.models.keyedvectors.Vocab at 0x1a220e7550>,
#  'wiles': <gensim.models.keyedvectors.Vocab at 0x1a220e7be0>,
#  'exhaled': <gensim.models.keyedvectors.Vocab at 0x1a22033c88>,
#  'seeks': <gensim.models.keyedvectors.Vocab at 0x1a220e7048>,
#  'Syme': <gensim.models.keyedvectors.Vocab at 0x1a220e7e10>,
#  'securely': <gensim.models.keyedvectors.Vocab at 0x1a220e74e0>,
#  'chances': <gensim.models.keyedvectors.Vocab at 0x1a220e79b0>,
#  'brink': <gensim.models.keyedvectors.Vocab at 0x1a220e7780>,
#  'droop': <gensim.models.keyedvectors.Vocab at 0x1a220e7b00>,
#  'lay': <gensim.models.keyedvectors.Vocab at 0x1a220e7c18>,
#  'bind': <gensim.models.keyedvectors.Vocab at 0x1a220e7d68>,
#  'guise': <gensim.models.keyedvectors.Vocab at 0x1a220e79e8>,
#  'Greek': <gensim.models.keyedvectors.Vocab at 0x1a220e7cc0>,
#  'ancient': <gensim.models.keyedvectors.Vocab at 0x1a220e7320>,
#  'denies': <gensim.models.keyedvectors.Vocab at 0x1a220e78d0>,
#  'prior': <gensim.models.keyedvectors.Vocab at 0x1a220e7630>,
#  'examined': <gensim.models.keyedvectors.Vocab at 0x1a220e7ac8>,
#  'beastly': <gensim.models.keyedvectors.Vocab at 0x1a220e75c0>,
#  'studded': <gensim.models.keyedvectors.Vocab at 0x1a220e7f28>,
#  'exceeded': <gensim.models.keyedvectors.Vocab at 0x1a220e7eb8>,
#  'endangered': <gensim.models.keyedvectors.Vocab at 0x1a220e75f8>,
#  'slaying': <gensim.models.keyedvectors.Vocab at 0x1a220a5e10>,
#  'impassive': <gensim.models.keyedvectors.Vocab at 0x1a220a58d0>,
#  'BE': <gensim.models.keyedvectors.Vocab at 0x1a220a5b70>,
#  'carelessness': <gensim.models.keyedvectors.Vocab at 0x1a220a5cf8>,
#  'promised': <gensim.models.keyedvectors.Vocab at 0x1a220a5dd8>,
#  'Stay': <gensim.models.keyedvectors.Vocab at 0x1a2217b208>,
#  'poet': <gensim.models.keyedvectors.Vocab at 0x1a220a5c88>,
#  'barbed': <gensim.models.keyedvectors.Vocab at 0x1a220a5518>,
#  'Crab': <gensim.models.keyedvectors.Vocab at 0x1a220a57f0>,
#  'cease': <gensim.models.keyedvectors.Vocab at 0x1a220a5320>,
#  'greatness': <gensim.models.keyedvectors.Vocab at 0x1a220a5b38>,
#  'comes': <gensim.models.keyedvectors.Vocab at 0x1a1fc64a90>,
#  'soften': <gensim.models.keyedvectors.Vocab at 0x1a220a5c18>,
#  'diversion': <gensim.models.keyedvectors.Vocab at 0x1a220a5208>,
#  'tasting': <gensim.models.keyedvectors.Vocab at 0x1a220a52e8>,
#  '--': <gensim.models.keyedvectors.Vocab at 0x1a220a59e8>,
#  'snake': <gensim.models.keyedvectors.Vocab at 0x1a220a5048>,
#  'Cherubick': <gensim.models.keyedvectors.Vocab at 0x1a220a57b8>,
#  'string': <gensim.models.keyedvectors.Vocab at 0x1a220a5e48>,
#  'subjects': <gensim.models.keyedvectors.Vocab at 0x1a220a5630>,
#  'toiled': <gensim.models.keyedvectors.Vocab at 0x1a220a5ac8>,
#  'Laughing': <gensim.models.keyedvectors.Vocab at 0x1a220a50b8>,
#  'Goody': <gensim.models.keyedvectors.Vocab at 0x1a220a55f8>,
#  'glories': <gensim.models.keyedvectors.Vocab at 0x1a220a5748>,
#  'Equator': <gensim.models.keyedvectors.Vocab at 0x1a220a5d68>,
#  'I': <gensim.models.keyedvectors.Vocab at 0x1a220a5278>,
#  'vanity': <gensim.models.keyedvectors.Vocab at 0x1a220a52b0>,
#  'hoa': <gensim.models.keyedvectors.Vocab at 0x1a220a5828>,
#  'Psalms': <gensim.models.keyedvectors.Vocab at 0x1a220a5898>,
#  'belief': <gensim.models.keyedvectors.Vocab at 0x1a220a59b0>,
#  'Ser': <gensim.models.keyedvectors.Vocab at 0x1a220a5a20>,
#  'corpses': <gensim.models.keyedvectors.Vocab at 0x1a220a5908>,
#  'resentment': <gensim.models.keyedvectors.Vocab at 0x1a220a5128>,
#  'hump': <gensim.models.keyedvectors.Vocab at 0x1a220a55c0>,
#  'outrage': <gensim.models.keyedvectors.Vocab at 0x1a2215b4e0>,
#  'rather': <gensim.models.keyedvectors.Vocab at 0x1a220a5cc0>,
#  'nuptial': <gensim.models.keyedvectors.Vocab at 0x1a220a5b00>,
#  'Fleet': <gensim.models.keyedvectors.Vocab at 0x1a220a5358>,
#  'burnt': <gensim.models.keyedvectors.Vocab at 0x1a22fbca58>,
#  'thirds': <gensim.models.keyedvectors.Vocab at 0x1a21c28eb8>,
#  'parcels': <gensim.models.keyedvectors.Vocab at 0x1a21c28668>,
#  'cruel': <gensim.models.keyedvectors.Vocab at 0x1a21c28128>,
#  'confess': <gensim.models.keyedvectors.Vocab at 0x1a21df7828>,
#  'patron': <gensim.models.keyedvectors.Vocab at 0x1a21c28710>,
#  'tolerably': <gensim.models.keyedvectors.Vocab at 0x1a21c287b8>,
#  'restoring': <gensim.models.keyedvectors.Vocab at 0x1a21c28438>,
#  'Cicero': <gensim.models.keyedvectors.Vocab at 0x1a21c280b8>,
#  'chairman': <gensim.models.keyedvectors.Vocab at 0x1a1fcaf8d0>,
#  'Peter': <gensim.models.keyedvectors.Vocab at 0x1a21c28908>,
#  'Rocks': <gensim.models.keyedvectors.Vocab at 0x1a21c28198>,
#  'Shaphan': <gensim.models.keyedvectors.Vocab at 0x108d5d5f8>,
#  'Cato': <gensim.models.keyedvectors.Vocab at 0x1a21c283c8>,
#  'thirty': <gensim.models.keyedvectors.Vocab at 0x1a21c28208>,
#  'distributed': <gensim.models.keyedvectors.Vocab at 0x1a21c28080>,
#  'kissed': <gensim.models.keyedvectors.Vocab at 0x1a21c28b70>,
#  'dive': <gensim.models.keyedvectors.Vocab at 0x1a1fc61b00>,
#  'appeased': <gensim.models.keyedvectors.Vocab at 0x1a21c280f0>,
#  'foote': <gensim.models.keyedvectors.Vocab at 0x1a21c28dd8>,
#  'displeased': <gensim.models.keyedvectors.Vocab at 0x1a21c28358>,
#  'murther': <gensim.models.keyedvectors.Vocab at 0x1a21c28470>,
#  'handsome': <gensim.models.keyedvectors.Vocab at 0x1a21c282e8>,
#  'defileth': <gensim.models.keyedvectors.Vocab at 0x1a21c28048>,
#  'sharply': <gensim.models.keyedvectors.Vocab at 0x1a1ede0048>,
#  'Dubosc': <gensim.models.keyedvectors.Vocab at 0x1a1fd8b128>,
#  'goose': <gensim.models.keyedvectors.Vocab at 0x1a1ede7ef0>,
#  'attractive': <gensim.models.keyedvectors.Vocab at 0x1a1ede7898>,
#  'watch': <gensim.models.keyedvectors.Vocab at 0x1a1ede7048>,
#  'jackets': <gensim.models.keyedvectors.Vocab at 0x1a1fcb26d8>,
#  'enthusiasm': <gensim.models.keyedvectors.Vocab at 0x1a1ede7a58>,
#  'Ater': <gensim.models.keyedvectors.Vocab at 0x1a1ede77f0>,
#  'incumbent': <gensim.models.keyedvectors.Vocab at 0x1a1ede79b0>,
#  'forks': <gensim.models.keyedvectors.Vocab at 0x108ca62b0>,
#  'Accordingly': <gensim.models.keyedvectors.Vocab at 0x1a1ede72b0>,
#  'IT': <gensim.models.keyedvectors.Vocab at 0x1a1ede7320>,
#  'founder': <gensim.models.keyedvectors.Vocab at 0x1a1ede7c88>,
#  'Twice': <gensim.models.keyedvectors.Vocab at 0x1a1fd41f28>,
#  'won': <gensim.models.keyedvectors.Vocab at 0x1a1ede7668>,
#  'Folly': <gensim.models.keyedvectors.Vocab at 0x1a220e60f0>,
#  'gag': <gensim.models.keyedvectors.Vocab at 0x1a1ede7860>,
#  'sweep': <gensim.models.keyedvectors.Vocab at 0x1a1ede7208>,
#  'confirmed': <gensim.models.keyedvectors.Vocab at 0x1a1ede7588>,
#  'sentiments': <gensim.models.keyedvectors.Vocab at 0x1a1ede7198>,
#  'drives': <gensim.models.keyedvectors.Vocab at 0x1a1ede7eb8>,
#  'letters': <gensim.models.keyedvectors.Vocab at 0x1a21fbef98>,
#  'reproachfully': <gensim.models.keyedvectors.Vocab at 0x1a21fbe0f0>,
#  'Beautiful': <gensim.models.keyedvectors.Vocab at 0x1a21fbed68>,
#  'witnessed': <gensim.models.keyedvectors.Vocab at 0x1a21fbefd0>,
#  'singularly': <gensim.models.keyedvectors.Vocab at 0x1a21fbe198>,
#  'Rosamond': <gensim.models.keyedvectors.Vocab at 0x1a21fbe908>,
#  'cautious': <gensim.models.keyedvectors.Vocab at 0x1a21fbe358>,
#  'intricacies': <gensim.models.keyedvectors.Vocab at 0x1a21fbe4a8>,
#  'launched': <gensim.models.keyedvectors.Vocab at 0x1a21fbe048>,
#  'shooting': <gensim.models.keyedvectors.Vocab at 0x1a21fbec88>,
#  'tendency': <gensim.models.keyedvectors.Vocab at 0x1a21fbe2b0>,
#  'Scotchmen': <gensim.models.keyedvectors.Vocab at 0x1a21fbe4e0>,
#  'brit': <gensim.models.keyedvectors.Vocab at 0x1a21fbecc0>,
#  'consternation': <gensim.models.keyedvectors.Vocab at 0x1a21fbe898>,
#  'failure': <gensim.models.keyedvectors.Vocab at 0x1a21fbee10>,
#  'dexterous': <gensim.models.keyedvectors.Vocab at 0x1a21bd6f60>,
#  'kindness': <gensim.models.keyedvectors.Vocab at 0x1a21fbeef0>,
#  'consisting': <gensim.models.keyedvectors.Vocab at 0x1a21fbeb70>,
#  'Lands': <gensim.models.keyedvectors.Vocab at 0x1a21fbe550>,
#  'knelt': <gensim.models.keyedvectors.Vocab at 0x1a21fbe780>,
#  'bad': <gensim.models.keyedvectors.Vocab at 0x1a21fbed30>,
#  'Earth': <gensim.models.keyedvectors.Vocab at 0x1a21fbea58>,
#  'bends': <gensim.models.keyedvectors.Vocab at 0x1a21fbe8d0>,
#  'transition': <gensim.models.keyedvectors.Vocab at 0x1a21fbef28>,
#  'attention': <gensim.models.keyedvectors.Vocab at 0x1a21fbe518>,
#  'thinkers': <gensim.models.keyedvectors.Vocab at 0x1a21fbe3c8>,
#  'chariot': <gensim.models.keyedvectors.Vocab at 0x1a21bef518>,
#  'Sacrifice': <gensim.models.keyedvectors.Vocab at 0x1a21bef7f0>,
#  'whalemen': <gensim.models.keyedvectors.Vocab at 0x1a21bef048>,
#  'lies': <gensim.models.keyedvectors.Vocab at 0x1a221afa20>,
#  'vigil': <gensim.models.keyedvectors.Vocab at 0x1a21bef630>,
#  'Sussex': <gensim.models.keyedvectors.Vocab at 0x1a21bef9e8>,
#  'handful': <gensim.models.keyedvectors.Vocab at 0x1a21befa90>,
#  'ghostly': <gensim.models.keyedvectors.Vocab at 0x1a22172780>,
#  'Dame': <gensim.models.keyedvectors.Vocab at 0x1a21bef8d0>,
#  'praised': <gensim.models.keyedvectors.Vocab at 0x1a21bef828>,
#  'decent': <gensim.models.keyedvectors.Vocab at 0x1a21befb70>,
#  'Meadows': <gensim.models.keyedvectors.Vocab at 0x1a21bef320>,
#  'vista': <gensim.models.keyedvectors.Vocab at 0x1a21bef860>,
#  'limbs': <gensim.models.keyedvectors.Vocab at 0x1a22fe57b8>,
#  'thought': <gensim.models.keyedvectors.Vocab at 0x1a21bef3c8>,
#  'classification': <gensim.models.keyedvectors.Vocab at 0x1a21beffd0>,
#  'flowery': <gensim.models.keyedvectors.Vocab at 0x1a2218ebe0>,
#  'Dishon': <gensim.models.keyedvectors.Vocab at 0x1a2218e390>,
#  'peg': <gensim.models.keyedvectors.Vocab at 0x1a2218ea58>,
#  'slip': <gensim.models.keyedvectors.Vocab at 0x1a2218ee80>,
#  'axe': <gensim.models.keyedvectors.Vocab at 0x1a2218ee10>,
#  'surely': <gensim.models.keyedvectors.Vocab at 0x1a2218e0b8>,
#  'accuse': <gensim.models.keyedvectors.Vocab at 0x1a2218eeb8>,
#  'Rosetta': <gensim.models.keyedvectors.Vocab at 0x1a220c4898>,
#  'Damascus': <gensim.models.keyedvectors.Vocab at 0x1a2216ecc0>,
#  'sell': <gensim.models.keyedvectors.Vocab at 0x1a2216e588>,
#  'played': <gensim.models.keyedvectors.Vocab at 0x1a1ee66748>,
#  'restored': <gensim.models.keyedvectors.Vocab at 0x108d5dd68>,
#  'whereupon': <gensim.models.keyedvectors.Vocab at 0x1a1fd451d0>,
#  'grass': <gensim.models.keyedvectors.Vocab at 0x1a2216e358>,
#  'variation': <gensim.models.keyedvectors.Vocab at 0x1a2216e780>,
#  'Tabor': <gensim.models.keyedvectors.Vocab at 0x1a2216e1d0>,
#  'Catholics': <gensim.models.keyedvectors.Vocab at 0x1a1fc6aa90>,
#  'Libertad': <gensim.models.keyedvectors.Vocab at 0x1a2216edd8>,
#  'former': <gensim.models.keyedvectors.Vocab at 0x1a2216e898>,
#  'revolved': <gensim.models.keyedvectors.Vocab at 0x1a2216e668>,
#  'modified': <gensim.models.keyedvectors.Vocab at 0x1a2216e860>,
#  'Florida': <gensim.models.keyedvectors.Vocab at 0x1a2216e4e0>,
#  'pages': <gensim.models.keyedvectors.Vocab at 0x1a2216e940>,
#  'Quick': <gensim.models.keyedvectors.Vocab at 0x1a2216e6a0>,
#  'monotonous': <gensim.models.keyedvectors.Vocab at 0x1a2216e518>,
#  'worshippeth': <gensim.models.keyedvectors.Vocab at 0x1a2216e048>,
#  'Norway': <gensim.models.keyedvectors.Vocab at 0x1a2216ec50>,
#  'physical': <gensim.models.keyedvectors.Vocab at 0x1a2216e208>,
#  'dove': <gensim.models.keyedvectors.Vocab at 0x1a2216ec88>,
#  'comfortable': <gensim.models.keyedvectors.Vocab at 0x1a2216eba8>,
#  'vulgar': <gensim.models.keyedvectors.Vocab at 0x1a2216eb38>,
#  'plaited': <gensim.models.keyedvectors.Vocab at 0x1a2216e0b8>,
#  'Gaal': <gensim.models.keyedvectors.Vocab at 0x1a2216e160>,
#  'esteemed': <gensim.models.keyedvectors.Vocab at 0x1a2216eeb8>,
#  'Flag': <gensim.models.keyedvectors.Vocab at 0x1a2216e240>,
#  'Tragedie': <gensim.models.keyedvectors.Vocab at 0x1a232b2f28>,
#  'rockets': <gensim.models.keyedvectors.Vocab at 0x1a2216e390>,
#  'assist': <gensim.models.keyedvectors.Vocab at 0x1a2216ebe0>,
#  'persisting': <gensim.models.keyedvectors.Vocab at 0x1a2216e710>,
#  'drave': <gensim.models.keyedvectors.Vocab at 0x1a2216ee80>,
#  'idiot': <gensim.models.keyedvectors.Vocab at 0x1a2216ecf8>,
#  'Chittim': <gensim.models.keyedvectors.Vocab at 0x1a2216e630>,
#  'critters': <gensim.models.keyedvectors.Vocab at 0x1a2216e9e8>,
#  'hotels': <gensim.models.keyedvectors.Vocab at 0x1a2216eb00>,
#  'Rephaiah': <gensim.models.keyedvectors.Vocab at 0x1a2216ef60>,
#  'suspension': <gensim.models.keyedvectors.Vocab at 0x1a2216ef28>,
#  'Besides': <gensim.models.keyedvectors.Vocab at 0x1a2216e2b0>,
#  'Sail': <gensim.models.keyedvectors.Vocab at 0x1a21d5f048>,
#  'bitten': <gensim.models.keyedvectors.Vocab at 0x1a21d5f588>,
#  'arctic': <gensim.models.keyedvectors.Vocab at 0x1a21d5fef0>,
#  'drowsy': <gensim.models.keyedvectors.Vocab at 0x1a21d5fb00>,
#  'exhort': <gensim.models.keyedvectors.Vocab at 0x1a21d5f438>,
#  'Sooth': <gensim.models.keyedvectors.Vocab at 0x1a21d5fdd8>,
#  'float': <gensim.models.keyedvectors.Vocab at 0x1a21d5fb70>,
#  'J': <gensim.models.keyedvectors.Vocab at 0x1a21d5f9b0>,
#  'climbing': <gensim.models.keyedvectors.Vocab at 0x1a21d5f908>,
#  'woeful': <gensim.models.keyedvectors.Vocab at 0x1a21d5f780>,
#  'hats': <gensim.models.keyedvectors.Vocab at 0x1a21d5fa20>,
#  'yielding': <gensim.models.keyedvectors.Vocab at 0x1a220c4128>,
#  'fanciful': <gensim.models.keyedvectors.Vocab at 0x1a21d5f0b8>,
#  'conflict': <gensim.models.keyedvectors.Vocab at 0x1a21d5fa58>,
#  'Emperor': <gensim.models.keyedvectors.Vocab at 0x1a21d5f0f0>,
#  'polite': <gensim.models.keyedvectors.Vocab at 0x1a1fd455c0>,
#  'detained': <gensim.models.keyedvectors.Vocab at 0x1a21d5f5c0>,
#  'assure': <gensim.models.keyedvectors.Vocab at 0x1a21d5ffd0>,
#  'killed': <gensim.models.keyedvectors.Vocab at 0x1a21d5fe80>,
#  'Into': <gensim.models.keyedvectors.Vocab at 0x1a21d5f198>,
#  'purchase': <gensim.models.keyedvectors.Vocab at 0x1a1edea4a8>,
#  'Only': <gensim.models.keyedvectors.Vocab at 0x1a1edea400>,
#  'difference': <gensim.models.keyedvectors.Vocab at 0x1a1edea320>,
#  'collar': <gensim.models.keyedvectors.Vocab at 0x1a1edea9b0>,
#  'Heard': <gensim.models.keyedvectors.Vocab at 0x1a1edea240>,
#  'shouts': <gensim.models.keyedvectors.Vocab at 0x1a1edea4e0>,
#  'endued': <gensim.models.keyedvectors.Vocab at 0x1a1edea7f0>,
#  'inferiority': <gensim.models.keyedvectors.Vocab at 0x1a1edeab70>,
#  'tastes': <gensim.models.keyedvectors.Vocab at 0x108c1b668>,
#  'standards': <gensim.models.keyedvectors.Vocab at 0x1a1edeab38>,
#  'every': <gensim.models.keyedvectors.Vocab at 0x1a1edea748>,
#  'average': <gensim.models.keyedvectors.Vocab at 0x1a221c5438>,
#  'fish': <gensim.models.keyedvectors.Vocab at 0x1a221c5c88>,
#  'cooled': <gensim.models.keyedvectors.Vocab at 0x1a221c5f60>,
#  'flattereth': <gensim.models.keyedvectors.Vocab at 0x1a221c54e0>,
#  'sounds': <gensim.models.keyedvectors.Vocab at 0x1a221c5470>,
#  'Joy': <gensim.models.keyedvectors.Vocab at 0x1a221c5b38>,
#  '105': <gensim.models.keyedvectors.Vocab at 0x1a221c56a0>,
#  'ocean': <gensim.models.keyedvectors.Vocab at 0x1a221c5320>,
#  'religious': <gensim.models.keyedvectors.Vocab at 0x1a1fd45780>,
#  'defile': <gensim.models.keyedvectors.Vocab at 0x1a1ee70978>,
#  'threshingfloor': <gensim.models.keyedvectors.Vocab at 0x1a221c5a58>,
#  'Cetology': <gensim.models.keyedvectors.Vocab at 0x1a221c5ac8>,
#  'joint': <gensim.models.keyedvectors.Vocab at 0x1a221c5be0>,
#  'luminous': <gensim.models.keyedvectors.Vocab at 0x1a221c58d0>,
#  'hoar': <gensim.models.keyedvectors.Vocab at 0x1a221c5860>,
#  'flats': <gensim.models.keyedvectors.Vocab at 0x1a221c52b0>,
#  'industry': <gensim.models.keyedvectors.Vocab at 0x1a221bfc50>,
#  'Thenceforth': <gensim.models.keyedvectors.Vocab at 0x1a221c5128>,
#  'Lost': <gensim.models.keyedvectors.Vocab at 0x1a221c5390>,
#  'cant': <gensim.models.keyedvectors.Vocab at 0x1a221c59e8>,
#  'faulty': <gensim.models.keyedvectors.Vocab at 0x1a221c5f28>,
#  'congratulations': <gensim.models.keyedvectors.Vocab at 0x1a221c5cc0>,
#  'blood': <gensim.models.keyedvectors.Vocab at 0x1a221c5a20>,
#  'forge': <gensim.models.keyedvectors.Vocab at 0x1a221c5c50>,
#  'scud': <gensim.models.keyedvectors.Vocab at 0x108c9de10>,
#  'valley': <gensim.models.keyedvectors.Vocab at 0x1a221c5668>,
#  'institution': <gensim.models.keyedvectors.Vocab at 0x1a221c5748>,
#  'brutal': <gensim.models.keyedvectors.Vocab at 0x1a1fcb2908>,
#  'apartments': <gensim.models.keyedvectors.Vocab at 0x1a221c57b8>,
#  'Nights': <gensim.models.keyedvectors.Vocab at 0x1a221c5eb8>,
#  'brothers': <gensim.models.keyedvectors.Vocab at 0x1a221c5550>,
#  'whether': <gensim.models.keyedvectors.Vocab at 0x1a221c5898>,
#  'eminence': <gensim.models.keyedvectors.Vocab at 0x1a221c50f0>,
#  'wantonness': <gensim.models.keyedvectors.Vocab at 0x1a221c5588>,
#  'Good': <gensim.models.keyedvectors.Vocab at 0x1a22fbc128>,
#  'shamed': <gensim.models.keyedvectors.Vocab at 0x1a221c5208>,
#  'stretch': <gensim.models.keyedvectors.Vocab at 0x1a221c57f0>,
#  'diamond': <gensim.models.keyedvectors.Vocab at 0x1a221c5160>,
#  'move': <gensim.models.keyedvectors.Vocab at 0x1a221c5a90>,
#  'discussion': <gensim.models.keyedvectors.Vocab at 0x1a221c5d68>,
#  'Sion': <gensim.models.keyedvectors.Vocab at 0x1a22012d68>,
#  'perchance': <gensim.models.keyedvectors.Vocab at 0x1a22186780>,
#  'blockhead': <gensim.models.keyedvectors.Vocab at 0x1a221862b0>,
#  'fortnight': <gensim.models.keyedvectors.Vocab at 0x1a221864e0>,
#  'Palmers': <gensim.models.keyedvectors.Vocab at 0x1a22186320>,
#  'illusion': <gensim.models.keyedvectors.Vocab at 0x1a22186d30>,
#  'Meremoth': <gensim.models.keyedvectors.Vocab at 0x1a22186eb8>,
#  'subtilty': <gensim.models.keyedvectors.Vocab at 0x1a220c47b8>,
#  'important': <gensim.models.keyedvectors.Vocab at 0x1a22186390>,
#  'detaining': <gensim.models.keyedvectors.Vocab at 0x1a221861d0>,
#  'incapable': <gensim.models.keyedvectors.Vocab at 0x1a221860b8>,
#  'Jordan': <gensim.models.keyedvectors.Vocab at 0x1a2207fd68>,
#  'Caes': <gensim.models.keyedvectors.Vocab at 0x1a22186668>,
#  'butter': <gensim.models.keyedvectors.Vocab at 0x1a22186828>,
#  'Zoan': <gensim.models.keyedvectors.Vocab at 0x1a22fdd358>,
#  'malicious': <gensim.models.keyedvectors.Vocab at 0x1a22186ac8>,
#  'trieth': <gensim.models.keyedvectors.Vocab at 0x1a22186630>,
#  'ranke': <gensim.models.keyedvectors.Vocab at 0x1a22186080>,
#  'enmity': <gensim.models.keyedvectors.Vocab at 0x1a221867b8>,
#  'plumed': <gensim.models.keyedvectors.Vocab at 0x1a221865f8>,
#  'opens': <gensim.models.keyedvectors.Vocab at 0x1a22186f60>,
#  'Gaius': <gensim.models.keyedvectors.Vocab at 0x1a22186ef0>,
#  'prolonged': <gensim.models.keyedvectors.Vocab at 0x1a22186710>,
#  'itself': <gensim.models.keyedvectors.Vocab at 0x1a22186be0>,
#  'accommodate': <gensim.models.keyedvectors.Vocab at 0x1a220c4978>,
#  'chastisement': <gensim.models.keyedvectors.Vocab at 0x1a22186f28>,
#  'Mouse': <gensim.models.keyedvectors.Vocab at 0x1a22186588>,
#  'Amorite': <gensim.models.keyedvectors.Vocab at 0x1a22186d68>,
#  '142': <gensim.models.keyedvectors.Vocab at 0x1a22186198>,
#  'Araunah': <gensim.models.keyedvectors.Vocab at 0x1a22186ba8>,
#  'pleaded': <gensim.models.keyedvectors.Vocab at 0x1a22186908>,
#  'potato': <gensim.models.keyedvectors.Vocab at 0x1a220c4a20>,
#  'antique': <gensim.models.keyedvectors.Vocab at 0x1a22186da0>,
#  'distrustful': <gensim.models.keyedvectors.Vocab at 0x108d966d8>,
#  'consort': <gensim.models.keyedvectors.Vocab at 0x1a221866a0>,
#  'Blood': <gensim.models.keyedvectors.Vocab at 0x1a22186b38>,
#  'Capitoll': <gensim.models.keyedvectors.Vocab at 0x1a22186e48>,
#  'wheeled': <gensim.models.keyedvectors.Vocab at 0x1a22186fd0>,
#  'aforetime': <gensim.models.keyedvectors.Vocab at 0x1a1fd45b70>,
#  'preaching': <gensim.models.keyedvectors.Vocab at 0x1a22186048>,
#  'fifteen': <gensim.models.keyedvectors.Vocab at 0x1a22186550>,
#  'affront': <gensim.models.keyedvectors.Vocab at 0x1a221980f0>,
#  'sallow': <gensim.models.keyedvectors.Vocab at 0x1a221988d0>,
#  'persecutors': <gensim.models.keyedvectors.Vocab at 0x1a22198b38>,
#  'restrained': <gensim.models.keyedvectors.Vocab at 0x1a22198d30>,
#  'drench': <gensim.models.keyedvectors.Vocab at 0x1a22198c18>,
#  'Elimelech': <gensim.models.keyedvectors.Vocab at 0x1a22198e48>,
#  'ease': <gensim.models.keyedvectors.Vocab at 0x1a22198400>,
#  'blush': <gensim.models.keyedvectors.Vocab at 0x1a22198ef0>,
#  'mortall': <gensim.models.keyedvectors.Vocab at 0x1a221b6ac8>,
#  'Alabama': <gensim.models.keyedvectors.Vocab at 0x1a221985f8>,
#  'foretold': <gensim.models.keyedvectors.Vocab at 0x1a22198be0>,
#  'contemplation': <gensim.models.keyedvectors.Vocab at 0x1a221985c0>,
#  'billiard': <gensim.models.keyedvectors.Vocab at 0x1a22198cf8>,
#  'stubble': <gensim.models.keyedvectors.Vocab at 0x1a221989e8>,
#  'bosom': <gensim.models.keyedvectors.Vocab at 0x1a221987b8>,
#  'frost': <gensim.models.keyedvectors.Vocab at 0x1a2219a2e8>,
#  'up': <gensim.models.keyedvectors.Vocab at 0x1a22198908>,
#  'trio': <gensim.models.keyedvectors.Vocab at 0x1a22198588>,
#  'worshippers': <gensim.models.keyedvectors.Vocab at 0x1a22198c88>,
#  'speakest': <gensim.models.keyedvectors.Vocab at 0x1a221987f0>,
#  'hug': <gensim.models.keyedvectors.Vocab at 0x1a221bbb70>,
#  'cheers': <gensim.models.keyedvectors.Vocab at 0x1a22119240>,
#  'chastised': <gensim.models.keyedvectors.Vocab at 0x1a1fd45c18>,
#  'castaways': <gensim.models.keyedvectors.Vocab at 0x1a22119630>,
#  'reapers': <gensim.models.keyedvectors.Vocab at 0x1a221199e8>,
#  'Rather': <gensim.models.keyedvectors.Vocab at 0x1a22119208>,
#  'fable': <gensim.models.keyedvectors.Vocab at 0x1a22119470>,
#  'regularity': <gensim.models.keyedvectors.Vocab at 0x1a1fc64be0>,
#  'urging': <gensim.models.keyedvectors.Vocab at 0x1a22119d30>,
#  'plot': <gensim.models.keyedvectors.Vocab at 0x1a22119550>,
#  'Horonaim': <gensim.models.keyedvectors.Vocab at 0x1a22119198>,
#  'throughout': <gensim.models.keyedvectors.Vocab at 0x1a22119588>,
#  'nautical': <gensim.models.keyedvectors.Vocab at 0x1a221197f0>,
#  'gorgeous': <gensim.models.keyedvectors.Vocab at 0x1a22119390>,
#  'ripe': <gensim.models.keyedvectors.Vocab at 0x1a22119be0>,
#  'child': <gensim.models.keyedvectors.Vocab at 0x1a22119eb8>,
#  'request': <gensim.models.keyedvectors.Vocab at 0x1a22119f28>,
#  'towering': <gensim.models.keyedvectors.Vocab at 0x1a2315f860>,
#  'aimed': <gensim.models.keyedvectors.Vocab at 0x1a22119da0>,
#  'support': <gensim.models.keyedvectors.Vocab at 0x1a22119940>,
#  'legend': <gensim.models.keyedvectors.Vocab at 0x1a22119048>,
#  'idiotic': <gensim.models.keyedvectors.Vocab at 0x1a22119128>,
#  'nerve': <gensim.models.keyedvectors.Vocab at 0x1a221192e8>,
#  'Her': <gensim.models.keyedvectors.Vocab at 0x1a1fd45cf8>,
#  'elderly': <gensim.models.keyedvectors.Vocab at 0x1a22119cc0>,
#  'behinde': <gensim.models.keyedvectors.Vocab at 0x1a22119f98>,
#  'hauled': <gensim.models.keyedvectors.Vocab at 0x1a1fc61080>,
#  'eras': <gensim.models.keyedvectors.Vocab at 0x1a1fd8e198>,
#  'Edomites': <gensim.models.keyedvectors.Vocab at 0x1a220c1c88>,
#  ',': <gensim.models.keyedvectors.Vocab at 0x1a22119f60>,
#  'lambent': <gensim.models.keyedvectors.Vocab at 0x1a221192b0>,
#  'overseers': <gensim.models.keyedvectors.Vocab at 0x1a22119ef0>,
#  'notched': <gensim.models.keyedvectors.Vocab at 0x1a22119c18>,
#  'EVEN': <gensim.models.keyedvectors.Vocab at 0x1a221196a0>,
#  'detest': <gensim.models.keyedvectors.Vocab at 0x1a1fd8e208>,
#  'fathoms': <gensim.models.keyedvectors.Vocab at 0x1a22119a58>,
#  'Fran': <gensim.models.keyedvectors.Vocab at 0x1a22119c50>,
#  'needle': <gensim.models.keyedvectors.Vocab at 0x1a22119780>,
#  'talkative': <gensim.models.keyedvectors.Vocab at 0x1a22119a90>,
#  'odious': <gensim.models.keyedvectors.Vocab at 0x1a221195c0>,
#  'MacNab': <gensim.models.keyedvectors.Vocab at 0x1a221198d0>,
#  'starve': <gensim.models.keyedvectors.Vocab at 0x1a221196d8>,
#  'blindness': <gensim.models.keyedvectors.Vocab at 0x1a22119ac8>,
#  'sullenly': <gensim.models.keyedvectors.Vocab at 0x1a221199b0>,
#  'familiarity': <gensim.models.keyedvectors.Vocab at 0x1a1fc52128>,
#  'poem': <gensim.models.keyedvectors.Vocab at 0x1a2303e048>,
#  'shall': <gensim.models.keyedvectors.Vocab at 0x1a220c4198>,
#  'Sabbath': <gensim.models.keyedvectors.Vocab at 0x1a2303e1d0>,
#  'part': <gensim.models.keyedvectors.Vocab at 0x1a2303e278>,
#  'formless': <gensim.models.keyedvectors.Vocab at 0x1a2303e2b0>,
#  'shouting': <gensim.models.keyedvectors.Vocab at 0x1a2303e160>,
#  'hoped': <gensim.models.keyedvectors.Vocab at 0x1a2303e240>,
#  'cleansing': <gensim.models.keyedvectors.Vocab at 0x1a2303e0b8>,
#  'groves': <gensim.models.keyedvectors.Vocab at 0x1a22001da0>,
#  'there': <gensim.models.keyedvectors.Vocab at 0x1a22001278>,
#  'Messiah': <gensim.models.keyedvectors.Vocab at 0x1a220010b8>,
#  'jealous': <gensim.models.keyedvectors.Vocab at 0x1a22001668>,
#  'fishermen': <gensim.models.keyedvectors.Vocab at 0x1a220012b0>,
#  'HOW': <gensim.models.keyedvectors.Vocab at 0x1a22001f60>,
#  'pockets': <gensim.models.keyedvectors.Vocab at 0x1a22001780>,
#  'awaked': <gensim.models.keyedvectors.Vocab at 0x1a22001630>,
#  'Ryan': <gensim.models.keyedvectors.Vocab at 0x1a1fc88278>,
#  'Honourable': <gensim.models.keyedvectors.Vocab at 0x1a220019e8>,
#  'hallowed': <gensim.models.keyedvectors.Vocab at 0x1a22001ac8>,
#  'rope': <gensim.models.keyedvectors.Vocab at 0x1a220d78d0>,
#  'folding': <gensim.models.keyedvectors.Vocab at 0x1a22001be0>,
#  'dab': <gensim.models.keyedvectors.Vocab at 0x1a220d7be0>,
#  'sharks': <gensim.models.keyedvectors.Vocab at 0x1a22001b70>,
#  'blinded': <gensim.models.keyedvectors.Vocab at 0x1a22001748>,
#  'sergeant': <gensim.models.keyedvectors.Vocab at 0x1a220017f0>,
#  'melon': <gensim.models.keyedvectors.Vocab at 0x1a22001e10>,
#  'ribbons': <gensim.models.keyedvectors.Vocab at 0x1a220aa400>,
#  '141': <gensim.models.keyedvectors.Vocab at 0x1a22001198>,
#  'Belshazzar': <gensim.models.keyedvectors.Vocab at 0x1a221655c0>,
#  'Talk': <gensim.models.keyedvectors.Vocab at 0x1a22001588>,
#  'footstool': <gensim.models.keyedvectors.Vocab at 0x1a22001860>,
#  'zone': <gensim.models.keyedvectors.Vocab at 0x1a22001b00>,
#  'Considering': <gensim.models.keyedvectors.Vocab at 0x1a220d7cf8>,
#  'floor': <gensim.models.keyedvectors.Vocab at 0x1a23178ef0>,
#  'myth': <gensim.models.keyedvectors.Vocab at 0x1a22001390>,
#  'Polonius': <gensim.models.keyedvectors.Vocab at 0x1a1fc8e080>,
#  'Undoubtedly': <gensim.models.keyedvectors.Vocab at 0x1a22001d68>,
#  'formation': <gensim.models.keyedvectors.Vocab at 0x1a22001a90>,
#  'endless': <gensim.models.keyedvectors.Vocab at 0x1a22001e48>,
#  'edition': <gensim.models.keyedvectors.Vocab at 0x1a21c267f0>,
#  'cooler': <gensim.models.keyedvectors.Vocab at 0x1a21c261d0>,
#  'cabman': <gensim.models.keyedvectors.Vocab at 0x1a21c263c8>,
#  'Except': <gensim.models.keyedvectors.Vocab at 0x1a1fd8e400>,
#  'lieutenants': <gensim.models.keyedvectors.Vocab at 0x1a21c269e8>,
#  'anguish': <gensim.models.keyedvectors.Vocab at 0x1a22165f28>,
#  'off': <gensim.models.keyedvectors.Vocab at 0x1a21c26d68>,
#  'including': <gensim.models.keyedvectors.Vocab at 0x1a22171cf8>,
#  'islands': <gensim.models.keyedvectors.Vocab at 0x1a21c26a58>,
#  'Woodpecker': <gensim.models.keyedvectors.Vocab at 0x1a22165e10>,
#  'muddy': <gensim.models.keyedvectors.Vocab at 0x1a21c265c0>,
#  'Nonsense': <gensim.models.keyedvectors.Vocab at 0x1a21bf53c8>,
#  'madman': <gensim.models.keyedvectors.Vocab at 0x1a21c26668>,
#  'before': <gensim.models.keyedvectors.Vocab at 0x1a21c26be0>,
#  'Felix': <gensim.models.keyedvectors.Vocab at 0x1a21c260f0>,
#  'soldiers': <gensim.models.keyedvectors.Vocab at 0x1a21c262b0>,
#  'item': <gensim.models.keyedvectors.Vocab at 0x1a21c26fd0>,
#  'lashed': <gensim.models.keyedvectors.Vocab at 0x1a21c26048>,
#  'Blow': <gensim.models.keyedvectors.Vocab at 0x1a1fd45f28>,
#  'profitable': <gensim.models.keyedvectors.Vocab at 0x1a21c26d30>,
#  'maimed': <gensim.models.keyedvectors.Vocab at 0x1a22165160>,
#  'sank': <gensim.models.keyedvectors.Vocab at 0x1a221a9d68>,
#  'Polon': <gensim.models.keyedvectors.Vocab at 0x1a221a9fd0>,
#  'raving': <gensim.models.keyedvectors.Vocab at 0x1a221a9080>,
#  'Anakims': <gensim.models.keyedvectors.Vocab at 0x1a221a9278>,
#  'Um': <gensim.models.keyedvectors.Vocab at 0x1a221a95f8>,
#  'Wheel': <gensim.models.keyedvectors.Vocab at 0x1a1fd8e588>,
#  'started': <gensim.models.keyedvectors.Vocab at 0x1a221a96d8>,
#  'mixing': <gensim.models.keyedvectors.Vocab at 0x1a221a94a8>,
#  'Wandering': <gensim.models.keyedvectors.Vocab at 0x1a221a9940>,
#  'Aye': <gensim.models.keyedvectors.Vocab at 0x1a221a97b8>,
#  'observance': <gensim.models.keyedvectors.Vocab at 0x1a221a9e48>,
#  'indifference': <gensim.models.keyedvectors.Vocab at 0x1a2208aac8>,
#  'Barak': <gensim.models.keyedvectors.Vocab at 0x1a221a9ef0>,
#  'mingle': <gensim.models.keyedvectors.Vocab at 0x1a221a93c8>,
#  'tackle': <gensim.models.keyedvectors.Vocab at 0x1a220d7358>,
#  'darkly': <gensim.models.keyedvectors.Vocab at 0x1a1ee84908>,
#  'age': <gensim.models.keyedvectors.Vocab at 0x1a221a99b0>,
#  'Faith': <gensim.models.keyedvectors.Vocab at 0x1a221a9ac8>,
#  'lengthened': <gensim.models.keyedvectors.Vocab at 0x1a221a9c18>,
#  'purity': <gensim.models.keyedvectors.Vocab at 0x1a221a9390>,
#  'Hanoch': <gensim.models.keyedvectors.Vocab at 0x1a221a9588>,
#  'hereafter': <gensim.models.keyedvectors.Vocab at 0x1a221a9668>,
#  'wronged': <gensim.models.keyedvectors.Vocab at 0x1a221a9b00>,
#  'apparently': <gensim.models.keyedvectors.Vocab at 0x1a221a9780>,
#  'Deal': <gensim.models.keyedvectors.Vocab at 0x1a221a9978>,
#  'dreamt': <gensim.models.keyedvectors.Vocab at 0x1a221a9a58>,
#  'logic': <gensim.models.keyedvectors.Vocab at 0x1a221a9518>,
#  'pause': <gensim.models.keyedvectors.Vocab at 0x1a221a9c88>,
#  'sat': <gensim.models.keyedvectors.Vocab at 0x1a221a97f0>,
#  'victuals': <gensim.models.keyedvectors.Vocab at 0x1a221219e8>,
#  'almighty': <gensim.models.keyedvectors.Vocab at 0x1a221a91d0>,
#  'Being': <gensim.models.keyedvectors.Vocab at 0x1a221a90b8>,
#  'let': <gensim.models.keyedvectors.Vocab at 0x1a1fd8e710>,
#  'unwholesome': <gensim.models.keyedvectors.Vocab at 0x1a1fc9b7f0>,
#  'Amoz': <gensim.models.keyedvectors.Vocab at 0x1a220d7da0>,
#  'Serpent': <gensim.models.keyedvectors.Vocab at 0x1a221a9c50>,
#  'hoe': <gensim.models.keyedvectors.Vocab at 0x1a221b60b8>,
#  'array': <gensim.models.keyedvectors.Vocab at 0x1a221a9be0>,
#  'barbarians': <gensim.models.keyedvectors.Vocab at 0x1a221a9240>,
#  'simpler': <gensim.models.keyedvectors.Vocab at 0x1a221a95c0>,
#  'prou': <gensim.models.keyedvectors.Vocab at 0x1a1ee31c18>,
#  'benediction': <gensim.models.keyedvectors.Vocab at 0x1a1ee31cf8>,
#  'Highest': <gensim.models.keyedvectors.Vocab at 0x1a1ee315c0>,
#  'shrouded': <gensim.models.keyedvectors.Vocab at 0x1a1ee31c50>,
#  'sunlit': <gensim.models.keyedvectors.Vocab at 0x1a1ee31b70>,
#  'Jeshimon': <gensim.models.keyedvectors.Vocab at 0x1a1ee31828>,
#  'vest': <gensim.models.keyedvectors.Vocab at 0x1a221812e8>,
#  'dense': <gensim.models.keyedvectors.Vocab at 0x1a1ee31dd8>,
#  'Achan': <gensim.models.keyedvectors.Vocab at 0x1a1ee31630>,
#  'piano': <gensim.models.keyedvectors.Vocab at 0x1a1ee31ba8>,
#  'slily': <gensim.models.keyedvectors.Vocab at 0x1a1ee31b00>,
#  'Cleveland': <gensim.models.keyedvectors.Vocab at 0x1a221b2668>,
#  'preacher': <gensim.models.keyedvectors.Vocab at 0x1a221b2eb8>,
#  'frightened': <gensim.models.keyedvectors.Vocab at 0x1a221b2d30>,
#  'action': <gensim.models.keyedvectors.Vocab at 0x1a221b2c88>,
#  'manger': <gensim.models.keyedvectors.Vocab at 0x1a221b2128>,
#  'Amaziah': <gensim.models.keyedvectors.Vocab at 0x1a1edf46d8>,
#  'none': <gensim.models.keyedvectors.Vocab at 0x1a221b2b00>,
#  'souls': <gensim.models.keyedvectors.Vocab at 0x1a221b2c50>,
#  'corridors': <gensim.models.keyedvectors.Vocab at 0x1a221b2898>,
#  'Mississippi': <gensim.models.keyedvectors.Vocab at 0x1a21fe81d0>,
#  'repast': <gensim.models.keyedvectors.Vocab at 0x1a221b2c18>,
#  'vitality': <gensim.models.keyedvectors.Vocab at 0x1a221b2a20>,
#  'steed': <gensim.models.keyedvectors.Vocab at 0x1a221b2940>,
#  'forgotten': <gensim.models.keyedvectors.Vocab at 0x1a221b2b38>,
#  'Jerusalem': <gensim.models.keyedvectors.Vocab at 0x1a221b2278>,
#  'accent': <gensim.models.keyedvectors.Vocab at 0x1a220aa668>,
#  'conspicuous': <gensim.models.keyedvectors.Vocab at 0x1a21c37ac8>,
#  'Road': <gensim.models.keyedvectors.Vocab at 0x1a221b29e8>,
#  'agreed': <gensim.models.keyedvectors.Vocab at 0x1a2200ca58>,
#  'swallows': <gensim.models.keyedvectors.Vocab at 0x1a2200c240>,
#  'introduced': <gensim.models.keyedvectors.Vocab at 0x1a221b2e10>,
#  'feels': <gensim.models.keyedvectors.Vocab at 0x1a2215bda0>,
#  'casement': <gensim.models.keyedvectors.Vocab at 0x1a2217dcf8>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x1a221b2da0>,
#  'fetch': <gensim.models.keyedvectors.Vocab at 0x1a221b2e48>,
#  'assent': <gensim.models.keyedvectors.Vocab at 0x1a221b2320>,
#  'Short': <gensim.models.keyedvectors.Vocab at 0x1a221b2048>,
#  'marshal': <gensim.models.keyedvectors.Vocab at 0x1a221b2240>,
#  'threatening': <gensim.models.keyedvectors.Vocab at 0x1a221b2748>,
#  'stating': <gensim.models.keyedvectors.Vocab at 0x1a221b2908>,
#  'layeth': <gensim.models.keyedvectors.Vocab at 0x1a221b27f0>,
#  'Obadiah': <gensim.models.keyedvectors.Vocab at 0x1a22fbc240>,
#  'sicken': <gensim.models.keyedvectors.Vocab at 0x1a221b2f98>,
#  'backs': <gensim.models.keyedvectors.Vocab at 0x1a221b20f0>,
#  'mint': <gensim.models.keyedvectors.Vocab at 0x1a221b2518>,
#  'properly': <gensim.models.keyedvectors.Vocab at 0x1a221b2a90>,
#  'Fishery': <gensim.models.keyedvectors.Vocab at 0x1a221b2470>,
#  'monster': <gensim.models.keyedvectors.Vocab at 0x1a221b2d68>,
#  'increased': <gensim.models.keyedvectors.Vocab at 0x1a22fe6198>,
#  'slacken': <gensim.models.keyedvectors.Vocab at 0x1a22152828>,
#  'Market': <gensim.models.keyedvectors.Vocab at 0x1a22051b70>,
#  'comparatively': <gensim.models.keyedvectors.Vocab at 0x1a22175320>,
#  '70': <gensim.models.keyedvectors.Vocab at 0x1a22175400>,
#  'relating': <gensim.models.keyedvectors.Vocab at 0x1a22175668>,
#  'authorities': <gensim.models.keyedvectors.Vocab at 0x1a22175438>,
#  'wants': <gensim.models.keyedvectors.Vocab at 0x1a22175550>,
#  'inordinate': <gensim.models.keyedvectors.Vocab at 0x1a22175d30>,
#  'restrain': <gensim.models.keyedvectors.Vocab at 0x1a22175a90>,
#  'justice': <gensim.models.keyedvectors.Vocab at 0x1a22175898>,
#  'endeavouring': <gensim.models.keyedvectors.Vocab at 0x1a21ccd3c8>,
#  'trusteth': <gensim.models.keyedvectors.Vocab at 0x1a1fd475c0>,
#  'parts': <gensim.models.keyedvectors.Vocab at 0x1a22175c18>,
#  '?': <gensim.models.keyedvectors.Vocab at 0x1a22019f98>,
#  '8': <gensim.models.keyedvectors.Vocab at 0x1a221753c8>,
#  'exceeding': <gensim.models.keyedvectors.Vocab at 0x1a22175208>,
#  'admonished': <gensim.models.keyedvectors.Vocab at 0x1a22175eb8>,
#  'Wallis': <gensim.models.keyedvectors.Vocab at 0x1a22175be0>,
#  'abhorrence': <gensim.models.keyedvectors.Vocab at 0x1a22175cf8>,
#  'denoted': <gensim.models.keyedvectors.Vocab at 0x1a221752b0>,
#  'bond': <gensim.models.keyedvectors.Vocab at 0x1a22175198>,
#  'disdained': <gensim.models.keyedvectors.Vocab at 0x1a22175c50>,
#  'moist': <gensim.models.keyedvectors.Vocab at 0x1a22175080>,
#  'Philistines': <gensim.models.keyedvectors.Vocab at 0x1a1fc5b5c0>,
#  'mountainous': <gensim.models.keyedvectors.Vocab at 0x1a1fd8ed30>,
#  'sentiment': <gensim.models.keyedvectors.Vocab at 0x1a220b3eb8>,
#  'Tranquo': <gensim.models.keyedvectors.Vocab at 0x1a1fca2b70>,
#  'audacity': <gensim.models.keyedvectors.Vocab at 0x1a221754a8>,
#  'gaining': <gensim.models.keyedvectors.Vocab at 0x1a22175f28>,
#  'split': <gensim.models.keyedvectors.Vocab at 0x1a1fd476d8>,
#  'fists': <gensim.models.keyedvectors.Vocab at 0x1a22175748>,
#  'dreadfully': <gensim.models.keyedvectors.Vocab at 0x1a22191e48>,
#  'Benjamites': <gensim.models.keyedvectors.Vocab at 0x1a22175240>,
#  'paling': <gensim.models.keyedvectors.Vocab at 0x1a22175828>,
#  'niece': <gensim.models.keyedvectors.Vocab at 0x1a22175f98>,
#  'heare': <gensim.models.keyedvectors.Vocab at 0x1a22175860>,
#  'Reynol': <gensim.models.keyedvectors.Vocab at 0x1a221290b8>,
#  'occupy': <gensim.models.keyedvectors.Vocab at 0x1a22129320>,
#  'desart': <gensim.models.keyedvectors.Vocab at 0x1a22129dd8>,
#  'yonder': <gensim.models.keyedvectors.Vocab at 0x1a22129940>,
#  'viper': <gensim.models.keyedvectors.Vocab at 0x1a22129cc0>,
#  'reigneth': <gensim.models.keyedvectors.Vocab at 0x1a22129d68>,
#  'neighboring': <gensim.models.keyedvectors.Vocab at 0x1a221292b0>,
#  'lasted': <gensim.models.keyedvectors.Vocab at 0x1a221295c0>,
#  'loosening': <gensim.models.keyedvectors.Vocab at 0x1a221290f0>,
#  'mournful': <gensim.models.keyedvectors.Vocab at 0x1a2218c080>,
#  'enjoined': <gensim.models.keyedvectors.Vocab at 0x1a1ede7e48>,
#  'invariably': <gensim.models.keyedvectors.Vocab at 0x1a22129550>,
#  'flower': <gensim.models.keyedvectors.Vocab at 0x1a22129ef0>,
#  'whirlwinds': <gensim.models.keyedvectors.Vocab at 0x1a22165f98>,
#  'OTTER': <gensim.models.keyedvectors.Vocab at 0x1a221297b8>,
#  'orange': <gensim.models.keyedvectors.Vocab at 0x1a221296d8>,
#  'Cilicia': <gensim.models.keyedvectors.Vocab at 0x1a22129a58>,
#  '133': <gensim.models.keyedvectors.Vocab at 0x1a22129978>,
#  'Speake': <gensim.models.keyedvectors.Vocab at 0x1a22129588>,
#  'realized': <gensim.models.keyedvectors.Vocab at 0x1a221296a0>,
#  'scales': <gensim.models.keyedvectors.Vocab at 0x1a22129c88>,
#  'firework': <gensim.models.keyedvectors.Vocab at 0x1a22129a20>,
#  'nearly': <gensim.models.keyedvectors.Vocab at 0x108cbd1d0>,
#  'charged': <gensim.models.keyedvectors.Vocab at 0x1a22129e48>,
#  'hallow': <gensim.models.keyedvectors.Vocab at 0x1a221294a8>,
#  'denounced': <gensim.models.keyedvectors.Vocab at 0x1a22129fd0>,
#  'fluke': <gensim.models.keyedvectors.Vocab at 0x1a22129470>,
#  'pooh': <gensim.models.keyedvectors.Vocab at 0x1a221294e0>,
#  'statements': <gensim.models.keyedvectors.Vocab at 0x1a22129748>,
#  'attendance': <gensim.models.keyedvectors.Vocab at 0x1a22129908>,
#  'pomegranates': <gensim.models.keyedvectors.Vocab at 0x1a22129be0>,
#  'Scotland': <gensim.models.keyedvectors.Vocab at 0x1a22fdbf28>,
#  'describing': <gensim.models.keyedvectors.Vocab at 0x1a21c36dd8>,
#  'inches': <gensim.models.keyedvectors.Vocab at 0x1a22129b70>,
#  'Matter': <gensim.models.keyedvectors.Vocab at 0x1a22129278>,
#  "?'": <gensim.models.keyedvectors.Vocab at 0x1a22129160>,
#  'oppress': <gensim.models.keyedvectors.Vocab at 0x1a22129c50>,
#  'Write': <gensim.models.keyedvectors.Vocab at 0x1a22129080>,
#  'hearses': <gensim.models.keyedvectors.Vocab at 0x1a22129198>,
#  'target': <gensim.models.keyedvectors.Vocab at 0x1a221297f0>,
#  'designated': <gensim.models.keyedvectors.Vocab at 0x1a2213ff60>,
#  'vanities': <gensim.models.keyedvectors.Vocab at 0x1a2213fba8>,
#  'Japhia': <gensim.models.keyedvectors.Vocab at 0x1a2213fc18>,
#  'bearest': <gensim.models.keyedvectors.Vocab at 0x1a2213fa90>,
#  'Angus': <gensim.models.keyedvectors.Vocab at 0x1a2213ff28>,
#  'Even': <gensim.models.keyedvectors.Vocab at 0x1a2213f160>,
#  'remembrances': <gensim.models.keyedvectors.Vocab at 0x1a1fcb62b0>,
#  'possessor': <gensim.models.keyedvectors.Vocab at 0x1a2213fd30>,
#  'sayes': <gensim.models.keyedvectors.Vocab at 0x1a2213fef0>,
#  'obstinate': <gensim.models.keyedvectors.Vocab at 0x1a2213f748>,
#  'Bedford': <gensim.models.keyedvectors.Vocab at 0x1a2213f710>,
#  'promoted': <gensim.models.keyedvectors.Vocab at 0x1a2213f390>,
#  'dally': <gensim.models.keyedvectors.Vocab at 0x1a2213f438>,
#  'exercises': <gensim.models.keyedvectors.Vocab at 0x1a2213fe80>,
#  'ports': <gensim.models.keyedvectors.Vocab at 0x1a2213fbe0>,
#  'immemorial': <gensim.models.keyedvectors.Vocab at 0x1a2213f550>,
#  'mariner': <gensim.models.keyedvectors.Vocab at 0x1a2213f358>,
#  'cordage': <gensim.models.keyedvectors.Vocab at 0x1a2210fc18>,
#  'Rechab': <gensim.models.keyedvectors.Vocab at 0x108d5f710>,
#  'crests': <gensim.models.keyedvectors.Vocab at 0x1a2213f048>,
#  'sodden': <gensim.models.keyedvectors.Vocab at 0x1a2213fb00>,
#  'drinke': <gensim.models.keyedvectors.Vocab at 0x1a2213fdd8>,
#  'Saint': <gensim.models.keyedvectors.Vocab at 0x1a21e04198>,
#  'Baltic': <gensim.models.keyedvectors.Vocab at 0x1a2213f828>,
#  'anarchist': <gensim.models.keyedvectors.Vocab at 0x1a2213f7f0>,
#  'studied': <gensim.models.keyedvectors.Vocab at 0x1a21ca5668>,
#  'speake': <gensim.models.keyedvectors.Vocab at 0x1a2213fd68>,
#  'odor': <gensim.models.keyedvectors.Vocab at 0x1a2213f2e8>,
#  'planteth': <gensim.models.keyedvectors.Vocab at 0x1a2213fc88>,
#  'Ahiezer': <gensim.models.keyedvectors.Vocab at 0x1a2213f198>,
#  'intend': <gensim.models.keyedvectors.Vocab at 0x1a2213f1d0>,
#  'removeth': <gensim.models.keyedvectors.Vocab at 0x1a2213f0f0>,
#  'incessant': <gensim.models.keyedvectors.Vocab at 0x1a2213f6a0>,
#  'exploits': <gensim.models.keyedvectors.Vocab at 0x1a2213f400>,
#  '..."': <gensim.models.keyedvectors.Vocab at 0x1a2213fa58>,
#  'peaceably': <gensim.models.keyedvectors.Vocab at 0x1a2213f080>,
#  'sturdy': <gensim.models.keyedvectors.Vocab at 0x1a21ca54a8>,
#  'Lenox': <gensim.models.keyedvectors.Vocab at 0x1a2213f128>,
#  'Strathspey': <gensim.models.keyedvectors.Vocab at 0x1a2213f898>,
#  'penalty': <gensim.models.keyedvectors.Vocab at 0x1a2213fb38>,
#  'as': <gensim.models.keyedvectors.Vocab at 0x1a1fc81550>,
#  'Zidon': <gensim.models.keyedvectors.Vocab at 0x1a2213f0b8>,
#  'door': <gensim.models.keyedvectors.Vocab at 0x1a2213f2b0>,
#  'causes': <gensim.models.keyedvectors.Vocab at 0x1a21ca3e48>,
#  'fadeth': <gensim.models.keyedvectors.Vocab at 0x1a21ca3d30>,
#  'safe': <gensim.models.keyedvectors.Vocab at 0x1a21ca3c88>,
#  'towers': <gensim.models.keyedvectors.Vocab at 0x1a21ca3518>,
#  'anxiety': <gensim.models.keyedvectors.Vocab at 0x1a21ca3a58>,
#  'Stands': <gensim.models.keyedvectors.Vocab at 0x1a21ca3e80>,
#  'peas': <gensim.models.keyedvectors.Vocab at 0x1a21ca3a90>,
#  'Pedro': <gensim.models.keyedvectors.Vocab at 0x1a1fd91198>,
#  'impediment': <gensim.models.keyedvectors.Vocab at 0x1a21ca3b70>,
#  'holdeth': <gensim.models.keyedvectors.Vocab at 0x1a21ca31d0>,
#  'yes': <gensim.models.keyedvectors.Vocab at 0x1a21ca3160>,
#  'wondering': <gensim.models.keyedvectors.Vocab at 0x1a21ca3898>,
#  'reaching': <gensim.models.keyedvectors.Vocab at 0x1a21ca3fd0>,
#  'astonishing': <gensim.models.keyedvectors.Vocab at 0x1a23156ef0>,
#  'volition': <gensim.models.keyedvectors.Vocab at 0x1a21ca32e8>,
#  'efficacy': <gensim.models.keyedvectors.Vocab at 0x1a21ca3cc0>,
#  'sounded': <gensim.models.keyedvectors.Vocab at 0x1a21ca36a0>,
#  'sole': <gensim.models.keyedvectors.Vocab at 0x1a21ca36d8>,
#  'indignantly': <gensim.models.keyedvectors.Vocab at 0x1a22fc96a0>,
#  'dazzle': <gensim.models.keyedvectors.Vocab at 0x1a21ca3390>,
#  'renewing': <gensim.models.keyedvectors.Vocab at 0x1a21ca3320>,
#  'secret': <gensim.models.keyedvectors.Vocab at 0x1a21ca3860>,
#  'unnoticed': <gensim.models.keyedvectors.Vocab at 0x1a21ca5588>,
#  'sometimes': <gensim.models.keyedvectors.Vocab at 0x1a1fd91278>,
#  'm': <gensim.models.keyedvectors.Vocab at 0x1a21ca3da0>,
#  'suggest': <gensim.models.keyedvectors.Vocab at 0x1a21ca3198>,
#  'unsuspected': <gensim.models.keyedvectors.Vocab at 0x1a21ca39b0>,
#  'behaved': <gensim.models.keyedvectors.Vocab at 0x108cab128>,
#  'Finsb': <gensim.models.keyedvectors.Vocab at 0x1a21ca3630>,
#  'Mattithiah': <gensim.models.keyedvectors.Vocab at 0x1a21ca3048>,
#  'beg': <gensim.models.keyedvectors.Vocab at 0x1a21ca3400>,
#  'truly': <gensim.models.keyedvectors.Vocab at 0x1a21fb1208>,
#  'vial': <gensim.models.keyedvectors.Vocab at 0x1a21fb1518>,
#  'sustenance': <gensim.models.keyedvectors.Vocab at 0x1a21fb14e0>,
#  'painted': <gensim.models.keyedvectors.Vocab at 0x1a21fb1898>,
#  'Manchon': <gensim.models.keyedvectors.Vocab at 0x1a21fb15f8>,
#  'canal': <gensim.models.keyedvectors.Vocab at 0x1a21fb1748>,
#  'temperate': <gensim.models.keyedvectors.Vocab at 0x1a21fb1160>,
#  'along': <gensim.models.keyedvectors.Vocab at 0x1a21fb1400>,
#  'beggar': <gensim.models.keyedvectors.Vocab at 0x1a21fb17f0>,
#  'stead': <gensim.models.keyedvectors.Vocab at 0x1a21fb13c8>,
#  'Eshtaol': <gensim.models.keyedvectors.Vocab at 0x1a21fb1390>,
#  'tyrants': <gensim.models.keyedvectors.Vocab at 0x1a21fb1908>,
#  'drank': <gensim.models.keyedvectors.Vocab at 0x108cc2eb8>,
#  'ecstasy': <gensim.models.keyedvectors.Vocab at 0x1a21fb1ef0>,
#  'prey': <gensim.models.keyedvectors.Vocab at 0x1a21fb1f98>,
#  'unaccountably': <gensim.models.keyedvectors.Vocab at 0x1a21fb1048>,
#  'preceded': <gensim.models.keyedvectors.Vocab at 0x1a21fb1f28>,
#  'compel': <gensim.models.keyedvectors.Vocab at 0x1a21fb1a90>,
#  'Saturn': <gensim.models.keyedvectors.Vocab at 0x1a21fb1b38>,
#  'Celtic': <gensim.models.keyedvectors.Vocab at 0x1a21c442e8>,
#  'begotten': <gensim.models.keyedvectors.Vocab at 0x1a23167b70>,
#  'particle': <gensim.models.keyedvectors.Vocab at 0x1a21fb1978>,
#  'sway': <gensim.models.keyedvectors.Vocab at 0x1a1fc7d5f8>,
#  'plan': <gensim.models.keyedvectors.Vocab at 0x1a21fb1f60>,
#  'endure': <gensim.models.keyedvectors.Vocab at 0x1a21fb1be0>,
#  'depressed': <gensim.models.keyedvectors.Vocab at 0x1a21fb1d30>,
#  'thousand': <gensim.models.keyedvectors.Vocab at 0x1a21fb1a58>,
#  'stretching': <gensim.models.keyedvectors.Vocab at 0x1a21fb1828>,
#  'linger': <gensim.models.keyedvectors.Vocab at 0x1a21c44278>,
#  'Bethlehem': <gensim.models.keyedvectors.Vocab at 0x1a21fb1ba8>,
#  'occasion': <gensim.models.keyedvectors.Vocab at 0x1a21fb12e8>,
#  'Thus': <gensim.models.keyedvectors.Vocab at 0x1a21fb1940>,
#  'forbearance': <gensim.models.keyedvectors.Vocab at 0x1a21fb19e8>,
#  'boxes': <gensim.models.keyedvectors.Vocab at 0x1a1fd914e0>,
#  'fruition': <gensim.models.keyedvectors.Vocab at 0x1a21fb1c18>,
#  'win': <gensim.models.keyedvectors.Vocab at 0x1a21fb18d0>,
#  'wretchedly': <gensim.models.keyedvectors.Vocab at 0x1a21fb1dd8>,
#  'Burs': <gensim.models.keyedvectors.Vocab at 0x1a21fb1c50>,
#  'pupil': <gensim.models.keyedvectors.Vocab at 0x1a21fb1588>,
#  ...}

# %%
len(model.wv.vocab)
# Out:
# 17011

# %%
X = model[model.wv.vocab]
# Out:
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.

# %%
X.shape
# Out:
# (17011, 64)

# %%
tsne = TSNE(n_components=2, n_iter=1000) # 200 is minimum iter; default is 1000

# %%
X_2d = tsne.fit_transform(X)

# %%
X_2d[0:5]
# Out:
# array([[ 13.391891  ,   1.9432112 ],
#        [ 20.509947  ,   0.80460984],
#        [-53.964687  , -11.186844  ],
#        [ -9.772385  ,  26.141178  ],
#        [-20.207508  ,  -9.523707  ]], dtype=float32)

# %%
# create DataFrame for storing results and plotting
coords_df = pd.DataFrame(X_2d, columns=['x','y'])
coords_df['token'] = model.wv.vocab.keys()

# %%
coords_df.head()
# Out:
#            x          y      token
# 0  13.391891   1.943211  hurricane
# 1  20.509947   0.804610       beef
# 2 -53.964687 -11.186844    Caesars
# 3  -9.772385  26.141178     raised
# 4 -20.207508  -9.523707       hits

# %%
# coords_df.to_csv('raw_gutenberg_tsne.csv', index=False)

# %% [markdown]
# #### Visualize 2D representation of word vectors

# %%
coords_df.plot.scatter('x', 'y', figsize=(12,12), marker='.', s=10, alpha=0.2,c="blue")

# %%
output_notebook() # output bokeh plots inline in notebook
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="55a0de12-a6cf-44bb-aa10-cca2336ef680">Loading BokehJS ...</span>
#     </div>

# %%
subset_df = coords_df.sample(n=5000)

# %%
p = figure(plot_width=800, plot_height=800)
_ = p.text(x=subset_df.x, y=subset_df.y, text=subset_df.token)

# %%
show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="d61bce4c-cacd-4daf-952d-63a469d4505c"></div>
# </div>
